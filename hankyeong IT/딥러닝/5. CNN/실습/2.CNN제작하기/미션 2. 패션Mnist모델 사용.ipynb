# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### test_img폴더의 데이터셋 예측하기
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.models import load_model
model=load_model('./data/model/fashionMNIST_CNN.hdf5')  
model.summary()
model.layers[0].input_shape
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 64)          36928
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 64)                36928
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________
# (None, 28, 28, 1)

# %%
from PIL import Image
import numpy as np
from glob import glob
import matplotlib.pyplot as plt


imgs = glob('./test_img/*.jpg')
plt.figure(figsize=(20,5))
for cnt,x in enumerate(imgs):

    img=Image.open(x).convert('L') #흑백으로 읽음
    img=img.resize((28,28))
    imgArr=np.array(img)/255
    inputimage=imgArr.reshape(1,28,28,1)
    predictNum=model.predict(inputimage)  # 1-1에서 모델제작할때 
    num=np.argmax(predictNum)  #3번값이 제일큼

    plt.imshow(imgArr, cmap='gray')
    plt.title(class_names[num])
    plt.show()

    print('위의 이미지는 다음과 같이 예측함==>'+class_names[num])
    print('-'*50)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 위의 이미지는 다음과 같이 예측함==>Ankle boot
# --------------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# 위의 이미지는 다음과 같이 예측함==>Pullover
# --------------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# 위의 이미지는 다음과 같이 예측함==>Trouser
# --------------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# 위의 이미지는 다음과 같이 예측함==>Trouser
# --------------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# 위의 이미지는 다음과 같이 예측함==>Shirt
# --------------------------------------------------

# %% [markdown]
# ### 모델을 이용한 예측
# - test_img 폴더안 자료가 이미지, 출력값과 같이 나올수 있도록 코드를 작성
# ![image.png](attachment:image.png)

# %%
# Out:
# --------------------------------------------------
# 위의 이미지는 다음과같이 예측함==> Ankle boot
# --------------------------------------------------
# 위의 이미지는 다음과같이 예측함==> Pullover
# --------------------------------------------------
# 위의 이미지는 다음과같이 예측함==> Trouser
# --------------------------------------------------
# 위의 이미지는 다음과같이 예측함==> Trouser
# --------------------------------------------------
# 위의 이미지는 다음과같이 예측함==> Shirt
