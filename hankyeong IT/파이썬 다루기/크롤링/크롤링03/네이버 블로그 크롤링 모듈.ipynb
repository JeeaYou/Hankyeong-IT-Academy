# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup as bs
import warnings
warnings.filterwarnings('ignore')

def connect(검색어,pages=1):
    htmls=[]
    # 옵션 생성
    options = webdriver.ChromeOptions()
    # 창 숨기는 옵션 추가
    options.add_argument("headless")
    
    
    for page in range(1,pages+1):
        url='https://section.blog.naver.com/Search/Post.naver?pageNo='+str(page)+'&rangeType=ALL&orderBy=sim&keyword='+검색어

        driver=webdriver.Chrome('./chromedriver.exe') 
        driver.get(url)
        time.sleep(3)
        htmls.append(driver.page_source)

    driver.close()
    driver.quit()
    return htmls

def nBlog(검색어,pages=1):
    
        # 옵션 생성
    options = webdriver.ChromeOptions()
    # 창 숨기는 옵션 추가
    options.add_argument("headless")  
    
    htmls=connect(검색어,pages)
    res=[]
    for html in htmls:
        soup=bs(html,'html.parser')
        div_tags=soup.select('div.info_post')
        for  div in div_tags:
            title=div.find('span','title').text
            link=div.find('a','desc_inner')['href']
            cont=div.find('a','text').text
            writer=div.find('em','name_author').text
            date=div.find('span','date').text
            tmp={
                '제목':title,
                '작성자':writer,
                '작성일':date,
                '요약글':cont,
                '링크':link
            }
            res.append(tmp)
    df=pd.DataFrame(res)
   
    driver=webdriver.Chrome('./chromedriver.exe')
    cont_res=[]
    for i in df['링크']:
        driver.get(i)
        time.sleep(2)
        
        iframe=driver.find_element(By.ID,'mainFrame')
        driver.switch_to.frame(iframe) #irame 창으로 이동함
        
        contents=driver.find_element(By.CLASS_NAME,'se-main-container').text.replace('\n','')
        cont_res.append(contents)

    driver.close()
    driver.quit()

    df['내용']=cont_res
    print('--------------end----------------')
    return df



if __name__=='__main__':
    df_star=nBlog('스타벅스',2)
    display(df_star)
# Out:
# --------------end----------------
#                                                   제목        작성자           작성일  \
# 0                             스타벅스 테이크아웃 리유저블 트라이탄 컵        찬양론   2022. 8. 9.
# 1                                  내가 스타벅스에 가지 않는 이유  요리하는 부자엄마   2022. 8. 9.
# 2                        스타벅스 제주 청귤 라임 에이드 직접 마셔본 후기         바비   2022. 8. 2.
# 3                       스마일클럽 스타벅스 사이즈업 무료 월2회 챙기세요.       하루레나   2022. 8. 5.
# 4                         스타벅스 써머 캐리백 교환 및 대체상품 선택하기      Linda        17시간 전
# 5                     스타벅스 데스크 모듈 이번에 서머 캐리백 대체상품 소개    charmer        18시간 전
# 6                         냄새나는 스타벅스 서머 캐리백, 더 심각한 문제        달도시  2022. 6. 29.
# 7                 스타벅스 사이즈 커피 컵 크기, 톨 그란데 벤티까지 깔끔 정리       분홍기린        17시간 전
# 8                  일산호수공원 스타벅스 리저브 쿨라임피지오 그리고 바닐라빈라떼        알라미   2022. 8. 7.
# 9             스타벅스 신메뉴 우리쑥크림프라푸치노 기프티콘 2개 쓰고, 별적립 6개         헬씨   2022. 8. 7.
# 10         [미국주식] 스타벅스(SBUX) '22년 2분기 실적발표(22.08.02)        떠까야   2022. 8. 9.
# 11                 스타벅스 쿨서머캐모마일블렌디드 우리쑥크림프라푸치노 섭섭한데요         멍멍  2022. 7. 28.
# 12  여자혼자 말레이시아 자유여행 DAY4 : 페낭 바투페링기 스타벅스 접이식 텀블러...      vivian  2022. 8. 10.
# 13                            춘천 구봉산 카페 스타벅스 춘천구봉산R점      천국나그네   2022. 8. 4.
#
#                                                   요약글  \
# 0   요즘 어딜가나 챙겨 나가는 컵 저는 신세계 계열사를 재직중이라 스타벅스에 임직원 할...
# 1   사실 나는 스타벅스 죽순이였다. 특히, 겨울이 너무 길고 추운 미국 동부에 사는 사...
# 2   얼마 전 여름 3차 md 나오는 날 저는 스타벅스 제주 청귤 라임 에이드 마시고 왔...
# 3   바로 스마일클럽 스타벅스 사이즈업 무료~! 전국 스벅 매장에서 사용할 수 있는 이 ...
# 4   속에도 스타벅스 가서 캐리백 교환까지 야무지게 한 린다 칭찬해~ 나는 캐리백이 총 ...
# 5   스타벅스 데스크 모듈 드디어 서머 캐리백 사건 이후 스타벅스 대체상품 올라왔습니다!...
# 6   그럼에도 밖에서 일이 있거나 미팅이 있으면 스타벅스 나 커피빈 등을 애용합니다. 그...
# 7   스타벅스 사이즈인 Tall, Grande, Venti는 과연 어느 정도의 부피인지 ...
# 8   남편과 함께 일산호수공원 나들이 나와서 식사를 마치고 커피 한잔하러 스타벅스로 출동...
# 9   스타벅스 신메뉴 우리쑥크림프라푸치노 기프티콘 2개 쓰고, 별적립 6개 스타벅스기프티...
# 10  나의 최애 스타벅스도 실적을 발표했다. 늦은 포스팅이지만, 예상외의 호실적을 발표하...
# 11  스타벅스 쿨서머캐모마일블렌디드 주세요 헉헉 이름만큼이나 맛도 독특했던 두 가지 음료...
# 12  낮에 보는 페낭 바다 엄청 뜨겁다 ㅋㅋㅋㅋㅋㅋㅋㅋ 와우 더워 죽어요 ㅋㅋㅋㅋ 다른 ...
# 13  춘천 구봉산 카페 스타벅스 춘천구봉산R점 근래 춘천을 몇번 가고 있네요 ㅎㅎㅎ 카페...
#
#                                                   링크  \
# 0       https://blog.naver.com/chaetle6/222843855707
# 1   https://blog.naver.com/bellevuecake/222844227728
# 2      https://blog.naver.com/etienne03/222836999230
# 3     https://blog.naver.com/renapark99/222840696655
# 4      https://blog.naver.com/ekdud1990/222845143297
# 5         https://blog.naver.com/bwh011/222845068559
# 6        https://blog.naver.com/shane70/222793317101
# 7     https://blog.naver.com/sunzooland/222845144156
# 8     https://blog.naver.com/ariel_0402/222842105457
# 9        https://blog.naver.com/fmfaith/222842222119
# 10    https://blog.naver.com/dark_blitz/222843398776
# 11      https://blog.naver.com/nowwegom/222831767408
# 12       https://blog.naver.com/balovej/222844693626
# 13    https://blog.naver.com/jagger0723/222838619116
#
#                                                    내용
# 0   요즘 어딜가나 챙겨 나가는 컵저는 신세계 계열사를 재직중이라스타벅스에 임직원 할인이...
# 1   나는 커피 중독자다...아침에 일어나면 꼭 커피를 마셔줘야 한다.그런 나에게 네스프...
# 2   날씨가 너무 더워서 아침부터 아이스 음료만찾게 되는 요즘인데요.얼마 전 여름 3차 ...
# 3   잇님들 지마켓 스마일클럽 이용하시나요?~저는 벌써 몇 년째 매해 갱신하며 이용중인데...
# 4   오늘은 즐거운 연차..하지만 오늘 차 때문에아침 7시부터 오후 4시까지양산동 - 효...
# 5   스타벅스 데스크 모듈드디어 서머 캐리백 사건 이후스타벅스 대체상품 올라왔습니다!지금...
# 6   저는 #커피 중독자 입니다. 집과 사무실에 #전자동에스프레소머신 을 가져다 놓고 몇...
# 7   안녕하세요. 스벅 호갱님 분홍기린입니다.스벅의 핫 음료를 담아주는 종이컵 이미지 보...
# 8   남편과 함께 일산호수공원 나들이 나와서 식사를 마치고커피 한잔하러 스타벅스로 출동!...
# 9   스타벅스 신메뉴 우리쑥크림프라푸치노 기프티콘 2개 쓰고, 별적립 6개스타벅스기프티콘...
# 10  나의 최애 스타벅스도 실적을 발표했다.늦은 포스팅이지만, 예상외의 호실적을 발표하면...
# 11  이번 신상 메뉴들은 이름만 들어서는맛이 쉽게 상상되지 않는 것들이라전부 먹어보지 않...
# 12  낮에 보는 페낭 바다여자혼자 말레이시아 자유여행 DAY4 : 페낭 바투페링기 스타벅...
# 13  춘천 구봉산 카페스타벅스 춘천구봉산R점근래 춘천을 몇번 가고 있네요 ㅎㅎㅎ카페들이 ...
