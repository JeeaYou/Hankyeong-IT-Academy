# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as bs

# %%
검색어='스타벅스'
pages=10

htmls=[]
for page in range(1,pages+1):
    url='https://search.daum.net/search?w=blog&DA=PGD&enc=utf8&q='+검색어+'&p='+str(page)
    html=requests.get(url)
    htmls.append(html)

result=[]
for html in htmls:
    soup=bs(html.text,'html.parser')
    div_tags=soup.select('div.cont_inner')
    res=[]
    for div in div_tags:
        title=div.find('a','f_link_b').text
        url=div.find('a','f_link_b')['href']
        date=div.find('span','f_nb date').text
        contents=div.find('p','f_eb desc').text
        writer=div.find('a','f_nb').text
        tmp={
            '제목':title,
            '작성일':date,
            '내용':contents,
            '작성자':writer,
            'url':url
        }
        res.append(tmp)
    df=pd.DataFrame(res)
    result.append(df)

# df=pd.DataFrame(result)
# display(df)

# %%
df_res=pd.concat(result,ignore_index=True)
display(df_res)
# Out:
#                                   제목         작성일  \
# 0               스타벅스 메뉴 및 인상된 가격 총정리  2022.08.03
# 1     스타벅스코리아, 달라지는 건가? 반가운 변화 몇 가지.  2022.08.04
# 2                     요즘 스타벅스 왜 이러나?  2022.07.24
# 3           스타벅스서머캐리백 발암물질, 교환은 어떻게?  2022.08.02
# 4             [카페] 영등포 타임스퀘어 스타벅스 2F  2022.07.22
# ..                               ...         ...
# 95               스타벅스 논란과 스타벅스 주가 흐름  2022.07.26
# 96  스타벅스 샌드위치 추천 - 트리플 치즈 크로크무슈 구매리뷰  2022.08.03
# 97                  스타벅스 바리스타 6개월 후기  2022.08.01
# 98             스타벅스 커피캡슐 버리기 그리고 커피맛  2022.07.22
# 99         광교 스타벅스, 광교더샵레이크시티점 오픈 주차  2022.07.23
#
#                                                    내용                    작성자  \
# 0   스타벅스는 전 세계 가장 규모가 큰 커피 프랜차이즈로 국내에서도 많은 사람들이 이용...                 따뜻한세상
# 1   안녕하세요. 스타벅스, 단 1주 가지고 있는 초개미주주 석아산입니다. 그간 스타벅스...   micro story 작가 석...
# 2   스타벅스 유감 스타벅스는 국내 커피 산업의 대표 선두주자이자 국내 여가 문화를 바꾼...             카페 방문 블로그
# 3   스타벅스 여름 프리퀀시 증정품인 ‘서머 캐리백’에서 발암 물질로 간주되는 폼알데하이...           보라엘’s 이스터에그
# 4   타임스퀘어에는 무려 5개의 스타벅스가 있다. 나는 5군데의 스타벅스를 모두 가보았는...                  적자생존
# ..                                                ...                    ...
# 95  주시쿨 짝은거인 입니다. 스타벅스 논란과 스타벅스 주가 흐름 최근에 스타벅스가 논란...        주식투자를 시작하는 ...
# 96  스타벅스 샌드위치 추천 - 트리플 치즈 크리크무슈 구매리뷰 지금 바로 시작합니다. ...                   놀이터
# 97  ​ ​ 드디어 적는 스타벅스 알바 후기 솔직히 5개월도 못하고 나가떨어질 줄 알았는...              T, THREE
# 98  분리수거 하기가 참 애매하죠? 그냥 버리려니 양심에 걸리고 하기는 너무 귀찮고!! ...               나만의 노하우
# 99  스타벅스 광교더샵레이크시티점 ​ 경기도 수원시 영통구 광교호수공원로 20 문의전화:...                엉터리 식객
#
#                                                 url
# 0                            http://0302.h12p.com/3
# 1                   http://tjrdktks.tistory.com/392
# 2       https://blog.naver.com/sinjh77/222826707167
# 3                           http://purpleel.com/145
# 4            http://reading-meaning.tistory.com/131
# ..                                              ...
# 95                  http://jusikcool.tistory.com/40
# 96                             http://i1825.com/362
# 97    https://blog.naver.com/althd1704/222836466926
# 98        https://blog.naver.com/gndhs/222824031271
# 99  https://blog.naver.com/sunpower621/222824950977
#
# [100 rows x 5 columns]
