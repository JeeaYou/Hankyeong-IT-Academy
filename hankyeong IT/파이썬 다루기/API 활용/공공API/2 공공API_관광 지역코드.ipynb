# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'#한글 깨짐 해결
plt.rcParams['axes.unicode_minus'] = False  #- 깨짐 해결

# %%
def area_C(areaCode=''):
    key='Jid5jJfVfwuc7brfbSDE6yxusvhmIOTMmmZE%2F%2F%2B2YdeSPIAoRpSnof9qpb5OSeEpyvP8xnb6AO4V7kXVEJFPEQ%3D%3D'
    url1='http://api.visitkorea.or.kr/openapi/service/rest/KorService/areaCode?serviceKey=' + key
    url2='&numOfRows=100&pageNo=1&MobileOS=ETC&MobileApp=AppTest&areaCode='+areaCode
    url=url1+url2
    xml=requests.get(url)
    soup=bs(xml.text,'html.parser')
    data=soup.find_all('item')
    res=[]
    for i in data:
        res.append([i.find('code').text,i.find('name').text])
    
    return res

# %%
arr1
# Out:
# [['1', '서울'],
#  ['2', '인천'],
#  ['3', '대전'],
#  ['4', '대구'],
#  ['5', '광주'],
#  ['6', '부산'],
#  ['7', '울산'],
#  ['8', '세종특별자치시'],
#  ['31', '경기도'],
#  ['32', '강원도'],
#  ['33', '충청북도'],
#  ['34', '충청남도'],
#  ['35', '경상북도'],
#  ['36', '경상남도'],
#  ['37', '전라북도'],
#  ['38', '전라남도'],
#  ['39', '제주도']]

# %%
arr1=area_C()
arr2=[]
for i,_ in arr1:
    arr2.append(area_C(i))

# %%
res=[]
for i, j in zip(arr1,arr2):
    for k in j:
        res.append(i+k)
res
# Out:
# [['1', '서울', '1', '강남구'],
#  ['1', '서울', '2', '강동구'],
#  ['1', '서울', '3', '강북구'],
#  ['1', '서울', '4', '강서구'],
#  ['1', '서울', '5', '관악구'],
#  ['1', '서울', '6', '광진구'],
#  ['1', '서울', '7', '구로구'],
#  ['1', '서울', '8', '금천구'],
#  ['1', '서울', '9', '노원구'],
#  ['1', '서울', '10', '도봉구'],
#  ['1', '서울', '11', '동대문구'],
#  ['1', '서울', '12', '동작구'],
#  ['1', '서울', '13', '마포구'],
#  ['1', '서울', '14', '서대문구'],
#  ['1', '서울', '15', '서초구'],
#  ['1', '서울', '16', '성동구'],
#  ['1', '서울', '17', '성북구'],
#  ['1', '서울', '18', '송파구'],
#  ['1', '서울', '19', '양천구'],
#  ['1', '서울', '20', '영등포구'],
#  ['1', '서울', '21', '용산구'],
#  ['1', '서울', '22', '은평구'],
#  ['1', '서울', '23', '종로구'],
#  ['1', '서울', '24', '중구'],
#  ['1', '서울', '25', '중랑구'],
#  ['2', '인천', '1', '강화군'],
#  ['2', '인천', '2', '계양구'],
#  ['2', '인천', '3', '미추홀구'],
#  ['2', '인천', '4', '남동구'],
#  ['2', '인천', '5', '동구'],
#  ['2', '인천', '6', '부평구'],
#  ['2', '인천', '7', '서구'],
#  ['2', '인천', '8', '연수구'],
#  ['2', '인천', '9', '옹진군'],
#  ['2', '인천', '10', '중구'],
# ...

# %%
df=pd.DataFrame(res,columns=['addr1','시도','addr2','시군구'])

# %%
df
# Out:
#     addr1    시도 addr2   시군구
# 0       1    서울     1   강남구
# 1       1    서울     2   강동구
# 2       1    서울     3   강북구
# 3       1    서울     4   강서구
# 4       1    서울     5   관악구
# ..    ...   ...   ...   ...
# 229    38  전라남도    24   화순군
# 230    39   제주도     1  남제주군
# 231    39   제주도     2  북제주군
# 232    39   제주도     3  서귀포시
# 233    39   제주도     4   제주시
#
# [234 rows x 4 columns]

# %%
df.to_csv('지역코드.csv', encoding='cp949')
