# %%
import os
import sys
import urllib.request
import json
import pandas as pd

def connect(검색어,api):
    client_id = "MhFgqjK_W22Mux6cStc6"
    client_secret = "m12uohVmNe"
    api=api
    검색어=검색어
    encText = urllib.parse.quote('스타벅스')
    start=1
    url = 'https://openapi.naver.com/v1/search/'+api+'?query=' + encText +'&display=100'+'&start='+str(start) # json 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()

    else:
        print("Error Code:" + rescode)
        return
    return response_body

def naver_api(검색어,api='blog'):
    '''
     api='blog'(default) 'news | cafearticle | kin | book | encyc | movie'
     
     'news(뉴스) | cafearticle(카페글) | kin(지식인) | book(책검색) | encyc(백과사전) | movie(영화검색)'
    '''
    response_body=connect(검색어,api)
    json_obj=json.loads(response_body)
    df=pd.DataFrame(json_obj['items'])
    return df

def total_count(검색어,api='blog'):
    '''
     [검색결과 총 개수 확인]
     api='blog'(default) 'news | cafearticle | kin | book | encyc | movie'
     
     'news(뉴스) | cafearticle(카페글) | kin(지식인) | book(책검색) | encyc(백과사전) | movie(영화검색)'
    '''
    response_body=connect(검색어,api)
    json_obj=json.loads(response_body)
    total=json_obj['total']
    return total

if __name__=='__main__':
    
    df=naver_api('스타벅스','news')
    display(df)
# Out:
#                                                 title  \
# 0          NH농협카드, 착한 기업 &apos;농카발굴단 시즌3&apos; 유튜브 공개
# 1             <b>스타벅스</b>, 논란 후폭풍에 성장세 &apos;흔들&apos;
# 2                      NH농협카드, 착한소비 확산 위한 홍보영상 유튜브 공개
# 3          유통업계, 멤버십 경쟁·상장 추진까지 &apos;격동&apos; 상반기 보내
# 4                   서울시50플러스재단, 굿잡 5060 취업 트렌드 세미나 개최
# ..                                                ...
# 95  신한금융투자, 비대면 VIP 고객 위한…&apos;디지털 VIP 멤버십 서비스&ap...
# 96   신한금융투자, &apos;디지털 VIP 멤버십 서비스&apos; 오픈 기념 이벤트 실시
# 97                                     G마켓, 상시 할인전 진행
# 98                           현대카드, 8월 할인 및 캐시백 이벤트 진행
# 99  노랑풍선, 예능 &apos;연애는 직진&apos; 제작지원.. &apos;다낭 코스...
#
#                                          originallink  \
# 0   http://www.shinailbo.co.kr/news/articleView.ht...
# 1           https://www.paxnetnews.com/articles/90228
# 2   http://www.m-i.kr/news/articleView.html?idxno=...
# 3         https://zdnet.co.kr/view/?no=20220803180043
# 4   https://www.onews.tv/news/articleView.html?idx...
# ..                                                ...
# 95  http://www.lcnews.co.kr/news/articleView.html?...
# 96  http://www.seoulwire.com/news/articleView.html...
# 97  http://www.newsworker.co.kr/news/articleView.h...
# 98  http://www.newsworker.co.kr/news/articleView.h...
# 99  http://www.discoverynews.kr/news/articleView.h...
#
#                                                  link  \
# 0   http://www.shinailbo.co.kr/news/articleView.ht...
# 1           https://www.paxnetnews.com/articles/90228
# 2   http://www.m-i.kr/news/articleView.html?idxno=...
# 3   https://n.news.naver.com/mnews/article/092/000...
# 4   https://www.onews.tv/news/articleView.html?idx...
# ..                                                ...
# 95  http://www.lcnews.co.kr/news/articleView.html?...
# 96  http://www.seoulwire.com/news/articleView.html...
# 97  http://www.newsworker.co.kr/news/articleView.h...
# 98  http://www.newsworker.co.kr/news/articleView.h...
# 99  http://www.discoverynews.kr/news/articleView.h...
#
#                                           description  \
# 0   영상을 시청한 후 이벤트 게시글에 감상평 댓글을 남기면 추첨을 통해 △동구밭 패키지...
# 1   시민단체·소비자 불만 지속…이미지 타격·실적 성장 제동 우려 <b>스타벅스</b>코...
# 2   농카발굴단 댓글 이벤트도 공식 유튜브 채널에서 진행한다. 영상을 시청한 후 이벤트 ...
# 3   신세계그룹의 ‘스마일클럽’은 SSG닷컴·지마켓·옥션·<b>스타벅스</b>코리아 혜택...
# 4   사전 등록 신청 및 생방송 만족도 설문 참여자들을 대상으로 추첨을 통해 <b>스타벅...
# ..                                                ...
# 95  이벤트 기간 중 순입금고 10만원 이상인 고객을 대상으로 매주 30명, 총 390명...
# 96  이벤트 기간 중 순입금고 10만원 이상인 고객을 대상으로 매주 30명, 총 390명...
# 97  빕스, 애슐리, 매드포갈릭, 서가앤쿡 등 인기 레스토랑과 유명 커피 및 디저트 브랜...
# 98  매장에서 사용할 수 있는 모바일 쿠폰 19종을 마련했다. 대상 브랜드는 <b>스타벅...
# 99  추첨을 통해 1등(1명)에게는 150만원 상당의 남호이안 빈펄리조트 2베드 풀빌라 ...
#
#                             pubDate
# 0   Thu, 04 Aug 2022 08:26:00 +0900
# 1   Thu, 04 Aug 2022 08:22:00 +0900
# 2   Thu, 04 Aug 2022 08:12:00 +0900
# 3   Thu, 04 Aug 2022 08:07:00 +0900
# 4   Thu, 04 Aug 2022 07:56:00 +0900
# ..                              ...
# 95  Wed, 03 Aug 2022 13:16:00 +0900
# 96  Wed, 03 Aug 2022 13:12:00 +0900
# 97  Wed, 03 Aug 2022 13:10:00 +0900
# 98  Wed, 03 Aug 2022 13:10:00 +0900
# 99  Wed, 03 Aug 2022 12:40:00 +0900
#
# [100 rows x 5 columns]
