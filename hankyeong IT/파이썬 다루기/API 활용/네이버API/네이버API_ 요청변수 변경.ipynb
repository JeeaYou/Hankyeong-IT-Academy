# %%
# 요청 변수 변경하기

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json

client_id = "MhFgqjK_W22Mux6cStc6"
client_secret = "m12uohVmNe"
encText = urllib.parse.quote("스타벅스")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText +'&display=100'+'&start=1' # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    json_obj=json.loads(response_body)
    print(len(json_obj['items']))
    display(json_obj['items'])
    #print(response_body.decode('utf-8'))

else:
    print("Error Code:" + rescode)
# Out:
# 100
# [{'title': '새로나온 <b>스타벅스</b> 퍼플사워블렌디드',
#   'link': 'https://blog.naver.com/brightenedu?Redirect=Log&logNo=222786790959',
#   'description': '얼마 전에 여름 신메뉴 2탄으로 <b>스타벅스</b> 퍼플사워블렌디드 포함 3종이 나왔다고 해서 마셔봤어요.... 그래도 <b>스타벅스</b> 퍼플사워블렌디드와 커피 드로잉 말차 프라푸치노의 맛이 궁금해 주문해 보았고요. 늘... ',
#   'bloggername': '김원장의 탐구생활',
#   'bloggerlink': 'https://blog.naver.com/brightenedu',
#   'postdate': '20220624'},
#  {'title': '<b>스타벅스</b> 제주 청귤 라임 에이드 직접 마셔본 후기',
#   'link': 'https://blog.naver.com/etienne03?Redirect=Log&logNo=222836999230',
#   'description': '얼마 전 여름 3차 md 나오는 날 저는 <b>스타벅스</b> 제주 청귤 라임 에이드 마시고 왔어요. 아침부터 친구랑... 이번 <b>스타벅스</b> 신음료는 총 3가지로 제주 청귤 라임 에이드 우리 쑥 크림 프라푸치노 with 콜드 브루 쿨... ',
#   'bloggername': 'Barbie&apos;s place',
#   'bloggerlink': 'https://blog.naver.com/etienne03',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 원두 데일리로 부담일 때 가성비 핸드드립 커피 원두... ',
#   'link': 'https://blog.naver.com/sticky4?Redirect=Log&logNo=222836936488',
#   'description': '원래는 <b>스타벅스</b> 커피를 좋아해서 집에서 마실 때도 <b>스타벅스</b> 원두 매장이나 이마트에서 사다마셨거든요..! 원래 마시던 건 제가 산미를 좋아해서 케냐나 에티오피아를 사다 마셨는데요. <b>스타벅스</b> 원두... ',
#   'bloggername': '트래블리♡ travel + lovely',
#   'bloggerlink': 'https://blog.naver.com/sticky4',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 천안서북이마트점 리뉴얼 오픈',
#   'link': 'https://blog.naver.com/renapark99?Redirect=Log&logNo=222833741364',
#   'description': '<b>스타벅스</b> 천안서북이마트점 리뉴얼 오픈!! 이마트 천안서북점이 작년 가을부턴가 리뉴얼 공사를 하더니만... 어느새 사라진 <b>스타벅스</b>는 왜 다시 오픈할 생각을 안 하는지.. 정신없이 7월 한 달 보내다보니... ',
#   'bloggername': '하루레나의 육아로그 Start small☆',
#   'bloggerlink': 'https://blog.naver.com/renapark99',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 선불충전금과 선수금 회계처리 기본 개념',
#   'link': 'https://blog.naver.com/zhowoon79?Redirect=Log&logNo=222803235614',
#   'description': '<b>스타벅스</b> 코리아 홈페이지 <b>스타벅스</b> 선불충전금도 일종의 선수금이다. 사이렌이라는 편리한 서비스를 이용하기 위해 미리 충전해 놓은 결제 대금인 것이다. 지금 <b>스타벅스</b>는 이런 결제 대금을 과거 조선사처럼... ',
#   'bloggername': '기업의 일생 feat. 회계사',
#   'bloggerlink': 'https://blog.naver.com/zhowoon79',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 배당금, 배당일, 주가 알아봅시다',
#   'link': 'https://blog.naver.com/hoosigidane?Redirect=Log&logNo=222836911416',
#   'description': '<b>스타벅스</b> 배당금, 배당일, 주식 알아봅시다 안녕하세요 오늘은 <b>스타벅스</b> 최근 주가 현황과 배당금, 배당일까지 알아보겠습니다! 커피시장에서 부동의 1위를 차지하고 있는 <b>스타벅스</b> 연일 안좋은 소식들이... ',
#   'bloggername': '느프트린이',
#   'bloggerlink': 'https://blog.naver.com/hoosigidane',
#   'postdate': '20220801'},
#  {'title': '제주 협재 해수욕장 <b>스타벅스</b> &amp; 제주 감성 기념품샵 오달콤제주',
#   'link': 'https://blog.naver.com/boring_29?Redirect=Log&logNo=222836331881',
#   'description': 'ㅎㅎ 제주 협재 해수욕장 <b>스타벅스</b> 제주 감성 기념품샵 오달콤제주 - 두 아이와 함께 하는 제주 여행... 그래서 아이들과 함께 협재 해수욕장에 있는 <b>스타벅스</b>에 갔습니다. 협재 해수욕장에 다른 카페도 있지만... ',
#   'bloggername': '보링보링의 손으로 만든 세상',
#   'bloggerlink': 'https://blog.naver.com/boring_29',
#   'postdate': '20220802'},
#  {'title': '냄새나는 <b>스타벅스</b> 서머 캐리백, 더 심각한 문제',
#   'link': 'https://blog.naver.com/shane70?Redirect=Log&logNo=222793317101',
#   'description': '그럼에도 밖에서 일이 있거나 미팅이 있으면 <b>스타벅스</b> 나 커피빈 등을 애용합니다. 그러다보니 #<b>스타벅스</b> #프리퀀시 상품을 빠지지 않고 다 받았습니다. 사실 잘 쓰지도 않는데도 불구하고 다 집에 모여... ',
#   'bloggername': '아직은 아냐^ ^ (달도시 블로그)',
#   'bloggerlink': 'https://blog.naver.com/shane70',
#   'postdate': '20220629'},
#  {'title': '방콕의 랑수안 <b>스타벅스</b>는 아시아 1호점이 아닙니다',
#   'link': 'https://blog.naver.com/malahalo?Redirect=Log&logNo=222825045305',
#   'description': '태국 방콕 여행을 기획한 나언니가 방콕에 아시아 1호점 <b>스타벅스</b>가 있다고 해서 굉장히 설레는... 실제로 국내에선 보기 힘든 형태의 건물이 <b>스타벅스</b>여서 시선을 끌긴 하더라고요. 심지어 저희가 묵었던 호텔... ',
#   'bloggername': '라깰의 어제보다 즐거운 오늘',
#   'bloggerlink': 'https://blog.naver.com/malahalo',
#   'postdate': '20220723'},
#  {'title': '<b>스타벅스</b> 우리 쑥 크림 프라푸치노 맛보다/ <b>스타벅스</b> 웰컴레벨... ',
#   'link': 'https://blog.naver.com/amj5356?Redirect=Log&logNo=222838854078',
#   'description': '코로나로 대형마트 안간지가 몇주가 되었어요 신랑 마지막으로 코로나 격리해제되고 마트장보고 왔답니다 간김에 날짜 임박한 기프티콘 쓰고 <b>스타벅스</b> 음료 즐겨주었지요 <b>스타벅스</b> 양산 이마트점 제일 자주... ',
#   'bloggername': '왕뽈따구',
#   'bloggerlink': 'https://blog.naver.com/amj5356',
#   'postdate': '20220803'},
#  {'title': '영도카페: 영도에 두번째 <b>스타벅스</b> (영도청학DT점)',
#   'link': 'https://blog.naver.com/goswn1022?Redirect=Log&logNo=222833483908',
#   'description': '영도에 두번째 <b>스타벅스</b>가 생기다니 엄마가 청학동에 지금 짓고있는거 <b>스타벅스</b>인가 그렇다는데? 하길래 <b>스타벅스</b>가 뭐를 위해서 여기 안쪽까지 들어오겠어? 라며 사업에 영 보는 눈이 없는 내가 말했다..... ',
#   'bloggername': '힘을내는블로그',
#   'bloggerlink': 'https://blog.naver.com/goswn1022',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 쿨서머캐모마일블렌디드 우리쑥크림프라푸치노... ',
#   'link': 'https://blog.naver.com/nowwegom?Redirect=Log&logNo=222831767408',
#   'description': '<b>스타벅스</b> 쿨서머캐모마일블렌디드 주세요 헉헉 이름만큼이나 맛도 독특했던 두 가지 음료를 한 번... 요번에는 <b>스타벅스</b> 쿨서머캐모마일블렌디드에 기대를 걸어본다. 왜냐면 캐모마일 이름 붙은 건 대부분... ',
#   'bloggername': '먹기 위해 사는 위장 환자',
#   'bloggerlink': 'https://blog.naver.com/nowwegom',
#   'postdate': '20220728'},
#  {'title': '명동역 : <b>스타벅스</b> 별다방점 일회용 컵 없는 에코매장이용기',
#   'link': 'https://blog.naver.com/qptcjstk6?Redirect=Log&logNo=222803551256',
#   'description': '명동역 근처에 있는 <b>스타벅스</b> 별다방점! 얼마전에 남대문에 볼일 있어서 나갔다가, 예전부터 가보고 싶었던 <b>스타벅스</b> 별다방점! 명동역 근처에 있더라구요 : ) 여기에서만 파는 원두랑 카드가 궁금하기도하고... ',
#   'bloggername': 'Hello , 현정이 이야기',
#   'bloggerlink': 'https://blog.naver.com/qptcjstk6',
#   'postdate': '20220707'},
#  {'title': '120% K-패치 완료된 회사, <b>스타벅스</b> 코리아',
#   'link': 'https://blog.naver.com/superheavy?Redirect=Log&logNo=222834736544',
#   'description': '이케아, 맥도날드, <b>스타벅스</b> 등이 대표적인 예가 되겠다. 해외 생활을 할 때, 그리고 세계 여러 장소들을 유랑할 때 가장 많이 들렀던 장소 중 하나는 <b>스타벅스</b>였다. 언제나 생각하는 그런 맛을 먹을 수 있다는... ',
#   'bloggername': '날개in;Lifelog',
#   'bloggerlink': 'https://blog.naver.com/superheavy',
#   'postdate': '20220730'},
#  {'title': '제주 <b>스타벅스</b> 한정메뉴 md 리저브 매장까지.',
#   'link': 'https://blog.naver.com/queen77577?Redirect=Log&logNo=222835206833',
#   'description': '오늘은 제주 <b>스타벅스</b>에 다녀온 후기를 보여드리려고 합니다. 저는 평소에 스벅을 그다지 자주... 제주 <b>스타벅스</b> 리저브 매장 처음으로 방문한 곳은 신화 월드 지점입니다. 신화월드 랜딩관 지하 1층에... ',
#   'bloggername': '마녀씨의 힐링 스토리',
#   'bloggerlink': 'https://blog.naver.com/queen77577',
#   'postdate': '20220731'},
#  {'title': '<b>스타벅스</b> 리유저블 컵 쓰다 바꾼 이중 아이스컵',
#   'link': 'https://blog.naver.com/chaetle6?Redirect=Log&logNo=222832322790',
#   'description': '전회사에서 거의 2년 가깝게 쓰던 <b>스타벅스</b> 리유저블 컵~ 전회사가 여의도 <b>스타벅스</b> 건물이라서 항상 1층에서 개인컵을 썼었는데 이번에 이직한 회사는 커피머신이 있어서 커피값이 완전 굳어버림 그전에는 항상... ',
#   'bloggername': '뀨',
#   'bloggerlink': 'https://blog.naver.com/chaetle6',
#   'postdate': '20220728'},
#  {'title': '<b>스타벅스</b> 제주 청귤 라임 에이드 신메뉴 도전',
#   'link': 'https://blog.naver.com/ariel_0402?Redirect=Log&logNo=222829662154',
#   'description': '세상에 <b>스타벅스</b> 서머 프로모션 두 번째 음료가 나왔다!!! 다른 동네로 가봐야겠다 하며 버스에 몸을... 급 내려서 조금 걸었다 ㅎ_ㅎ 그리하여 항상 가던 매장 다시 방문 완료 * <b>스타벅스</b> 고양원흥DT점 자세한... ',
#   'bloggername': '알라미의 블로그',
#   'bloggerlink': 'https://blog.naver.com/ariel_0402',
#   'postdate': '20220726'},
#  {'title': 'coffee, 2022/ <b>스타벅스</b>&amp;폴바셋&amp;커피빈&amp;네스프레소 5-7월',
#   'link': 'https://blog.naver.com/tjsdlswkd303?Redirect=Log&logNo=222827867157',
#   'description': '#번트치즈케이크 <b>스타벅스</b>에선 왠만하면 케이크 종류는 안사려고하는데, 갑자기 치케가 고파서..급... #아이스유스베리로즈티브리즈 이 음료를 마지막으로 정말 <b>스타벅스</b> 신메뉴는 끊으련다. 충전해둔 카드... ',
#   'bloggername': 'TravEl rEciPe',
#   'bloggerlink': 'https://blog.naver.com/tjsdlswkd303',
#   'postdate': '20220730'},
#  {'title': '<b>스타벅스</b> 투고그린 쿨링백 구매, 내돈내산 솔직후기 : )',
#   'link': 'https://blog.naver.com/kmj1874?Redirect=Log&logNo=222836628486',
#   'description': '아 이건 안되겄다 ㅋㅋㅋㅋ 지혜랑 내꺼 하라는거구나 #<b>스타벅스</b>그린투고쿨링백가격 가격은 2.6이고요... 저랑 친구꺼 두개를 구입 했구요 #<b>스타벅스</b>할인카드 중에 만약 국민은행노리카드..(저는 펭수카드)가... ',
#   'bloggername': '쭌쮜로그 :)',
#   'bloggerlink': 'https://blog.naver.com/kmj1874',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 서머캐리백 포름알데히드 제거 후기',
#   'link': 'https://blog.naver.com/shane70?Redirect=Log&logNo=222829544868',
#   'description': '#<b>스타벅스</b> #캐리백 에 뿌리려고 준비한 #액상형 #알델리트 입니다. 1병 세트를 준비했습니다. 알델리트... 바꿔 먹을지는 모르겠습니다. 이제 장장 3일에 걸친 #<b>스타벅스</b> 늪에서 벗어날 수 있을 듯 합니다.',
#   'bloggername': '아직은 아냐^ ^ (달도시 블로그)',
#   'bloggerlink': 'https://blog.naver.com/shane70',
#   'postdate': '20220726'},
#  {'title': '2022 <b>스타벅스</b> 여름 MD 3차 스탠리 디자인이 괜찮네요',
#   'link': 'https://blog.naver.com/sunzooland?Redirect=Log&logNo=222829304099',
#   'description': "2022 <b>스타벅스</b> 여름 MD 3차 출시가 된다는 소식에 지난주였나? 온라인으로 미리 살펴보고는 '장바구니'에... 2022 <b>스타벅스</b> 여름 md 3차 제품들은 전반적으로 색이 괜찮은 듯싶어요. 노란색이 일부 있기는 하지만... ",
#   'bloggername': 'La Vie En Rose',
#   'bloggerlink': 'https://blog.naver.com/sunzooland',
#   'postdate': '20220726'},
#  {'title': '&lt;7_4 주간일기&gt; <b>스타벅스</b> 서머캐리백의 배신',
#   'link': 'https://blog.naver.com/pooh0512?Redirect=Log&logNo=222833604029',
#   'description': '뉴스는 <b>스타벅스</b>의 배신이 아닐까 싶다. 정말 화가난다. 나는 내 블로그를 통해서도 굉장히 스벅빠의 면모를 많이 보여줬다. 그만큼 아주 어릴때부터 <b>스타벅스</b>를 사랑했던 고객이다. 그리고 언제부터인가... ',
#   'bloggername': '시간의마법사',
#   'bloggerlink': 'https://blog.naver.com/pooh0512',
#   'postdate': '20220729'},
#  {'title': '파라스파라서울에서 토이뮤지엄과 <b>스타벅스</b>는 덤 !',
#   'link': 'https://blog.naver.com/thedalda?Redirect=Log&logNo=222837397258',
#   'description': '꽂아놓고 <b>스타벅스</b>에서 커피한잔 사고 올라오면 딱 이예요 :) 회전 교차로에서 돌면 두가지 길이... 집앞이라 자주 들리거든요 :) 충천 꽂아두고 나와서 아래로 내려가면 <b>스타벅스</b>가 있어요 :) 커피한잔 사러... ',
#   'bloggername': '엄디디의 슬기로운생활',
#   'bloggerlink': 'https://blog.naver.com/thedalda',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 신메뉴 우리 쑥 크림 푸라푸치노',
#   'link': 'https://blog.naver.com/talesoff?Redirect=Log&logNo=222833097291',
#   'description': '오랜만에 방문한 요새 말많고 탈많은 <b>스타벅스</b>. 팀장님이 쏘신다는 한마디에 뭔가 새로운 메뉴가 먹고싶어서 두리번 거리던 중에 신메뉴인 우리 쑥 크림 푸라푸치노 눈에 들어왔다. 참고로 평소에는 <b>스타벅스</b>에... ',
#   'bloggername': 'Balance',
#   'bloggerlink': 'https://blog.naver.com/talesoff',
#   'postdate': '20220728'},
#  {'title': '일본생활 - 부룬디 커피 / <b>스타벅스</b> / 키크론 k3 / 마하충전기... ',
#   'link': 'https://blog.naver.com/hcgoon?Redirect=Log&logNo=222836494522',
#   'description': '코끼리 코가 걸이역할을 하더군요.ㅎ <b>스타벅스</b>의 바나나 도너츠. 맛은 없었습니다… spigen 아이패드 케이스는 아주 만족스럽게 사용중입니다. 키보드 거의 정리하고 카페에서는 요 키크론 k3 만 사용하네요.... ',
#   'bloggername': 'Tokyo Life - 대고바 혹성 :: 요다의 일본생활기',
#   'bloggerlink': 'https://blog.naver.com/hcgoon',
#   'postdate': '20220801'},
#  {'title': '바질토마토크림치즈 베이글 샌드위치 만들기 :: <b>스타벅스</b>... ',
#   'link': 'https://blog.naver.com/missto5?Redirect=Log&logNo=222771484590',
#   'description': '마켓컬리/샌드위치만들기 바질토마토크림치즈 베이글 <b>스타벅스</b>에서 바질토마토크림치즈 베이글을... <b>스타벅스</b>는 올리브감자베이글을 사용해서 비슷한 제품으로 선택 먼저 반으로 잘라줍니다. 블랙 올리브가... ',
#   'bloggername': '쑤댕&apos;s 테이스트',
#   'bloggerlink': 'https://blog.naver.com/missto5',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 ↔ 음료 무료쿠폰으로 교환하기',
#   'link': 'https://blog.naver.com/wooes2?Redirect=Log&logNo=222832331285',
#   'description': '<b>스타벅스</b> 여름 프리퀀시 기간이 끝난지 얼마나 되었다고 전국 뉴스를 강타한 바로 그 소식 <b>스타벅스</b> 서머캐리백에 포름알데히드가..!? 영화 &lt;괴물&gt;에서나 보던 포름알데히드 아니냐고요ㅠㅠㅠㅠ 심지어... ',
#   'bloggername': '지니의 끄적끄적',
#   'bloggerlink': 'https://blog.naver.com/wooes2',
#   'postdate': '20220728'},
#  {'title': '<b>스타벅스</b> 제주청귤라임에이드/루벤 샌드위치',
#   'link': 'https://blog.naver.com/rira8989?Redirect=Log&logNo=222833754090',
#   'description': '이번주 화요일날 <b>스타벅스</b> 신메뉴가 나왔어요! 어떤걸 먹어볼까 고민하다가 이번 <b>스타벅스</b> 루벤 샌드위치도 궁금하고 제주청귤라임에이드도 비쥬얼이 예뻐 두가지를 먹어보기위해 방문했답니다 ㅎㅎ 이번... ',
#   'bloggername': '리라리:)언제나 변함없이',
#   'bloggerlink': 'https://blog.naver.com/rira8989',
#   'postdate': '20220729'},
#  {'title': '주간일기 9주차. 잠시 떠난 제주. <b>스타벅스</b> 리유저블 컵 반납',
#   'link': 'https://blog.naver.com/80milk?Redirect=Log&logNo=222838579520',
#   'description': '<b>스타벅스</b> 리유저블 컵 반납 첫째가 이제 고등 졸업 때까지는 공부에 집중하고 싶다고 멀리 나가고 싶어... 첫째는 제일 먹고 싶었던 게 <b>스타벅스</b> 메뉴 중 제주 only 제품인데요 너무너무 먹고 싶어 해서... ',
#   'bloggername': '따랑해의 엄마표 육아교육 감성놀이',
#   'bloggerlink': 'https://blog.naver.com/80milk',
#   'postdate': '20220803'},
#  {'title': '발리 초대형 <b>스타벅스</b>',
#   'link': 'https://blog.naver.com/wks0102?Redirect=Log&logNo=222838511480',
#   'description': '<b>스타벅스</b> 리저브 데와타 (Starbucks Reserve Dewata) 발리에서 꼭 방문해야 할 새로운 Instagram 명소가 생겼네요! 발리 리저브 데와따 <b>스타벅스</b>는 커피 농장을 보유한 동남아시아에서 가장 큰... ',
#   'bloggername': '발리 자유여행 가이드 프리스타일 발리',
#   'bloggerlink': 'https://blog.naver.com/wks0102',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 교환 보상 정보 (새 굿즈, 기프트카드... ',
#   'link': 'https://blog.naver.com/wkdgksk0605?Redirect=Log&logNo=222836024681',
#   'description': '안녕하세요 하나입니다:) 여러분 최근에 <b>스타벅스</b>에서 큰 문제가 생겼었죠.. 올해 5월부터 17잔을 마시고 프리퀀시를 모으면 서머 캐리백으로 교환해주는 이벤트를 진행했었는데요! <b>스타벅스</b>를 자주 이용하는... ',
#   'bloggername': '@hana__j',
#   'bloggerlink': 'https://blog.naver.com/wkdgksk0605',
#   'postdate': '20220801'},
#  {'title': '춘천 여행 구봉산 카페 거리 <b>스타벅스</b> 춘천구봉산R점 비오는... ',
#   'link': 'https://blog.naver.com/poke82?Redirect=Log&logNo=222838134630',
#   'description': '평소 <b>스타벅스</b>에 잘 방문하지 않는 남편, 그런데 여기저기서 쿠폰 받아 놓은 게 많다고 해서 쿠폰을 사용할 겸 저희는 춘천 구봉산 카페거리에 <b>스타벅스</b> 춘천 구봉산R점으로 향했어요. 춘천 구봉산 전망대... ',
#   'bloggername': '오늘도행복주워담기',
#   'bloggerlink': 'https://blog.naver.com/poke82',
#   'postdate': '20220803'},
#  {'title': '산본 맛집 이차돌에서 차돌박이 뿌시기 / <b>스타벅스</b> 피지오로... ',
#   'link': 'https://blog.naver.com/mgamp?Redirect=Log&logNo=222822746533',
#   'description': '이렇게 차돌박이 뿌순 다음에는 소화 좀 시킬겸 <b>스타벅스</b> 가서 피지오를 마셨어요. 저는 항상 마시는 쿨라임 피지오로 마셨어요! 고기 먹은 다음에는 탄산을 꼭 마셔줘야 되는 것 같아요. 쿨라임 피지오 정말... ',
#   'bloggername': 'i like hm',
#   'bloggerlink': 'https://blog.naver.com/mgamp',
#   'postdate': '20220721'},
#  {'title': '담아서 먹는다 (메리어트조식, 신화월드<b>스타벅스</b>, 대한항공)',
#   'link': 'https://blog.naver.com/working_sh?Redirect=Log&logNo=222837151403',
#   'description': '느낌이 있긴 했는데 그래도 푸짐하게 맛있게 먹었습니다 제주 신화월드 <b>스타벅스</b> 리저브 오픈 시간 맞춰서 커피 수령하러 간 제주 신화월드 <b>스타벅스</b>(리저브) 사람 없을 때 살짝 찍었는데 진짜 줄서서... ',
#   'bloggername': '수짱의 여행과 일상 이야기',
#   'bloggerlink': 'https://blog.naver.com/working_sh',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 다른 프리퀀시 상품은 괜찮을까?',
#   'link': 'https://blog.naver.com/shane70?Redirect=Log&logNo=222824161577',
#   'description': '갑자기 어제부터 제가 쓴 #<b>스타벅스</b> #서머캐리백 #썸머캐리백 에 대한 블로그 글을 보시는 분들이 폭증하였습니다. https://blog.naver.com/shane70/222793317101 #발암물질 이자 #독성물질 인 #포름알데히드 가... ',
#   'bloggername': '아직은 아냐^ ^ (달도시 블로그)',
#   'bloggerlink': 'https://blog.naver.com/shane70',
#   'postdate': '20220722'},
#  {'title': '<b>스타벅스</b> 미아점 여름메뉴',
#   'link': 'https://blog.naver.com/mistyb74?Redirect=Log&logNo=222820856772',
#   'description': '쓰러 <b>스타벅스</b> 고고. 어디로 갈까하다 걍 직장근처 미아점으로 외관샷 실내샷 점심때 갔더니 사람이 사람이;;; 자리 1도 없음 ㅋㅋ 뭐 이런 분위기입니당. 손님이 많아서 천장이랑 벽만 찍고 옴 <b>스타벅스</b> md 여름... ',
#   'bloggername': '기둥언니의 놀고,먹고,떠나고',
#   'bloggerlink': 'https://blog.naver.com/mistyb74',
#   'postdate': '20220720'},
#  {'title': '2022년 <b>스타벅스</b> 여름 md및 음료 신메뉴 리뷰',
#   'link': 'https://blog.naver.com/minsyungtm?Redirect=Log&logNo=222829998021',
#   'description': '안녕하세요:) 쏭유예요~ <b>스타벅스</b> 여름 md가 나왔다는 소리를 듣고 추가로 신메뉴도 나왔다고 해서~ 오랜만에 출근전에 10분이 남아서 회사 출근길에~ <b>스타벅스</b>에 신메뉴를 먹으러 왔어요~ 저는 제주 청귤... ',
#   'bloggername': '£¤¥€ ~° 사랑했수민~°',
#   'bloggerlink': 'https://blog.naver.com/minsyungtm',
#   'postdate': '20220726'},
#  {'title': '<b>스타벅스</b> 서머 캐리백을 음료쿠폰으로 교환',
#   'link': 'https://blog.naver.com/hungry5253?Redirect=Log&logNo=222837166854',
#   'description': '<b>스타벅스</b>코리아가 여름 프리퀀시 이벤트로 진행했던 제품중 서머캐리백에서 발암물질 폼알데하이드가 검출된 시험성적서를 제출하며 공식사과를 발표했네요. 참…흠…ㅜㅜ @<b>스타벅스</b>코리아 홈페이지... ',
#   'bloggername': '.....연인비의 소소한 이야기....',
#   'bloggerlink': 'https://blog.naver.com/hungry5253',
#   'postdate': '20220802'},
#  {'title': '반포 한강공원 아침 산책 <b>스타벅스</b> 한강뷰카페',
#   'link': 'https://blog.naver.com/himerosyo?Redirect=Log&logNo=222833573492',
#   'description': '#반포 #잠원 #한강공원 #<b>스타벅스</b> #아침산책 #한강뷰카페 이틀밖에 안됐지만 요새 아침에 일어나면... 있는 <b>스타벅스</b> 한강위에 그림처럼 둥둥 떠있음 다리 건너서 <b>스타벅스</b>로 들어옴 <b>스타벅스</b> 좋아하진 않는데... ',
#   'bloggername': '약&락life',
#   'bloggerlink': 'https://blog.naver.com/himerosyo',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> e카드 교환권 등록 / 해지하는 방법',
#   'link': 'https://blog.naver.com/bloomingjeju?Redirect=Log&logNo=222828652260',
#   'description': '얼마전 생일때 아가씨에게 <b>스타벅스</b> e카드 교환권을 선물 받았어요 시골이지만 옆마을 함덕에는 <b>스타벅스</b>가 있기에 유용한 교환권 하지만 <b>스타벅스</b>를 자주 이용하지않다보니 어플도 없고 e카드 교환권을... ',
#   'bloggername': '연이네다락방 여행같은 제주 일상기록장',
#   'bloggerlink': 'https://blog.naver.com/bloomingjeju',
#   'postdate': '20220725'},
#  {'title': '<b>스타벅스</b> 2022 써머 실리콘 컨테이너 실물 후기',
#   'link': 'https://blog.naver.com/p0pp0?Redirect=Log&logNo=222833140564',
#   'description': '2022년의 마지막 <b>스타벅스</b> 써머 MD 상품이 될 것 같다! 일단 스벅 어플에서 커밍순 예고편을 보고 바아로~ 요 실리콘 반찬통 ㅎㅎ 이 눈에 쏙 들어왔는데 출시일에 맞춰 회사 근처 <b>스타벅스</b>에 가보니 역시나... ',
#   'bloggername': '햄토링 데이로그 ♩',
#   'bloggerlink': 'https://blog.naver.com/p0pp0',
#   'postdate': '20220728'},
#  {'title': '<b>스타벅스</b> 캐리백 발암물질 검출 무료 음료 쿠폰 교환☆',
#   'link': 'https://blog.naver.com/smr1029?Redirect=Log&logNo=222833106067',
#   'description': '#<b>스타벅스</b> #<b>스타벅스</b>캐리백 #<b>스타벅스</b>발암물질 #<b>스타벅스</b>캐리백발암물질 #<b>스타벅스</b>캐리백교환 요즘 이슈가 되고 있는 <b>스타벅스</b> 캐리백 발암물질 검출 저도 이번에 프리퀀시 다 채워서 캐리백2개 매장에서... ',
#   'bloggername': '♥ 미란 ♥',
#   'bloggerlink': 'https://blog.naver.com/smr1029',
#   'postdate': '20220728'},
#  {'title': '<b>스타벅스</b> 미디엄 로스트 아메리카노/  커피글라스 받으려고... ',
#   'link': 'https://blog.naver.com/ciel82321?Redirect=Log&logNo=222838857532',
#   'description': '기웃거리다 #<b>스타벅스</b>미디엄로스트아메리카노 여름한정 글라스 증정 상품을 보게 되었다. 나도 유리잔에 기분내며 커피를 마시고 싶어서 두개나 구매를 했다. #<b>스타벅스</b>미디엄로스트 현재는 쓱닷컴 사이트에... ',
#   'bloggername': '지구별여행자',
#   'bloggerlink': 'https://blog.naver.com/ciel82321',
#   'postdate': '20220803'},
#  {'title': '주말에 공부하기 좋은 카페 <b>스타벅스</b> 독산역점',
#   'link': 'https://blog.naver.com/ifp1592?Redirect=Log&logNo=222838497236',
#   'description': '그래서 <b>스타벅스</b>가 인기가 높습니다 .<b>스타벅스</b> 커피가 솔직히 맛은 없습니다. 탄 커피의 대명사잖아요. 다만 라떼 같이 커피에 우유 첨가하는 커피는 맛이 그런대로 좋고 스벅도 라떼류를 밀고 있습니다. 무료... ',
#   'bloggername': '여기영화IT수다',
#   'bloggerlink': 'https://blog.naver.com/ifp1592',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 메뉴 후기 : 제주 청귤 라임에이드 (MD)',
#   'link': 'https://blog.naver.com/daesuk217?Redirect=Log&logNo=222831163541',
#   'description': '<b>스타벅스</b> 메뉴 후기 제주 청귤 라임에이드 쑥 먹고 다른 스벅가서 청귤을 먹어보았습니다. 다들... <b>스타벅스</b> 대치사거리점 : 기본정보  위치 : 서울 강남구 삼성로 402 (삼성역 4번 출구에서 942m) ☎️ 번호... ',
#   'bloggername': '블루진의 기적노트',
#   'bloggerlink': 'https://blog.naver.com/daesuk217',
#   'postdate': '20220727'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 교환 - 무료쿠폰 3장',
#   'link': 'https://blog.naver.com/chasunghan?Redirect=Log&logNo=222831564723',
#   'description': '<b>스타벅스</b> 서머 캐리백 고객 사과문 요약 (2022.7.28) &lt;서머 캐리백 폼알데하이드 검출 시험 결과&gt; - 개봉... 기대하시는 <b>스타벅스</b> 제품의 품질 기준에는 부합하지 않았기에 이 점 다시 한번 진심으로 송구하게... ',
#   'bloggername': '소소한 일상',
#   'bloggerlink': 'https://blog.naver.com/chasunghan',
#   'postdate': '20220727'},
#  {'title': '[<b>스타벅스</b> 서머 캐리백 음료교환권]',
#   'link': 'https://blog.naver.com/sally_86?Redirect=Log&logNo=222830993641',
#   'description': '일단 우려가 있기 때문에 <b>스타벅스</b>에서는 음료교환권 3장을 준다고 하더라구요. 최근에 분가 이후... #<b>스타벅스</b>서머캐리백교환#<b>스타벅스</b>발암물질 #<b>스타벅스</b>폼알데하이드#<b>스타벅스</b>땡큐쿠폰',
#   'bloggername': 'sally home & life',
#   'bloggerlink': 'https://blog.naver.com/sally_86',
#   'postdate': '20220727'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 사태와 <b>스타벅스</b> 여름 아이템들',
#   'link': 'https://blog.naver.com/pigstudy?Redirect=Log&logNo=222825510566',
#   'description': '갖은 쿠폰을 소진하다가 얻게 된(?) <b>스타벅스</b> 서머 캐리백. 이렇게 접어서 쓰는 여름용 가방이다. 올해... <b>스타벅스</b>의 대처는 이렇다. 그야말로 귀추가 주목된다. 새삼 안내문을 잘 읽어본 후, 서머 캐리백은... ',
#   'bloggername': '글이 빛나는 밤에',
#   'bloggerlink': 'https://blog.naver.com/pigstudy',
#   'postdate': '20220723'},
#  {'title': '여행 셋째날 고바우설렁탕&amp;양평<b>스타벅스</b>',
#   'link': 'https://blog.naver.com/skeunhea1?Redirect=Log&logNo=222834152711',
#   'description': '밥을먹고 후식이 빠질순 없겠죠ㅋ 어디갈까 하다 <b>스타벅스</b>에 갔답니다~~ #고바우설렁탕 #양평설렁탕맛집 #양평맛집 #양평설렁탕 양평 <b>스타벅스</b>dt 유명한 곳이죠ㅋ #<b>스타벅스</b>양평 #양평dt #양평커피숍... ',
#   'bloggername': '메이의 일상',
#   'bloggerlink': 'https://blog.naver.com/skeunhea1',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 여름MD 2차 - 22 바다거북 머그 355ml',
#   'link': 'https://blog.naver.com/rikuming?Redirect=Log&logNo=222829610461',
#   'description': '요즘 <b>스타벅스</b>에 관심이 하락하고 있었는데, 우연히 보게 된 <b>스타벅스</b> 여름 MD 2차를 보고 완전 뿅 가버렸다. 뭐냐면 거북이 머그가 등장한다는 사진!!! 오른쪽 하단에 너무 귀엽게 있는 거북이 발견.... 하... ',
#   'bloggername': '끄적끄적리쿠밍 ♪',
#   'bloggerlink': 'https://blog.naver.com/rikuming',
#   'postdate': '20220726'},
#  {'title': '2022 <b>스타벅스</b> 서머 캐리백 반품 &amp; 땡큐쿠폰 교환 후기',
#   'link': 'https://blog.naver.com/ringo90?Redirect=Log&logNo=222836493928',
#   'description': '그리고 오늘도 댈님 동행하에 운전연수 받으면서 <b>스타벅스</b>로 향했다 주위산만한 날위해 댈님이 맨날 긴장타셔서 그저 죄송했음... <b>스타벅스</b> 방문해서 캐리백 내니까 묻지도 따지지도 않고 바로 떙큐 쿠폰... ',
#   'bloggername': '바깥순이의 요양블로그(feat.종이인형)',
#   'bloggerlink': 'https://blog.naver.com/ringo90',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 창원NC파크R점 - 야구장 <b>스타벅스</b> 리저브 메뉴&amp;후기',
#   'link': 'https://blog.naver.com/yswh4123?Redirect=Log&logNo=222836978391',
#   'description': '<b>스타벅스</b> 창원NC파크R점 #<b>스타벅스</b> #창원NC파크 #창원<b>스타벅스</b> #NC파크<b>스타벅스</b> #<b>스타벅스</b>리저브메뉴 #야구장<b>스타벅스</b> #창원<b>스타벅스</b>리저브 #야구장스벅 #이색<b>스타벅스</b> #<b>스타벅스</b>창원NC파크R점 #NC<b>스타벅스</b> 글... ',
#   'bloggername': '라봉이와 순간의 기록♥️',
#   'bloggerlink': 'https://blog.naver.com/yswh4123',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 서머캐리백 땡큐쿠폰으로 교환(보상교환)',
#   'link': 'https://blog.naver.com/kwljk?Redirect=Log&logNo=222834384901',
#   'description': '요즘 연일 뉴스에서 <b>스타벅스</b> 프리퀀시로 받은 서머 캐리백때문에 말이 많죠~저도 보고 듣고 있었는데....저는 지난 번 포스팅 했던 것 처럼 <b>스타벅스</b> 서머캐리백 크림과 파우치 핑크 2개를 받았었는데요... 일단... ',
#   'bloggername': 'Lies only lead to more lies',
#   'bloggerlink': 'https://blog.naver.com/kwljk',
#   'postdate': '20220730'},
#  {'title': '롯데카드 마이데이터 이벤트 <b>스타벅스</b>2잔+엘포인트',
#   'link': 'https://blog.naver.com/xuenxu?Redirect=Log&logNo=222771187168',
#   'description': '1,2번은 <b>스타벅스</b> 기프티콘 바로 지급. 3~4번은 엘포인트를 100~1,000점 랜덤 지급해준데요. 4가지 모두 했더니... 혜택 1번에서 엘포인트 3000점 미션 1,2번에서 <b>스타벅스</b> 기프티콘 2매 (기프티콘이 따로 문자로... ',
#   'bloggername': '재테크의 여왕 슈엔슈',
#   'bloggerlink': 'https://blog.naver.com/xuenxu',
#   'postdate': '20220613'},
#  {'title': '<b>스타벅스</b> 채용 폐업소상공인 리스타트프로그램 참여해요',
#   'link': 'https://blog.naver.com/surfinian?Redirect=Log&logNo=222811966350',
#   'description': '<b>스타벅스</b> 리스타트 교육생모집 희망리턴패키지의 전직특화교육중 하나인 <b>스타벅스</b> 리스타트프로그램은 카페에 취업을 희망하는 폐업소상공인과 배우자을 대상으로 1년에 총 4회 실시되고 있는데요.... ',
#   'bloggername': '카페집사의 블로그',
#   'bloggerlink': 'https://blog.naver.com/surfinian',
#   'postdate': '20220715'},
#  {'title': '대전 신세계 5층 <b>스타벅스</b> 리저브',
#   'link': 'https://blog.naver.com/kidart01?Redirect=Log&logNo=222818831320',
#   'description': '5층 <b>스타벅스</b> 리저브 매장에 방문했어요~~ 신세계 백화점도 시원한데 <b>스타벅스</b> 리저브 매장은 추울 정도였어요 ㅋㅋ 피서하기 최적의 장소!! 대전 유성구 도룡동 신세계 백화점에 저녁에는 산책도 하고 마감 할인... ',
#   'bloggername': '신기루',
#   'bloggerlink': 'https://blog.naver.com/kidart01',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 더블 에스프레소칩 프라푸치노',
#   'link': 'https://blog.naver.com/tlrevolution?Redirect=Log&logNo=222829374218',
#   'description': '별 12개 적립 무료음료 쿠폰 사용을 위해서 방문한 <b>스타벅스</b>.. 결국엔 이번에도 별쿠폰 유효기간 마지막 날에 방문하게 되었네요.. STARBUCKS.. BUKGAJWA DRIVE THRU.. <b>스타벅스</b> 북가좌DT점을 찾았네요.. FIND YOUR... ',
#   'bloggername': '타미스다이너',
#   'bloggerlink': 'https://blog.naver.com/tlrevolution',
#   'postdate': '20220728'},
#  {'title': '일본 <b>스타벅스</b>, 여름 이벤트 사전공개',
#   'link': 'https://esendial.tistory.com/9177',
#   'description': '일본 <b>스타벅스</b> 메일링은 꾸준하게 받아서 봤지만, 올리는 건 오랜만입니다. 이번에는 신작 프라푸치노... 말장난인거죠.-ㅠ- 복숭아 알레르기가 있다면 <b>스타벅스</b> 근처에도 가고 싶지 않을 메뉴지만... ',
#   'bloggername': 'Cafe Esendial - 3 :: Cafe Esendial - 3',
#   'bloggerlink': 'https://esendial.tistory.com/',
#   'postdate': '20220706'},
#  {'title': '영양제 후기 쓰고 <b>스타벅스</b> 기프티콘 받는 법) ♥',
#   'link': 'https://blog.naver.com/soje1234?Redirect=Log&logNo=222834808013',
#   'description': '마침 영양제 리뷰를 쓰기만 하면 <b>스타벅스</b> 기프티콘을 100% 증정하는 이벤트가 지금 바로 진행되고 있드라구 ◡̈  내가 먹어본 영양제 리뷰 5개 이상만 쓰면 되고 베스트 리뷰어 10명에게는 신세계상품권까지... ',
#   'bloggername': '민속학도의 시선으로 담은 기록보관소',
#   'bloggerlink': 'https://blog.naver.com/soje1234',
#   'postdate': '20220730'},
#  {'title': '[<b>스타벅스</b>] 캐리백 논란 <b>스타벅스</b>, 서비스 만족도 ‘평균 이하’',
#   'link': 'https://blog.naver.com/akdlf7369?Redirect=Log&logNo=222837867116',
#   'description': '(2022.08.01) -상위 7개 커피전문점 가격 및 서비스 만족도 평균치 3.66점…<b>스타벅스</b>는 3.51점 ‘꼴등’ -종합만족도에선 <b>스타벅스</b>가 1위 차지…<b>스타벅스</b> 3.99점, 커피빈 3.93점, 할리스 3.92점 ▲ <b>스타벅스</b>... ',
#   'bloggername': '작품과 현실',
#   'bloggerlink': 'https://blog.naver.com/akdlf7369',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 쑥크림 프라푸치노 with 콜드브루 가격, 칼로리, 맛... ',
#   'link': 'https://blog.naver.com/dalgam89?Redirect=Log&logNo=222836281221',
#   'description': '제주지역 <b>스타벅스</b>에서 한정 판매하던 우리 쑥크림프라푸치노 with 콜드브루 이번 여름 시즌음료로... 그래도 이게 기존 <b>스타벅스</b> 프라푸치노 제품군보다 당류가 적은 편이에요. 실제로 프라푸치노 치고... ',
#   'bloggername': '달감나무',
#   'bloggerlink': 'https://blog.naver.com/dalgam89',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 서머 캐리백_논란의 증정품 땡큐 쿠폰(전사이즈) 3장... ',
#   'link': 'https://blog.naver.com/mylittlebb?Redirect=Log&logNo=222837976396',
#   'description': '이번 <b>스타벅스</b> 여름 프리퀀시 캐리백은 진짜 마음에 쏙 드는 아이였는데, 발암물질인 폼알데히드가... 없었음 <b>스타벅스</b> 앱으로 내용을 확인하고 물건을 들고 인근 포포인츠 <b>스타벅스</b>로 향함 한번도 사용하지... ',
#   'bloggername': 'My Little B',
#   'bloggerlink': 'https://blog.naver.com/mylittlebb',
#   'postdate': '20220803'},
#  {'title': '[<b>스타벅스</b>] 콜드컵 SIP리드 473/591/710ml (콜드컵 리드 교체)',
#   'link': 'https://blog.naver.com/omini82?Redirect=Log&logNo=222836312973',
#   'description': '<b>스타벅스</b> 네이버 스토어에 가면 <b>스타벅스</b> 텀블러 리드를 따로 구매할 수 있는데요 710 벤티 사이즈 콜드컵 리드도 나왔더라구요!! 맨날 구멍뚫려있어서 가지구 다니기 애매한 콜드컵인데 밀폐는 안되더라도... ',
#   'bloggername': '★오미니 블로그★ - 덕후의 취미생활',
#   'bloggerlink': 'https://blog.naver.com/omini82',
#   'postdate': '20220801'},
#  {'title': '인천공항T2 입국장 <b>스타벅스</b> 위치',
#   'link': 'https://blog.naver.com/heyloveyou19?Redirect=Log&logNo=222831103633',
#   'description': '인천공항 제2터미널 입국장 <b>스타벅스</b>는 1층 입국장 A번 출구있는 쪽!! 서편에 위치해있다. 출국장 <b>스타벅스</b>는 3층 동편에 위치해 있어 자주 간다 호호 코로나 기간에도 항상 열려있었던 인천공항 제2터미널... ',
#   'bloggername': 'Hace Mosaic World 3.3',
#   'bloggerlink': 'https://blog.naver.com/heyloveyou19',
#   'postdate': '20220727'},
#  {'title': '<b>스타벅스</b> 퍼스널옵션 쿠폰사용하기 1+1 조으다',
#   'link': 'https://blog.naver.com/amj5356?Redirect=Log&logNo=222821286540',
#   'description': '있던 <b>스타벅스</b> 퍼스널옵션 쿠폰을 사용해봅니다 <b>스타벅스</b> 다이어리에 들어 있는 쿠폰중 마지막 쿠폰이예요 두장은 오후, 오전 시간 맞춰 쓰는쿠폰 이었고 퍼스널 쿠폰은 ? 인터넷 검색해보니 제조음료중 내... ',
#   'bloggername': '왕뽈따구',
#   'bloggerlink': 'https://blog.naver.com/amj5356',
#   'postdate': '20220720'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 음료교환 및 추후 굿즈? 리워드? 선택',
#   'link': 'https://blog.naver.com/tjmh82?Redirect=Log&logNo=222837357597',
#   'description': '그러다 오늘 아침 힘들게 받았던 <b>스타벅스</b> 서머 캐리백을 다시 꺼냈어요. 이거 맘에 들었는데 ㅠㅠ 포름알데히드 수령점아니더라도 가까운 <b>스타벅스</b> 매장 가면 되요. 안쪽에 황금보자기 색이 맘에 들었었는데.... ',
#   'bloggername': '오늘도 초보사장',
#   'bloggerlink': 'https://blog.naver.com/tjmh82',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 고객사과문 2022 여름 프리퀀시 서머캐리백 관련',
#   'link': 'https://blog.naver.com/sounder2?Redirect=Log&logNo=222833390203',
#   'description': '<b>스타벅스</b> 고객사과문 2022 여름 프리퀀시 서머캐리백 관련 내용입니다. <b>스타벅스</b> 어플에 들어갔더니 고객사과문이 바로 나오더군요. 그동안 사람들이 <b>스타벅스</b>를 믿고 프리퀀시를 위해서 음료도 많이... ',
#   'bloggername': 'sounder&apos;s Brick & Brick',
#   'bloggerlink': 'https://blog.naver.com/sounder2',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 병음료 주스 추천, 핑크 용과 레모네이드(가격)',
#   'link': 'https://blog.naver.com/mitsru79?Redirect=Log&logNo=222835761497',
#   'description': '여긴 홍대입구역 8번출구로 나오자마자 바로 코 앞에 있는 <b>스타벅스</b>! 사람이 늘 붐비는 <b>스타벅스</b>지요. 홍대 KFC앞과 더불어서 최고의 만남의 장소랄까요 ㅎ 사용기한이 며칠 안남은 <b>스타벅스</b> 기프티콘 쓰려고... ',
#   'bloggername': '미쯔루의 맛있는 이야기',
#   'bloggerlink': 'https://blog.naver.com/mitsru79',
#   'postdate': '20220731'},
#  {'title': '2022 <b>스타벅스</b> 여름 md SUMMER 2 프로모션 엠디 출시',
#   'link': 'https://blog.naver.com/ameliepink?Redirect=Log&logNo=222828269619',
#   'description': '<b>스타벅스</b> SUMMER 2 7월 26일 #<b>스타벅스</b>엠디출시 #SUNNER2프로모션MD #여름엠디 다 나왔는데 또 나옴? 하긴..아직 여름이구나.. 그럼 이건 3차가 아닌거야? 아 헷갈려.. 4월, 6월 여름 엠디가 나왔고.. 이건 또 나오네... ',
#   'bloggername': '핑크빛 가득한 아멜리에',
#   'bloggerlink': 'https://blog.naver.com/ameliepink',
#   'postdate': '20220725'},
#  {'title': '<b>스타벅스</b> 캐리백 쿠폰 교환 후기',
#   'link': 'https://blog.naver.com/freshtomato?Redirect=Log&logNo=222833826804',
#   'description': '되고, <b>스타벅스</b>앱에 옮겨서 사용하셔도 되는데 쿠폰 등록 <b>스타벅스</b> 앱 방법 1. 앱 첫화면 윗쪽에 Coupon 을 클릭 2. 쿠폰 화면에서 오른쪽 상담의 + 표시 클릭 3. 쿠폰등록창으로 넘어가는데 여긴 보안이 걸려서... ',
#   'bloggername': '수봉리로스터스',
#   'bloggerlink': 'https://blog.naver.com/freshtomato',
#   'postdate': '20220729'},
#  {'title': '경리단길 <b>스타벅스</b> 오픈! 텀블러 세척기',
#   'link': 'https://blog.naver.com/marykayqueen?Redirect=Log&logNo=222833050127',
#   'description': '친정이 있는 동네라 자주 방문하는데 드디어 이곳에도 <b>스타벅스</b> 매장이 오픈했어요 <b>스타벅스</b> 경리단길점 영업시간 08:00-22:00 토,일 08:00-21:00 * 주차 불가능 <b>스타벅스</b> 경리단길점 이태원 녹사평역에서 하얏트... ',
#   'bloggername': '우리의 하루',
#   'bloggerlink': 'https://blog.naver.com/marykayqueen',
#   'postdate': '20220728'},
#  {'title': '춘천 카페 <b>스타벅스</b> 춘천구봉산R점 특별한 메뉴가득',
#   'link': 'https://blog.naver.com/sin0788?Redirect=Log&logNo=222830834579',
#   'description': '춘천카페추천 <b>스타벅스</b> 춘천구봉산 R점 <b>스타벅스</b>리저브지점 춘천IC 근처에 학곡리 닭갈비를 먹고 가까운 구봉산카페거리의 <b>스타벅스</b>로 커피 마시러 갔어요! 예전에 방문했을 때 뷰가 너무 시원시원해서 다시... ',
#   'bloggername': 'Happily Ever After',
#   'bloggerlink': 'https://blog.naver.com/sin0788',
#   'postdate': '20220727'},
#  {'title': '<b>스타벅스</b> 신메뉴 우리쑥크림프라푸치노',
#   'link': 'https://blog.naver.com/lalad?Redirect=Log&logNo=222831744466',
#   'description': '<b>스타벅스</b> 신메뉴 우리쑥크림프라푸치노 #우리쑥크림프라푸치노 #스벅신메뉴 #쑥프라푸치노 #스벅프라푸치노 #캐모마일티 내가 좋아하는 쑥! 이번에 스벅 신메뉴로 쑥프라푸치노가 나왔다. 갈산역 근처에... ',
#   'bloggername': '릴리랄라 행복한 일상❤ 미식×인테리어',
#   'bloggerlink': 'https://blog.naver.com/lalad',
#   'postdate': '20220727'},
#  {'title': '<b>스타벅스</b> 추천 메뉴 : 햄&amp;루꼴라 올리브 샌드위치',
#   'link': 'https://blog.naver.com/pbk890515?Redirect=Log&logNo=222834535677',
#   'description': '<b>스타벅스</b> 대구중동네거리DT점으로 향했어요 이미 많은 차들이 주차장에 있구요 이미 샌드위치를... 최근 <b>스타벅스</b> 샌드위치 부실논란이 있어서 다들 속을 궁금해 하실 것 같아서 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ... ',
#   'bloggername': '책읽어 주는 남자 빠피용',
#   'bloggerlink': 'https://blog.naver.com/pbk890515',
#   'postdate': '20220801'},
#  {'title': '<b>스타벅스</b> 바닐라크림 콜드브루 깔끔한 단맛!',
#   'link': 'https://blog.naver.com/maize210?Redirect=Log&logNo=222821312221',
#   'description': '정말 오랜만에 <b>스타벅스</b> 바닐라크림 콜드브루를 마셨어요! 근데 오랜만에 마셔서 그런지 아니면... ㅋㅋㅋ 근데 오늘 마신 <b>스타벅스</b> 바닐라크림 콜드브루는 진한 단맛도 나고 커피맛도 넘 맛있어서 또 새삼... ',
#   'bloggername': '살구블라썸',
#   'bloggerlink': 'https://blog.naver.com/maize210',
#   'postdate': '20220721'},
#  {'title': '청라 <b>스타벅스</b> // 청라 한신더휴커낼웨이에서',
#   'link': 'https://blog.naver.com/bwjun4?Redirect=Log&logNo=222836202783',
#   'description': '청라 <b>스타벅스</b> // 청라 한신더휴커낼웨이에서 &quot;청라 한신더휴에 <b>스타벅스</b>가 새로이 문을 열었다하여, 청라 홈플러스와 주변 들리는 김에 한번 가 보았습니다.&quot; &quot;<b>스타벅스</b> 인천청라한신점&quot;은 (청라... ',
#   'bloggername': '"만세 블로그" 방문하신 분들, 행운과 함께 하시길~',
#   'bloggerlink': 'https://blog.naver.com/bwjun4',
#   'postdate': '20220801'},
#  {'title': '#<b>스타벅스</b> 여름 신메뉴_제주 청귤 라임 에이드(칼로리, 후기)',
#   'link': 'https://blog.naver.com/euirime?Redirect=Log&logNo=222838694240',
#   'description': '<b>스타벅스</b> 여름 신메뉴 제주 청귤 라임 에이드(칼로리, 후기) 안녕하세욧!! 목요일을 바라보고 있는... 요즘 헤이해져서 <b>스타벅스</b> 신메뉴를 잘 안마시고 있는데 요렇게 상콤한 음료를 주셨지 뭐예요..!... ',
#   'bloggername': 'Have a kiho’ day.',
#   'bloggerlink': 'https://blog.naver.com/euirime',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 로고 디폼블럭 만들기',
#   'link': 'https://blog.naver.com/kangho1999?Redirect=Log&logNo=222834114623',
#   'description': '<b>스타벅스</b> 로고 그 인어공주같은 그 로고 디폼블럭 도전한다. 디폼블럭으로 아이가 여러가지 도안으로... 근데 이 <b>스타벅스</b>로고 디폼블럭은 엄청 크다. 대충봐도 큰데..어디 쓸때가 있을지 모르겠지만 도전해본다.... ',
#   'bloggername': 'ID:workerant',
#   'bloggerlink': 'https://blog.naver.com/kangho1999',
#   'postdate': '20220729'},
#  {'title': '[日常] <b>스타벅스</b> 요즘 뭐하는 거지? 도우스루 <b>스타벅스</b>...?',
#   'link': 'https://blog.naver.com/jazzmate?Redirect=Log&logNo=222828459540',
#   'description': '주도 #<b>스타벅스</b> #주간일기 이번 #서머프리퀀시 증정품 받은거 정리해 놓고 대강 어디에 어떻게 써야겠다 생각중이었는데 두둥~!! #서머캐리백 에서 #폼알데하이드 가 나왔다는 제보~ <b>스타벅스</b>에서는 며칠 전 공지... ',
#   'bloggername': '14P 와가마마 레코멘',
#   'bloggerlink': 'https://blog.naver.com/jazzmate',
#   'postdate': '20220725'},
#  {'title': '나의 최애 커피 : <b>스타벅스</b> 카페라떼320ml 찾아라!찾았다!',
#   'link': 'https://blog.naver.com/4086088?Redirect=Log&logNo=222835881852',
#   'description': '나의 최애 커피 <b>스타벅스</b> 카페라떼320ml 찾아라! 찾았다! 2021년에 그려왔던 나의 그림일기를 보면 나와 마루바닥 말고 꾸준하게 그려지는 것이 하나 있어요. 바로 <b>스타벅스</b> 카페라떼! 구 슈퍼집 딸래미, 현... ',
#   'bloggername': '니야니야 나니야',
#   'bloggerlink': 'https://blog.naver.com/4086088',
#   'postdate': '20220731'},
#  {'title': '[<b>스타벅스</b>]블루베리 쏙 수플레 치즈케이크, 제주 청귤 라임... ',
#   'link': 'https://blog.naver.com/angela_402?Redirect=Log&logNo=222834791583',
#   'description': '#안녕하세요젤라예요 #내돈내산 #<b>스타벅스</b> #블루베리쏙수플레치즈케이크 나는야 치즈케이크 덕후! 케이크중에 치즈케이크가 젤~루 좋다 엄마랑 스벅 데이트 하면서 이번 <b>스타벅스</b> 신메뉴인 블루베리 쏙... ',
#   'bloggername': '안녕하세요 젤라예요',
#   'bloggerlink': 'https://blog.naver.com/angela_402',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 애플망고 코코넛 내돈내산 후기',
#   'link': 'https://blog.naver.com/skfoalsxm?Redirect=Log&logNo=222832585040',
#   'description': '<b>스타벅스</b>에 갔는데 신메뉴가 보이길래 호기롭게 먹어보았다. 이름은 애플망고코코넛! 가격은 4,300원... nooooo <b>스타벅스</b> 오면 원래 드시던 음료 드세요… 코코넛 향 사랑 + 시고 상큼한 맛 선호+ 도전 정신 있는... ',
#   'bloggername': '잘 먹고 잘 살기의 기록',
#   'bloggerlink': 'https://blog.naver.com/skfoalsxm',
#   'postdate': '20220728'},
#  {'title': '[음료] <b>스타벅스</b> 여름한정음료 제주청귤라임에이드 마셔봤어요.',
#   'link': 'https://blog.naver.com/danjy12?Redirect=Log&logNo=222838299262',
#   'description': '이래저래 말많고 탈많은 <b>스타벅스</b>... 갈수록 문제가 많아지는 <b>스타벅스</b>.... 음료값은 비싸지고.. 맛은.. 특별한게없는..그런 <b>스타벅스</b>... 그렇지만 한번씩 찾게되는 그런 마성의 카페...입니다..... ',
#   'bloggername': 'Lovely Soo~:-D',
#   'bloggerlink': 'https://blog.naver.com/danjy12',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 서머캐리백 폼알데하이드 검출 인정 공식 사과문',
#   'link': 'https://blog.naver.com/vpdlf1004?Redirect=Log&logNo=222833649034',
#   'description': '&quot;<b>스타벅스</b> 서머캐리백 폼알데하이드 검출 인정, 공식 사과문..&quot; 얼마 전 <b>스타벅스</b>에서 e프리퀀시 적립 이벤트를 진행했었고, 나도 오랜 시간에 걸쳐 프리퀀시 적립을 가까스로 마치고 7시 땡 대기 타고... ',
#   'bloggername': '나를 찾아 떠나는 여행 ··─★',
#   'bloggerlink': 'https://blog.naver.com/vpdlf1004',
#   'postdate': '20220729'},
#  {'title': '무더위, <b>스타벅스</b> 메뉴 3선',
#   'link': 'https://blog.naver.com/cynic20?Redirect=Log&logNo=222834584133',
#   'description': 'm 오전에 <b>스타벅스</b> 다녀와서 집에서 올리는 주말 포스팅! 이번주에는 특별히 먹은게 별로 없었어요! 안올릴려고 하다가, 그냥 간단히 올리기로~ 시작은 역전우동 0410의 냉우동과 양파치킨마요! <b>스타벅스</b>... ',
#   'bloggername': 'Stories By Epicure',
#   'bloggerlink': 'https://blog.naver.com/cynic20',
#   'postdate': '20220730'},
#  {'title': '<b>스타벅스</b> e카드 교환권 사용방법 (기프티콘 비교)',
#   'link': 'https://blog.naver.com/ds1104?Redirect=Log&logNo=222838364563',
#   'description': '얼마 전 <b>스타벅스</b> 기프티콘을 대량 선물 받았다. 그리고 이번에는 <b>스타벅스</b> e카드 교환권도 받아서 사용방법에 대해 알아봤다. <b>스타벅스</b> e카드 교환권이란? <b>스타벅스</b> e카드 교환권은 3만 원, 5만 원, 10만... ',
#   'bloggername': '윤님의 경제테크 블로그',
#   'bloggerlink': 'https://blog.naver.com/ds1104',
#   'postdate': '20220803'},
#  {'title': '<b>스타벅스</b> 서머캐리백 음료3잔쿠폰 교환하기',
#   'link': 'https://blog.naver.com/rmagml04?Redirect=Log&logNo=222837528159',
#   'description': '<b>스타벅스</b> 서머캐리백 음료3잔 쿠폰으로 교환하기 <b>스타벅스</b> 2022년 프리퀀시 서머캐리백 받았다고 포스팅까지 했는데 말이쥬~ 문제가 발생했네유.... 띠로리..... 덜덜 첨엔 귀찮아서 그냥 냅둘까 하다가... ',
#   'bloggername': '강방 블로그',
#   'bloggerlink': 'https://blog.naver.com/rmagml04',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 다크초콜릿 카우보이쿠키',
#   'link': 'https://blog.naver.com/jylhee0704?Redirect=Log&logNo=222827671216',
#   'description': '딸이 선물로 받아온 <b>스타벅스</b> 다크초콜릿 카우보이쿠키입니다. 원래는 두 개를 선물받았어요. <b>스타벅스</b> 다크초콜릿 카우보이쿠키 2,800원 실온보관하시구요. 유통기한도 표기되어 있어요. 원재료도 참고하세요.... ',
#   'bloggername': '밥심은 국력의 맛있는 이야기',
#   'bloggerlink': 'https://blog.naver.com/jylhee0704',
#   'postdate': '20220725'},
#  {'title': '<b>스타벅스</b> 아이스크림 가성비대박 #유기농아이스크림초콜릿',
#   'link': 'https://blog.naver.com/makaronn?Redirect=Log&logNo=222834113315',
#   'description': '카페인을 수혈하러 <b>스타벅스</b>에 왔습니다. 사람이 많아서 자리를 잡고 사이렌오더로 주문하려는데... #<b>스타벅스</b>유기농아이스크림 주말이라서 사람많은 스벅;;; 아이스크림 어찌 이렇게 동그랗게 퍼주셨지??... ',
#   'bloggername': '바닐라라이프',
#   'bloggerlink': 'https://blog.naver.com/makaronn',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 복현DT점 다녀왔다 <b>스타벅스</b> 서머2프로모션MD도 구경',
#   'link': 'https://blog.naver.com/sounder2?Redirect=Log&logNo=222834451198',
#   'description': '요즘 <b>스타벅스</b> 서머캐리백 문제로 시끌시끌... 이번주는 어깨랑 목이 너무 앞아서 근처 정형외과를 갔다 가는김에 7월에 새로운 <b>스타벅스</b> 음료도 나오고, 3스타대시를 해서 <b>스타벅스</b> 복현DT점을 다녀왔다.... ',
#   'bloggername': 'sounder&apos;s Brick & Brick',
#   'bloggerlink': 'https://blog.naver.com/sounder2',
#   'postdate': '20220730'},
#  {'title': '<b>스타벅스</b> 안목항점 : 강릉 안목해변 카페, 강릉 콜택시 전화번호',
#   'link': 'https://blog.naver.com/insung1214?Redirect=Log&logNo=222837258166',
#   'description': '안목해변 카페 2층에서 아내와의 데이트가 즐겁습니다. 커피도 맛있어서 가끔 오게 됩니다 ^^ #강릉안목해변 #<b>스타벅스</b>안목항점 #<b>스타벅스</b>안목 #강릉<b>스타벅스</b> #<b>스타벅스</b>망고주스',
#   'bloggername': '코리아 롱비치 14',
#   'bloggerlink': 'https://blog.naver.com/insung1214',
#   'postdate': '20220802'},
#  {'title': '<b>스타벅스</b> 오가닉 프로틴 그릭요거트 앤드 그래놀라 후기... ',
#   'link': 'https://blog.naver.com/mnbvc98?Redirect=Log&logNo=222834453424',
#   'description': '<b>스타벅스</b> 오가닉 프로틴 그릭요거트 &amp; 그래놀라 후기 달달하구 맛있다 갑자기 문득 그릭요거트를 먹고 싶을 때가 있다! 어제가 바로 그런 날이었다 ㅎㅎㅎ <b>스타벅스</b>에서 브런치를 사러간 김에 그릭요거트도... ',
#   'bloggername': 'Jinny’s Lovely Days',
#   'bloggerlink': 'https://blog.naver.com/mnbvc98',
#   'postdate': '20220730'},
#  {'title': '<b>스타벅스</b> 우리미 카스텔라 내돈내산',
#   'link': 'https://blog.naver.com/ciel82321?Redirect=Log&logNo=222821238816',
#   'description': '초딩 아들이 빵종류 중 특히나 좋아하는 #카스테라 <b>스타벅스</b>에 커피 마시러 갔다가 우리쌀로 만든 카스테라가 있길래 사들고 집으로 왔다. #<b>스타벅스</b>우리미카스텔라 9500원 하얀 바탕에 <b>스타벅스</b> 골드카드... ',
#   'bloggername': '지구별여행자',
#   'bloggerlink': 'https://blog.naver.com/ciel82321',
#   'postdate': '20220720'},
#  {'title': '캠핑장에 함께 한 <b>스타벅스</b> 프리퀀시 서머 캐리백 크림',
#   'link': 'https://blog.naver.com/dalcom96?Redirect=Log&logNo=222830092486',
#   'description': '이번 캠핑여행엔 <b>스타벅스</b> 서머 캐리백에 캠핑장에서 쓸 베개를 담아 갔답니다. 베개와 대형 타월... <b>스타벅스</b> 서머캐리백, 발암물질 논란…사측 &quot;검사 진행중&quot; 이번에 코베아 캠핑 베개를 2개 구입했어요.... ',
#   'bloggername': '크리에이터민의 라이프 스테이지',
#   'bloggerlink': 'https://blog.naver.com/dalcom96',
#   'postdate': '20220726'},
#  {'title': '여행용 <b>스타벅스</b> 서머 캐리백 수령',
#   'link': 'https://blog.naver.com/truelite?Redirect=Log&logNo=222820283288',
#   'description': '<b>스타벅스</b> 프리퀀시를 모아 받을 수 있는 서머 캐리백을 수령했습니다. (선물 받음, 감사합니다!) 서머... <b>스타벅스</b>는 고급 브랜드도 아니고 명품도 아닌 것이 은근히 인기가 좋아 신기합니다. 이번 <b>스타벅스</b> 서머... ',
#   'bloggername': '김기사',
#   'bloggerlink': 'https://blog.naver.com/truelite',
#   'postdate': '20220720'},
#  {'title': '대구 월촌 8번출구 <b>스타벅스</b>월촌점',
#   'link': 'https://blog.naver.com/inteliwon?Redirect=Log&logNo=222820851616',
#   'description': '남푠이 출장갑니다 저도 따라갑니다 이번 출장은 #대구 월촌 8번 출입구 #<b>스타벅스</b>월촌점 이 번 출장길 동행은 이 아이 입니다! ^^ 사실 <b>스타벅스</b> 커피를 좋아하지 않아요 라떼를 좋아하는데 <b>스타벅스</b>라떼는... ',
#   'bloggername': '펌프킨의 소소한 이야기,퀼트,그리고 Coffee',
#   'bloggerlink': 'https://blog.naver.com/inteliwon',
#   'postdate': '20220720'},
#  {'title': '코로나와 울산 시내 버스 / <b>스타벅스</b> 신메뉴 / 서이추 테러',
#   'link': 'https://blog.naver.com/by_0304?Redirect=Log&logNo=222835896713',
#   'description': '<b>스타벅스</b> 신메뉴 <b>스타벅스</b> 제주청귤레모네이드 오마카세 가기 전에 글쓰려고 스벅 들렸는데 첨가는 지점.. 그레이스님께 청귤레모네이드 주문했다고 인증샷 보냈는데 다먹으니 얼음만 남았냐고 여쭤보심..... ',
#   'bloggername': '아세마',
#   'bloggerlink': 'https://blog.naver.com/by_0304',
#   'postdate': '20220731'},
#  {'title': '<b>스타벅스</b> 써머 캐빈 파우치 - 그린',
#   'link': 'https://blog.naver.com/yamako0221?Redirect=Log&logNo=222832615520',
#   'description': '귀엽네요^^ <b>스타벅스</b> 서머 캐빈 파우치를 열면... 핑크랑 똑같죠 ㅋㅋ 칸막이로 되어있는데요~~ 핑크... 누구를 델꼬 갈까요 ㅎㅎ #<b>스타벅스</b> #<b>스타벅스</b>굿즈 #<b>스타벅스</b>서머캐빈파우치 #<b>스타벅스</b>서머캐빈파우치그린',
#   'bloggername': '히히낭낭',
#   'bloggerlink': 'https://blog.naver.com/yamako0221',
#   'postdate': '20220728'},
#  {'title': '길벗과 오랜만에 <b>스타벅스</b>에서 아침을',
#   'link': 'https://blog.naver.com/annerheekim?Redirect=Log&logNo=222833904375',
#   'description': '오늘은 길벗이 좀 늦게 출근해도 되는 날이라서 정말 오랜만에 <b>스타벅스</b>에 같이 가서 아침을 먹었어요.... (길벗은 뭐 사는 것을 너무 싫어해요) 오랜만의 <b>스타벅스</b>에서의 스벅 조식. 빵이 따끈따끈해서 확실히... ',
#   'bloggername': '길벗의 앤(Anne) @ Suzhou ZJG & Shanghai',
#   'bloggerlink': 'https://blog.naver.com/annerheekim',
#   'postdate': '20220729'},
#  {'title': '<b>스타벅스</b> 서머 캐리백 불량 보상 교환 3만원 기프트카드 제공... ',
#   'link': 'https://blog.naver.com/gjskrj?Redirect=Log&logNo=222839027102',
#   'description': '#<b>스타벅스</b>서머캐리백교환 #<b>스타벅스</b>서머캐리백보상방법 <b>스타벅스</b> 측은 발암물질 굿즈 사태가 터지자 실물 서머 캐리백 교환 시 무료 음료쿠폰 3잔 교환과 추가로 e-스티커 적립 후 증정품 교환 이력 제시... ',
#   'bloggername': '아쿠아블로그:소소하고도 화려한이야기',
#   'bloggerlink': 'https://blog.naver.com/gjskrj',
#   'postdate': '20220804'}]

# %%
# 뉴스
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd



client_id = "MhFgqjK_W22Mux6cStc6"
client_secret = "m12uohVmNe"
encText = urllib.parse.quote("스타벅스")
start=1
url = "https://openapi.naver.com/v1/search/news?query=" + encText +'&display=100'+'&start='+str(start) # json 결과
# url = "https://openapi.naver.com/v1/search/news.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))

    json_obj=json.loads(response_body)
    print(json_obj['total'])

    display(pd.DataFrame(json_obj['items']))

else:
    print("Error Code:" + rescode)
# Out:
# 447508
#                                               title  \
# 0                  쿠팡, 라이브에서 ‘캐리비안베이 종일권’ 50% 할인 판매
# 1                  인테리어티쳐, ‘2022 웨딩북 온라인 혼수 박람회’ 참가
# 2              [굿모닝 증시]“실적·경기 자신감 보인 美증시, 국내도 반응할까”
# 3                     8월 4일 미증시 특징주 [글로벌 시황&amp;이슈]
# 4             쿠팡, 라방서 &apos;캐리비안베이 종일권&apos; 50% 할인
# ..                                              ...
# 95             신한금투, &apos;디지털 VIP 멤버십 서비스&apos; 오픈
# 96             셀러비, 아이키와 훅(HOOK) 맴버들의 ‘우산댄스 챌린지’ 공개
# 97          광주은행, &apos;지금은 연금저축펀드로 갈아탈 때&apos; 이벤트
# 98                         현대카드, 8월 할인 및 캐시백 이벤트 진행
# 99  &apos;中 개점휴업&apos;에도…<b>스타벅스</b>, 2분기 호실적 낸 이유는
#
#                                          originallink  \
# 0   http://www.lawissue.co.kr/view.php?ud=20220804...
# 1   http://mirakle.mk.co.kr/view.php?year=2022&no=...
# 2   https://view.asiae.co.kr/article/2022080408381...
# 3   https://www.wowtv.co.kr/NewsCenter/News/Read?a...
# 4   http://www.slist.kr/news/articleView.html?idxn...
# ..                                                ...
# 95  http://www.startuptoday.co.kr/news/articleView...
# 96  https://www.sportsw.kr/news/newsview.php?ncode...
# 97  http://www.g-enews.com/ko-kr/news/article/news...
# 98  http://www.consumuch.com/news/articleView.html...
# 99  https://www.hankyung.com/international/article...
#
#                                                  link  \
# 0   http://www.lawissue.co.kr/view.php?ud=20220804...
# 1   https://n.news.naver.com/mnews/article/009/000...
# 2   https://n.news.naver.com/mnews/article/277/000...
# 3   https://n.news.naver.com/mnews/article/215/000...
# 4   http://www.slist.kr/news/articleView.html?idxn...
# ..                                                ...
# 95  http://www.startuptoday.co.kr/news/articleView...
# 96  https://www.sportsw.kr/news/newsview.php?ncode...
# 97  http://www.g-enews.com/ko-kr/news/article/news...
# 98  http://www.consumuch.com/news/articleView.html...
# 99  https://n.news.naver.com/mnews/article/015/000...
#
#                                           description  \
# 0   또 추첨을 통해 캐리비안베이 모바일 기프트콘 3만원과 <b>스타벅스</b> 기프티콘...
# 1   상담 후기를 작성하면 <b>스타벅스</b> 아메리카노 기프티콘을 증정하는 이벤트도 ...
# 2   견고한 실적을 발표한 <b>스타벅스</b>(4%) 페이팔(9%), 소피아(28%),...
# 3   (<b>스타벅스</b>) 어제 실적을 발표한 기업들, 오늘 장에서는 어떤 흐름 보였...
# 4   또 추첨을 통해 캐리비안베이 모바일 기프트콘 3만원과 <b>스타벅스</b> 기프티콘...
# ..                                                ...
# 95  이벤트 기간 중 순입금고 10만원 이상인 고객을 대상으로 매주 30명, 총 390명...
# 96  챌린지 참여기간은 오는 29일까지로 약 4주간 진행되고 참여경품으로 추첨을 통해 ‘...
# 97  이전금액이 ▲1천만원 미만인 고객에게는 <b>스타벅스</b> 아메리카노 기프티콘 1...
# 98  대상 브랜드는 ▲<b>스타벅스</b>▲파리바게뜨▲뚜레쥬르▲피자헛▲파파존스▲지니▲디즈...
# 99  <b>스타벅스</b>가 2분기 중국 ‘제로 코로나’ 타격에도 시장 추정치를 웃도는 ...
#
#                             pubDate
# 0   Thu, 04 Aug 2022 08:40:00 +0900
# 1   Thu, 04 Aug 2022 08:39:00 +0900
# 2   Thu, 04 Aug 2022 08:38:00 +0900
# 3   Thu, 04 Aug 2022 08:37:00 +0900
# 4   Thu, 04 Aug 2022 08:36:00 +0900
# ..                              ...
# 95  Wed, 03 Aug 2022 13:50:00 +0900
# 96  Wed, 03 Aug 2022 13:40:00 +0900
# 97  Wed, 03 Aug 2022 13:40:00 +0900
# 98  Wed, 03 Aug 2022 13:38:00 +0900
# 99  Wed, 03 Aug 2022 13:28:00 +0900
#
# [100 rows x 5 columns]

# %%
# 지식인
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd



client_id = "MhFgqjK_W22Mux6cStc6"
client_secret = "m12uohVmNe"
encText = urllib.parse.quote("스타벅스")
start=1
url = "https://openapi.naver.com/v1/search/kin?query=" + encText +'&display=100'+'&start='+str(start) # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))

    json_obj=json.loads(response_body)

    display(pd.DataFrame(json_obj['items']))

else:
    print("Error Code:" + rescode)
# Out:
#                                   title  \
# 0            미국 시애틀 <b>스타벅스</b> (내공100)
# 1                    <b>스타벅스</b> 별적립 문의
# 2           <b>스타벅스</b>에 취업할려고 하는데 타투 있
# 3           <b>스타벅스</b> 자소서 쓰려는데 서비스직 한
# 4                   <b>스타벅스</b> 굿즈 발암물질
# ..                                  ...
# 95                   <b>스타벅스</b> 텀블러 구매
# 96                      <b>스타벅스</b> 별적립
# 97  왜 보험, 금융사에서는 <b>스타벅스</b> 기프티콘만 주나요?
# 98          <b>스타벅스</b> 1만원 모바일상품권 한번 쓸
# 99             <b>스타벅스</b> 근무하면서 개인카페윤영
#
#                                                  link  \
# 0   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 1   https://kin.naver.com/qna/detail.naver?d1id=8&...
# 2   https://kin.naver.com/qna/detail.naver?d1id=9&...
# 3   https://kin.naver.com/qna/detail.naver?d1id=4&...
# 4   https://kin.naver.com/qna/detail.naver?d1id=11...
# ..                                                ...
# 95  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 96  https://kin.naver.com/qna/detail.naver?d1id=8&...
# 97  https://kin.naver.com/qna/detail.naver?d1id=4&...
# 98  https://kin.naver.com/qna/detail.naver?d1id=5&...
# 99  https://kin.naver.com/qna/detail.naver?d1id=4&...
#
#                                           description
# 0   ... 시애틀에 <b>스타벅스</b> 1호점이 있다고 하여 가볼려구 합니다 한국에서...
# 1   ... 사이즈업 때문일까요? <b>스타벅스</b> 카드의 기본설정이 에코별로 되어있...
# 2   <b>스타벅스</b>에 취업할려고 하는데 타투 있으면 안되나요?  안녕하세요. TM...
# 3   <b>스타벅스</b> 자소서 쓰려는데 서비스직 한번도 안 해봤고... 질문자님께서는...
# 4   <b>스타벅스</b> 캐리백에서 1급 발암물질 폼알데히드 나와서 난리잖아요. 그럼 ...
# ..                                                ...
# 95  <b>스타벅스</b> 텀블러를 구매하고 싶은데 <b>스타벅스</b> 공홈에서는 주문...
# 96  <b>스타벅스</b> 별적립 무료쿠폰을 사용하면 신메뉴 3개 별 적립을 얻을 수 없...
# 97  ... 항상 <b>스타벅스</b> 아이스 아메리카노 톨 사이즈 기프티콘을 주더라구요...
# 98  <b>스타벅스</b> 1만원 모바일상품권 한번 쓸때 만약7천원 썼다면 남은 3천원은...
# 99  ... 제목 그대로 <b>스타벅스</b>는 근무하면서 개인카페 창업이 꿈인데 알바분...
#
# [100 rows x 3 columns]

# %%
# 카페
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import json
import pandas as pd



client_id = "MhFgqjK_W22Mux6cStc6"
client_secret = "m12uohVmNe"
encText = urllib.parse.quote("스타벅스")
start=1
url = "https://openapi.naver.com/v1/search/cafearticle?query=" + encText +'&display=100'+'&start='+str(start) # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))

    json_obj=json.loads(response_body)
    print(json_obj['total'])

    display(pd.DataFrame(json_obj['items']))

else:
    print("Error Code:" + rescode)
