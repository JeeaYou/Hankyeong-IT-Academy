# %%
from konlpy.tag import Okt,Kkma,Hannanum
import time
import re
from wordcloud import WordCloud

# %%
txt='''대한민국(大韓民國, 영어: Republic of Korea, ROK), 약칭 남한(南韓, 영어: South Korea), 한국(韓國)은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기[3], 국가는 관습상 애국가[4], 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도(약 2611만명)가 수도권에 살고 있다.[5]

대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.

대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 (GNI)은 명목 3만 4,994달러이다.[6] 2020년 유엔개발계획 (UNDP)이 매년 발표하는 인간개발지수 (HDI) 조사에서 세계 22위를 기록하였다.[2] 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다.[7] 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역

대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 (G20), 경제 협력 개발 기구 (OECD), 개발 원조 위원회 (DAC), 파리 클럽 등의 회원국이다.[8]

1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국을 합쳐 2019년을 기준으로 약 7,700만 명에 달한다[9].'''

# %%
mask=re.compile('\(.+?\)')
mask.findall(txt)[0]
# Out:
# '(大韓民國, 영어: Republic of Korea, ROK)'

# %%
mask=re.compile('\(.+?\)|\(.+?\)')
txt1=mask.sub('',txt)
txt1
# Out:
# '대한민국, 약칭 남한, 한국은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기[3], 국가는 관습상 애국가[4], 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도가 수도권에 살고 있다.[5]\n\n대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.\n\n대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 은 명목 3만 4,994달러이다.[6] 2020년 유엔개발계획 이 매년 발표하는 인간개발지수  조사에서 세계 22위를 기록하였다.[2] 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다.[7] 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역\n\n대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 , 경제 협력 개발 기구 , 개발 원조 위원회 , 파리 클럽 등의 회원국이다.[8]\n\n1948년 이후로 오늘날까지 한반도에는 대한민국과 조선민주주의인민공화국이라는 두 개의 분단국가가 각각 남북에 위치하고 있다. 한반도와 부속도서의 면적은 약 22만 km2이며, 인구는 대한민국과 조선민주주의인민공화국
# ...

# %%
#okt에서 형용사 추출
ls=['Adjective','Verb']
res_a=[]
for i,j in okt.pos(txt1):
    if j=='Adjective':
        res_a.append(i)
print(res_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 4>()
#       2 ls=['Adjective','Verb']
#       3 res_a=[]
# ----> 4 for i,j in okt.pos(txt1):
#       5     if j=='Adjective':
#       6         res_a.append(i)
#
# NameError: name 'okt' is not defined

# %%
#kkma의 형용사 뽑기
ls=['VA','VV']
res_a=[]
for i,j in kkma.pos(txt1):
    if j=='VA':
        res_a.append(i)
print(res_a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 4>()
#       2 ls=['VA','VV']
#       3 res_a=[]
# ----> 4 for i,j in kkma.pos(txt1):
#       5     if j=='VA':
#       6         res_a.append(i)
#
# NameError: name 'kkma' is not defined

# %%
#kkma의 동사 뽑기
ls=['VA','VV']
res_v=[]
for i,j in kkma.pos(txt1):
    if j=='VV':
        res_v.append(i+'다')
print(res_v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       2 ls=['VA','VV']
#       3 res_v=[]
# ----> 4 for i,j in kkma.pos(txt1):
#       5     if j=='VV':
#       6         res_v.append(i+'다')
#
# NameError: name 'kkma' is not defined

# %%
print(txt)
# Out:
# 대한민국(大韓民國, 영어: Republic of Korea, ROK), 약칭 남한(南韓, 영어: South Korea), 한국(韓國)은 동아시아의 한반도 남부에 자리한 민주공화국이다. 대한민국의 국기는 대한민국 국기법에 따라 태극기[3], 국가는 관습상 애국가[4], 국화는 관습상 무궁화이다. 공용어는 한국어와 한국 수어이다. 수도는 서울이다. 인구는 약 5,160만명으로, 전체 인구 중 절반 정도(약 2611만명)가 수도권에 살고 있다.[5]
#
# 대한민국은 1948년 5월 10일 총선거를 통해 제헌국회를 구성하였고, 1948년 8월 15일 대한민국 정부를 수립하였다. 1948년 제헌 국회에서 대한민국의 국호를 계승하여 헌법에 명시하였고, 다시 1950년 1월 16일 국무원 고시 제7호 ‘국호 및 일부 지방명과 지도색 사용에 관한 건’에 의해 확정하였다.
#
# 대한민국은 20세기 후반 이후 급격한 경제 성장을 이루었다. 그 과정에서 1990년대 말 외환 위기 등의 부침이 있기도 했다. 대한민국의 2022년 1인당 국민 총소득 (GNI)은 명목 3만 4,994달러이다.[6] 2020년 유엔개발계획 (UNDP)이 매년 발표하는 인간개발지수 (HDI) 조사에서 세계 22위를 기록하였다.[2] 2021년 7월 2일 스위스 제네바 본부에서 열린 ‘제68차 무역개발이사회’ 마지막 회의에서 한국의 지위를 선진국 그룹으로 ‘의견 일치’로 변경하고 선진국으로 인정했다.[7] 다만 높은 자살률, 장시간 근로 문화와 높은 산업 재해 사망률, 저출산 등의 사회 문제가 이 같은 성과와 병존하고 있다. 대한민국의 행정 구역
#
# 대한민국은 이코노미스트에서 발표하는 민주주의 지수 조사에서 2019년 기준 23위의 8.0점을 기록한 바와 같이 아시아에서 민주주의 수준이 가장 높은 국가 가운데 하나이다. 또한 대한민국은 주요 20개국 (G20), 경제 협력 개발 기구 (OECD), 개발 원조 위원회 (DAC), 파리 클럽 등의 회원국이다.[8]
#
# ...

# %%
# %time
okt=Okt()
nouns=okt.nouns(txt)
nouns
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# ['대한민국',
#  '영어',
#  '약칭',
#  '남한',
#  '영어',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기',
#  '국가',
#  '관습',
#  '애국가',
#  '국화',
#  '관습',
#  '무궁화',
#  '용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '약',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '수도권',
#  '살',
#  '대한민국',
#  '총선거',
#  '통해',
#  '제헌국회',
#  '구성',
#  '대한민국',
#  '정부',
#  '수립',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '다시',
#  '국무원',
#  '고시',
#  '제',
#  '호',
#  '국호',
#  '및',
#  '일부',
#  '지방',
#  '명과',
#  '도색',
#  '사용',
#  '관',
#  '건',
#  '확정',
#  '대한민국',
#  '세기',
#  '후반',
#  '이후',
#  '경제',
#  '성장',
#  '그',
#  '과정',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '대한민국',
#  '국민',
#  '소득',
#  '은',
#  '명목',
#  '유엔',
#  '개발',
#  '계획',
#  '이',
#  '매년',
#  '발표',
#  '인간',
#  '개발',
#  '지수',
#  '조사',
#  '세계',
#  '위',
#  '기록',
#  '스위스',
#  '제네바',
#  '본부',
#  '제',
#  '차',
# ...

# %%
nouns
# Out:
# ['대한민국',
#  '영어',
#  '약칭',
#  '남한',
#  '영어',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기',
#  '국가',
#  '관습',
#  '애국가',
#  '국화',
#  '관습',
#  '무궁화',
#  '용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '약',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '수도권',
#  '살',
#  '대한민국',
#  '총선거',
#  '통해',
#  '제헌국회',
#  '구성',
#  '대한민국',
#  '정부',
#  '수립',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '다시',
#  '국무원',
#  '고시',
#  '제',
#  '호',
#  '국호',
#  '및',
#  '일부',
#  '지방',
#  '명과',
#  '도색',
#  '사용',
#  '관',
#  '건',
#  '확정',
#  '대한민국',
#  '세기',
#  '후반',
#  '이후',
#  '경제',
#  '성장',
#  '그',
#  '과정',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '대한민국',
#  '국민',
#  '소득',
#  '은',
#  '명목',
#  '유엔',
#  '개발',
#  '계획',
#  '이',
#  '매년',
#  '발표',
#  '인간',
#  '개발',
#  '지수',
#  '조사',
#  '세계',
#  '위',
#  '기록',
#  '스위스',
#  '제네바',
#  '본부',
#  '제',
#  '차',
#  '무역',
#  '개발',
#  '이사회',
#  '마지막',
#  '회의',
# ...

# %%
len(nouns)
# Out:
# 198

# %%
# %time
han=Hannanum()
h_nouns=han.nouns(txt)
h_nouns
# Out:
# CPU times: total: 0 ns
# Wall time: 499 µs
# ['대한민국(大韓民國,',
#  '영어',
#  '약칭',
#  '남한(南韓,',
#  '영어',
#  '한국(韓國)',
#  '동아시아',
#  '한반',
#  '남부',
#  '자리한',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기[3],',
#  '국가',
#  '관습상',
#  '애국가[4],',
#  '국화',
#  '관습상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수',
#  '서울',
#  '인구',
#  '약',
#  '5,160만명',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도(약',
#  '2611만명',
#  '수도권',
#  '5',
#  '대한민국',
#  '1948년',
#  '5월',
#  '10',
#  '총선거',
#  '제헌국회',
#  '구성',
#  '1948년',
#  '8월',
#  '15일',
#  '대한민국',
#  '정부',
#  '수립',
#  '1948년',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950년',
#  '1월',
#  '16일',
#  '국무원',
#  '고시',
#  '제7호',
#  '‘국호',
#  '일부',
#  '지방명',
#  '지도색',
#  '사용',
#  '건’',
#  '확정',
#  '대한민국',
#  '20세',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990년대',
#  '외환',
#  '위',
#  '등',
#  '대한민국',
#  '2022년',
#  '1인당',
#  '국민',
#  '총소득',
#  '명목',
#  '3',
#  '4,994달러',
#  '6',
#  '2020년',
# ...

# %%
kkma=Kkma()
k_nouns=kkma.nouns(txt)

# %%
k_nouns
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
# ...

# %%
okt.pos(txt)
# Out:
# [('대한민국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('大韓民國', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('Republic', 'Alpha'),
#  ('of', 'Alpha'),
#  ('Korea', 'Alpha'),
#  (',', 'Punctuation'),
#  ('ROK', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('약칭', 'Noun'),
#  ('남한', 'Noun'),
#  ('(', 'Punctuation'),
#  ('南韓', 'Foreign'),
#  (',', 'Punctuation'),
#  ('영어', 'Noun'),
#  (':', 'Punctuation'),
#  ('South', 'Alpha'),
#  ('Korea', 'Alpha'),
#  ('),', 'Punctuation'),
#  ('한국', 'Noun'),
#  ('(', 'Punctuation'),
#  ('韓國', 'Foreign'),
#  (')', 'Punctuation'),
#  ('은', 'Noun'),
#  ('동아시아', 'Noun'),
#  ('의', 'Josa'),
#  ('한반도', 'Noun'),
#  ('남부', 'Noun'),
#  ('에', 'Josa'),
#  ('자리', 'Noun'),
#  ('한', 'Josa'),
#  ('민주공화국', 'Noun'),
#  ('이다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('대한민국', 'Noun'),
#  ('의', 'Josa'),
#  ('국기', 'Noun'),
#  ('는', 'Josa'),
#  ('대한민국', 'Noun'),
#  ('국기법', 'Noun'),
#  ('에', 'Josa'),
#  ('따라', 'Verb'),
#  ('태극기', 'Noun'),
# ...

# %%
okt.tagset
# Out:
# {'Adjective': '형용사',
#  'Adverb': '부사',
#  'Alpha': '알파벳',
#  'Conjunction': '접속사',
#  'Determiner': '관형사',
#  'Eomi': '어미',
#  'Exclamation': '감탄사',
#  'Foreign': '외국어, 한자 및 기타기호',
#  'Hashtag': '트위터 해쉬태그',
#  'Josa': '조사',
#  'KoreanParticle': '(ex: ㅋㅋ)',
#  'Noun': '명사',
#  'Number': '숫자',
#  'PreEomi': '선어말어미',
#  'Punctuation': '구두점',
#  'ScreenName': '트위터 아이디',
#  'Suffix': '접미사',
#  'Unknown': '미등록어',
#  'Verb': '동사'}

# %%
okt.morphs(txt)
# Out:
# ['대한민국',
#  '(',
#  '大韓民國',
#  ',',
#  '영어',
#  ':',
#  'Republic',
#  'of',
#  'Korea',
#  ',',
#  'ROK',
#  '),',
#  '약칭',
#  '남한',
#  '(',
#  '南韓',
#  ',',
#  '영어',
#  ':',
#  'South',
#  'Korea',
#  '),',
#  '한국',
#  '(',
#  '韓國',
#  ')',
#  '은',
#  '동아시아',
#  '의',
#  '한반도',
#  '남부',
#  '에',
#  '자리',
#  '한',
#  '민주공화국',
#  '이다',
#  '.',
#  '대한민국',
#  '의',
#  '국기',
#  '는',
#  '대한민국',
#  '국기법',
#  '에',
#  '따라',
#  '태극기',
#  '[',
#  '3',
#  '],',
#  '국가',
#  '는',
#  '관습',
#  '상',
#  '애국가',
#  '[',
#  '4',
#  '],',
#  '국화',
#  '는',
#  '관습',
#  '상',
#  '무궁화',
#  '이다',
#  '.',
#  '공',
#  '용어',
#  '는',
#  '한국어',
#  '와',
#  '한국',
#  '수어',
#  '이다',
#  '.',
#  '수도',
#  '는',
#  '서울',
#  '이다',
#  '.',
#  '인구',
#  '는',
#  '약',
#  '5,160만',
#  '명으로',
#  ',',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도',
#  '(',
#  '약',
#  '2611만',
#  '명',
#  ')',
#  '가',
#  '수도권',
#  '에',
#  '살',
#  '고',
#  '있다',
#  '.[',
#  '5',
#  ']',
#  '\n\n',
#  '대한민국',
#  '은',
#  '1948년',
#  '5월',
#  '10일',
#  '총선거',
# ...

# %%
a=okt.pos(txt)
res=[]
for i in a:
    if i[1]=='Adjective':
        res.append(i)
print(res)
# Out:
# [('있다', 'Adjective'), ('의해', 'Adjective'), ('급격한', 'Adjective'), ('있기도', 'Adjective'), ('높은', 'Adjective'), ('높은', 'Adjective'), ('같은', 'Adjective'), ('있다', 'Adjective'), ('높은', 'Adjective'), ('있다', 'Adjective')]

# %%
a_list=[n[0] for n in okt.pos(txt) if n[1]=='Adjective']
a_list
a_list2=[i for i,j in okt.pos(txt) if j=='Adjective']
a_list2
# Out:
# ['있다', '의해', '급격한', '있기도', '높은', '높은', '같은', '있다', '높은', '있다']

# %%
okt_v=[i for i,j in okt.pos(txt) if j=='Verb']
okt_v
# Out:
# ['따라',
#  '가',
#  '하였고',
#  '하였다',
#  '하여',
#  '하였고',
#  '하였다',
#  '이루었다',
#  '부침이',
#  '했다',
#  '인당',
#  '하는',
#  '하였다',
#  '열린',
#  '했다',
#  '하는',
#  '합쳐']

# %%
kkma_v=[i for i,j in kkma.pos(txt) if j=='VA']
kkma_v
# Out:
# ['높', '높', '같', '높']

# %%
kkma_v=[i for i,j in kkma.pos(txt) if j=='VV']
kkma_v
# Out:
# ['따르', '가', '살', '통하', '관하', '의하', '이루', '있', '하', '열리', '하', '하', '합치', '달하']

# %%
han_v=[i for i,j in han.pos(txt) if j=='P']
han_v
# Out:
# ['따르',
#  '살',
#  '있',
#  '통하',
#  '관하',
#  '의하',
#  '이루',
#  '말',
#  '부치',
#  '있',
#  '하',
#  '열리',
#  '높',
#  '높',
#  '재',
#  '하',
#  '같',
#  '있',
#  '같',
#  '높',
#  '있',
#  '합치']

# %%
kkma.pos(txt)
# Out:
# [('대한민국', 'NNG'),
#  ('(', 'SS'),
#  ('大韓民國', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('Republic', 'OL'),
#  ('of', 'OL'),
#  ('Korea', 'OL'),
#  (',', 'SP'),
#  ('ROK', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('약칭', 'NNG'),
#  ('남한', 'NNG'),
#  ('(', 'SS'),
#  ('南韓', 'OH'),
#  (',', 'SP'),
#  ('영어', 'NNG'),
#  (':', 'SP'),
#  ('South', 'OL'),
#  ('Korea', 'OL'),
#  (')', 'SS'),
#  (',', 'SP'),
#  ('한국', 'NNG'),
#  ('(', 'SS'),
#  ('韓國', 'OH'),
#  (')', 'SS'),
#  ('은', 'NNG'),
#  ('동아시아', 'NNP'),
#  ('의', 'JKG'),
#  ('한반도', 'NNG'),
#  ('남부', 'NNG'),
#  ('에', 'JKM'),
#  ('자리', 'NNG'),
#  ('하', 'XSV'),
#  ('ㄴ', 'ETD'),
#  ('민주', 'NNG'),
#  ('공화국', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('.', 'SF'),
#  ('대한민국', 'NNG'),
#  ('의', 'JKG'),
#  ('국기', 'NNG'),
#  ('는', 'JX'),
#  ('대한민국', 'NNG'),
#  ('국', 'NNG'),
#  ('기법', 'NNG'),
#  ('에', 'JKM'),
#  ('따르', 'VV'),
#  ('아', 'ECS'),
#  ('태극기', 'NNG'),
#  ('[', 'SS'),
#  ('3', 'NR'),
#  (']', 'SS'),
#  (',', 'SP'),
# ...

# %%
kkma.tagset
# Out:
# {'EC': '연결 어미',
#  'ECD': '의존적 연결 어미',
#  'ECE': '대등 연결 어미',
#  'ECS': '보조적 연결 어미',
#  'EF': '종결 어미',
#  'EFA': '청유형 종결 어미',
#  'EFI': '감탄형 종결 어미',
#  'EFN': '평서형 종결 어미',
#  'EFO': '명령형 종결 어미',
#  'EFQ': '의문형 종결 어미',
#  'EFR': '존칭형 종결 어미',
#  'EP': '선어말 어미',
#  'EPH': '존칭 선어말 어미',
#  'EPP': '공손 선어말 어미',
#  'EPT': '시제 선어말 어미',
#  'ET': '전성 어미',
#  'ETD': '관형형 전성 어미',
#  'ETN': '명사형 전성 어미',
#  'IC': '감탄사',
#  'JC': '접속 조사',
#  'JK': '조사',
#  'JKC': '보격 조사',
#  'JKG': '관형격 조사',
#  'JKI': '호격 조사',
#  'JKM': '부사격 조사',
#  'JKO': '목적격 조사',
#  'JKQ': '인용격 조사',
#  'JKS': '주격 조사',
#  'JX': '보조사',
#  'MA': '부사',
#  'MAC': '접속 부사',
#  'MAG': '일반 부사',
#  'MD': '관형사',
#  'MDN': '수 관형사',
#  'MDT': '일반 관형사',
#  'NN': '명사',
#  'NNB': '일반 의존 명사',
#  'NNG': '보통명사',
#  'NNM': '단위 의존 명사',
#  'NNP': '고유명사',
#  'NP': '대명사',
#  'NR': '수사',
#  'OH': '한자',
#  'OL': '외국어',
#  'ON': '숫자',
#  'SE': '줄임표',
#  'SF': '마침표, 물음표, 느낌표',
#  'SO': '붙임표(물결,숨김,빠짐)',
#  'SP': '쉼표,가운뎃점,콜론,빗금',
#  'SS': '따옴표,괄호표,줄표',
# ...

# %%
han.tagset
# Out:
# {'E': '어미',
#  'EC': '연결 어미',
#  'EF': '종결 어미',
#  'EP': '선어말어미',
#  'ET': '전성 어미',
#  'F': '외국어',
#  'I': '독립언',
#  'II': '감탄사',
#  'J': '관계언',
#  'JC': '격조사',
#  'JP': '서술격 조사',
#  'JX': '보조사',
#  'M': '수식언',
#  'MA': '부사',
#  'MM': '관형사',
#  'N': '체언',
#  'NB': '의존명사',
#  'NC': '보통명사',
#  'NN': '수사',
#  'NP': '대명사',
#  'NQ': '고유명사',
#  'P': '용언',
#  'PA': '형용사',
#  'PV': '동사',
#  'PX': '보조 용언',
#  'S': '기호',
#  'X': '접사',
#  'XP': '접두사',
#  'XS': '접미사'}

# %%
han.pos(txt)
# Out:
# [('대한민국(大韓民國,', 'N'),
#  ('영어', 'N'),
#  (':', 'S'),
#  ('Republic', 'F'),
#  ('of', 'F'),
#  ('Korea', 'F'),
#  (',', 'S'),
#  ('ROK', 'F'),
#  ('),', 'S'),
#  ('약칭', 'N'),
#  ('남한(南韓,', 'N'),
#  ('영어', 'N'),
#  (':', 'S'),
#  ('South', 'F'),
#  ('Korea', 'F'),
#  ('),', 'S'),
#  ('한국(韓國)', 'N'),
#  ('은', 'J'),
#  ('동아시아', 'N'),
#  ('의', 'J'),
#  ('한반', 'N'),
#  ('도', 'J'),
#  ('남부', 'N'),
#  ('에', 'J'),
#  ('자리한', 'N'),
#  ('민주공화국', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('대한민국', 'N'),
#  ('의', 'J'),
#  ('국기', 'N'),
#  ('는', 'J'),
#  ('대한민국', 'N'),
#  ('국기법', 'N'),
#  ('에', 'J'),
#  ('따르', 'P'),
#  ('아', 'E'),
#  ('태극기[3],', 'N'),
#  ('국가', 'N'),
#  ('는', 'J'),
#  ('관습상', 'N'),
#  ('애국가[4],', 'N'),
#  ('국화', 'N'),
#  ('는', 'J'),
#  ('관습상', 'N'),
#  ('무궁화', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('공용어', 'N'),
#  ('는', 'J'),
#  ('한국어', 'N'),
#  ('와', 'J'),
#  ('한국', 'N'),
#  ('수어', 'N'),
#  ('이', 'J'),
#  ('다', 'E'),
#  ('.', 'S'),
#  ('수', 'N'),
# ...

# %%
han.nouns(txt)
# Out:
# ['대한민국(大韓民國,',
#  '영어',
#  '약칭',
#  '남한(南韓,',
#  '영어',
#  '한국(韓國)',
#  '동아시아',
#  '한반',
#  '남부',
#  '자리한',
#  '민주공화국',
#  '대한민국',
#  '국기',
#  '대한민국',
#  '국기법',
#  '태극기[3],',
#  '국가',
#  '관습상',
#  '애국가[4],',
#  '국화',
#  '관습상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '한국',
#  '수어',
#  '수',
#  '서울',
#  '인구',
#  '약',
#  '5,160만명',
#  '전체',
#  '인구',
#  '중',
#  '절반',
#  '정도(약',
#  '2611만명',
#  '수도권',
#  '5',
#  '대한민국',
#  '1948년',
#  '5월',
#  '10',
#  '총선거',
#  '제헌국회',
#  '구성',
#  '1948년',
#  '8월',
#  '15일',
#  '대한민국',
#  '정부',
#  '수립',
#  '1948년',
#  '제헌',
#  '국회',
#  '대한민국',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950년',
#  '1월',
#  '16일',
#  '국무원',
#  '고시',
#  '제7호',
#  '‘국호',
#  '일부',
#  '지방명',
#  '지도색',
#  '사용',
#  '건’',
#  '확정',
#  '대한민국',
#  '20세',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990년대',
#  '외환',
#  '위',
#  '등',
#  '대한민국',
#  '2022년',
#  '1인당',
#  '국민',
#  '총소득',
#  '명목',
#  '3',
#  '4,994달러',
#  '6',
#  '2020년',
#  '유엔개발계획',
#  '발표',
#  '인간개발지수',
#  '조사',
# ...

# %%
# 미션   단어 붙여서 담는다
kkma_nouns=[]
kkma_h=[]
kkma_v=[]

# %%
kkma_v=[i for i,j in kkma.pos(txt) if j=='VV']
kkma_v
# Out:
# ['따르', '가', '살', '통하', '관하', '의하', '이루', '있', '하', '열리', '하', '하', '합치', '달하']

# %%
k_nouns
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
# ...

# %%
res_a
# Out:
# []

# %%
res_v
# Out:
# []

# %%
re=k_nouns+res_v+res_a
re
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
# ...

# %%
len(re)
# Out:
# 228

# %%
re1=' '.join(re)
re1
# Out:
# '대한 대한민국 민국 영어 약칭 남한 한국 은 동아시아 한반도 남부 자리 민주 민주공화국 공화국 국기 국 국기법 기법 태극기 3 국가 관습 애 애국가 4 국화 관습상 상 무궁화 공용어 한국어 수어 수도 서울 인구 5,160 5,160만명 만 명 전체 중 절반 정도 약 2611 2611만명 수도권 5 1948 1948년 년 5월 월 10 10일 일 총선거 제헌 제헌국회 국회 구성 8 8월 15 15일 정부 수립 국호 계승 헌법 명시 1950 1950년 1 1월 16 16일 국무원 고시 제 제7호 7 호 호 일부 지방 지방명과 명과 지도 지도색 색 사용 건 확정 20 20세기 세기 후반 이후 급격 경제 성장 과정 1990 1990년대 년대 말 외환 위기 등 부침 2022 2022년 1인 인 국민 총소득 명목 3만 4,994 4,994달러 달러 6 2020 2020년 유엔 유엔개발계획 개발 계획 이 발표 인간 인간개발지수 지수 조사 세계 22 22위 위 기록 2 2021 2021년 7월 2일 스위스 제네바 본부 저 68 68차 차 무역 무역개발이사회 이사회 마지막 회의 지위 선진국 그룹 의견 일치 로 변경 인정 자살률 장시간 근로 문화 산업 재해 사망률 저출산 사회 문제 이 성과 병존 행정 구역 이코노 이코노미스트 미스트 민주주의 주의 2019 2019년 기준 23 23위의 위의 8.0 8.0점 점 바 아시아 수준 가운데 주요 20개국 개국 협력 기구 원조 위원회 파리 클럽 회원국 오늘날 조선 인민 조선민주주의 개 분단 분단국가 남북 위치 부 부속도서의 속도 서의 면적 22만 조선민주주의인민공화국 7,700 7,700만 9'

# %%
import matplotlib.pyplot as plt
import numpy as np
wc = WordCloud('./NanumGothic.ttf',
               background_color = "white",
               max_words = 200)
               #stopwords = stopwords)
wc = wc.generate(re1) # str자료만 가능, list자료는 |안됨
plt.figure(figsize = (12, 12))
plt.imshow(wc) #interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
s=['이','호','대한민국','대한','한국','민국']
[i for i in re if i not in s]
# Out:
# ['영어',
#  '약칭',
#  '남한',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
#  '년대',
#  '말',
#  '외환',
#  '위기',
#  '등',
#  '부침',
# ...

# %%
re1=' '.join(re)
re1
# Out:
# '대한 대한민국 민국 영어 약칭 남한 한국 은 동아시아 한반도 남부 자리 민주 민주공화국 공화국 국기 국 국기법 기법 태극기 3 국가 관습 애 애국가 4 국화 관습상 상 무궁화 공용어 한국어 수어 수도 서울 인구 5,160 5,160만명 만 명 전체 중 절반 정도 약 2611 2611만명 수도권 5 1948 1948년 년 5월 월 10 10일 일 총선거 제헌 제헌국회 국회 구성 8 8월 15 15일 정부 수립 국호 계승 헌법 명시 1950 1950년 1 1월 16 16일 국무원 고시 제 제7호 7 호 호 일부 지방 지방명과 명과 지도 지도색 색 사용 건 확정 20 20세기 세기 후반 이후 급격 경제 성장 과정 1990 1990년대 년대 말 외환 위기 등 부침 2022 2022년 1인 인 국민 총소득 명목 3만 4,994 4,994달러 달러 6 2020 2020년 유엔 유엔개발계획 개발 계획 이 발표 인간 인간개발지수 지수 조사 세계 22 22위 위 기록 2 2021 2021년 7월 2일 스위스 제네바 본부 저 68 68차 차 무역 무역개발이사회 이사회 마지막 회의 지위 선진국 그룹 의견 일치 로 변경 인정 자살률 장시간 근로 문화 산업 재해 사망률 저출산 사회 문제 이 성과 병존 행정 구역 이코노 이코노미스트 미스트 민주주의 주의 2019 2019년 기준 23 23위의 위의 8.0 8.0점 점 바 아시아 수준 가운데 주요 20개국 개국 협력 기구 원조 위원회 파리 클럽 회원국 오늘날 조선 인민 조선민주주의 개 분단 분단국가 남북 위치 부 부속도서의 속도 서의 면적 22만 조선민주주의인민공화국 7,700 7,700만 9'

# %%
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'  #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] =False    #유니코드에서 음수 부호 설정

# %%
tmp=['a','b','a','b','b','c']

# %%
Counter(tmp)
# Out:
# Counter({'a': 2, 'b': 3, 'c': 1})

# %%
w_cnt=Counter(re)

# %%
top_50=pd.DataFrame(w_cnt.most_common(50))

# %%
top_50.columns=['nan','cnt']

# %%
top_50=top_50.set_index('nan')

# %%
top_50.plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='nan'>

# %%
import nltk

# %%
re
# Out:
# ['대한',
#  '대한민국',
#  '민국',
#  '영어',
#  '약칭',
#  '남한',
#  '한국',
#  '은',
#  '동아시아',
#  '한반도',
#  '남부',
#  '자리',
#  '민주',
#  '민주공화국',
#  '공화국',
#  '국기',
#  '국',
#  '국기법',
#  '기법',
#  '태극기',
#  '3',
#  '국가',
#  '관습',
#  '애',
#  '애국가',
#  '4',
#  '국화',
#  '관습상',
#  '상',
#  '무궁화',
#  '공용어',
#  '한국어',
#  '수어',
#  '수도',
#  '서울',
#  '인구',
#  '5,160',
#  '5,160만명',
#  '만',
#  '명',
#  '전체',
#  '중',
#  '절반',
#  '정도',
#  '약',
#  '2611',
#  '2611만명',
#  '수도권',
#  '5',
#  '1948',
#  '1948년',
#  '년',
#  '5월',
#  '월',
#  '10',
#  '10일',
#  '일',
#  '총선거',
#  '제헌',
#  '제헌국회',
#  '국회',
#  '구성',
#  '8',
#  '8월',
#  '15',
#  '15일',
#  '정부',
#  '수립',
#  '국호',
#  '계승',
#  '헌법',
#  '명시',
#  '1950',
#  '1950년',
#  '1',
#  '1월',
#  '16',
#  '16일',
#  '국무원',
#  '고시',
#  '제',
#  '제7호',
#  '7',
#  '호',
#  '호',
#  '일부',
#  '지방',
#  '지방명과',
#  '명과',
#  '지도',
#  '지도색',
#  '색',
#  '사용',
#  '건',
#  '확정',
#  '20',
#  '20세기',
#  '세기',
#  '후반',
#  '이후',
#  '급격',
#  '경제',
#  '성장',
#  '과정',
#  '1990',
#  '1990년대',
# ...

# %%
ko=nltk.Text(re)

# %%
type(ko.tokens)
# Out:
# list

# %%
len(set(ko.tokens))
# Out:
# 226

# %%
len(ko.tokens)
# Out:
# 228

# %%
ko.vocab()
# Out:
# FreqDist({'호': 2, '이': 2, '대한': 1, '대한민국': 1, '민국': 1, '영어': 1, '약칭': 1, '남한': 1, '한국': 1, '은': 1, ...})

# %%
plt.figure(figsize=(15,5))
ko.plot(50)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
s=['대한민국','한국']
ko=[i for i in ko if i not in s]

# %%
ko=nltk.Text(ko)
plt.figure(figsize=(15,5))
ko.plot(50)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
ko.vocab()
# Out:
# FreqDist({'호': 2, '이': 2, '대한': 1, '민국': 1, '영어': 1, '약칭': 1, '남한': 1, '은': 1, '동아시아': 1, '한반도': 1, ...})

# %%
ko.count('영어')
# Out:
# 1

# %%
ko.collocations()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\.conda\envs\han\lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\.conda\envs\han\lib\site-packages\nltk\data.py:583, in find(resource_name, paths)
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\yumei/nltk_data'
# ...

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
ko.concordance('대한')
