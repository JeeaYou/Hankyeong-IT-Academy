# %%
from konlpy.tag import Okt
f=open('./빅카인즈_코로나.txt', 'r' , encoding='utf-8')
txt=f.read() #readline(), readlines()
f.close
# Out:
# <function TextIOWrapper.close()>

# %%
okt=Okt()
re=okt.nouns(txt)

# %%
re

# %%
len(re)

# %%
re1=' '.join(re)

# %%
re1

# %%
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'  #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] =False    #유니코드에서 음수 부호 설정

# %%
tmp=['a','b','a','b','b','c']

# %%
Counter(tmp)

# %%
w_cnt=Counter(re)
w_cnt

# %%
top_50=pd.DataFrame(w_cnt.most_common(50))

# %%
top_50.columns
# Out:
# RangeIndex(start=0, stop=2, step=1)

# %%
top_50=top_50.set_index('nan')

# %%
top_50.plot(kind='bar', figsize=(15,5))

# %%
from collections import Counter
import pandas as pd
w_cnt=Counter(re)

# %%
df=pd.DataFrame(w_cnt)

# %%
#워드 클라우드
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)


wc = WordCloud('./NanumGothic.ttf',
               background_color = "white",
               max_words = 2000)
               #stopwords = stopwords)
wc = wc.generate(re1) # str자료만 가능, list자료는 안됨
plt.figure(figsize = (12, 12))
plt.imshow(wc) #interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
wc.words_
# Out:
# {'코로나': 1.0,
#  '확 진자': 0.320816149337964,
#  '코로나바이러스': 0.20056435858476232,
#  '한국': 0.12466536430070183,
#  '관계자': 0.10715577744012734,
#  '감염증': 0.10382750886332393,
#  '명': 0.10172925258664352,
#  '서울': 0.09847333767455321,
#  '온라인': 0.09181680052094639,
#  '동부 구치소': 0.08885030026770856,
#  '미국': 0.08725851964401997,
#  '만큼': 0.0828449460965198,
#  '시민': 0.07655017726647854,
#  '지역': 0.07387309167209319,
#  '사람': 0.0714854207365603,
#  '전문가': 0.06649301787135518,
#  '부산': 0.06627595687721582,
#  '감염': 0.06562477389479777,
#  '신축년': 0.06345416395340424,
#  '연말 시': 0.06244121264742059,
#  '소상 공인': 0.06236885898270748,
#  '시간': 0.05563996816438753,
#  '가능성': 0.05563996816438753,
#  '사업': 0.05339700455828088,
#  '의료 진': 0.052818175240575936,
#  '신년사': 0.05180522393459229,
#  '감염병': 0.0514434556110267,
#  '민주당': 0.05035815064032993,
#  '일자리': 0.0489834310107807,
#  '주': 0.04862166268721511,
#  '국민': 0.04811518703422328,
#  '집단 감염': 0.04811518703422328,
#  '위원회': 0.04645105274582158,
# ...

# %%
from collections import Counter
import pandas as pd

# %%
tmp=['a','b','a','b','b','c']

# %%
Counter(tmp)
# Out:
# Counter({'a': 2, 'b': 3, 'c': 1})

# %%
df=dict(w_cnt)

# %%
len(w_cnt.most_common())
# Out:
# 29115

# %%
w_cnt=Counter(re)

# %%
top_50=pd.DataFrame(w_cnt.most_common(50))

# %%
top_50.columns=['word','freq']

# %%
top_50=top_50.set_index('word')

# %%
top_50.plot(kind='bar', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='word'>

# %%
x=list(wc.words_.keys())[:50]
y=list(wc.words_.values())[:50]

# %%
plt.figure(figsize=(15,5))
plt.bar(x,y)
plt.xticks(rotation=90)
plt.show()

# %%
import nltk
from nltk.tokenize import RegexpTokenizer

# %%
ko=nltk.Text(re)

# %%
type(ko.tokens)
# Out:
# list

# %%
len(set(ko.tokens))
# Out:
# 29115

# %%
len(ko.tokens)
# Out:
# 548577

# %%
ko.vocab()
# Out:
# FreqDist({'코로나': 20338, '진자': 4523, '확': 4455, '서울': 3714, '명': 3508, '코로나바이러스': 3414, '한국': 2754, '지역': 2449, '방역': 2396, '구치소': 2342, ...})

# %%
plt.figure(figsize=(15,5))
ko.plot(50)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
ko.count('대구')
# Out:
# 961

# %%
ko.dispersion_plot(['코로나','서울','대구','정보통신부','김성주'])

# %%
ko.concordance('대구')
# Out:
# Displaying 25 of 961 matches:
# 력 각국 가능성 중국인 지렛대 노 코로나 노 백신 보도 기업 헬스장 대구 집합 금지 단계 코로나 무에타이 확산 세 연말 시 코로나 업주 달서
# 로나 업주 달서구 첫날 온라인 오픈 시위 자영 업자 온라인 방 본부 대구 소방본부 비수 전기차 자율 주행 현대차 현대차 그룹 임 직원 모빌리
# 원대 드라이브스루 경북 신입생 예비 소집 코로나바이러스 아이 코로나 대구 감염증 경북 지역 선생님 워 킹스 경산시 신입 방식 날 소집 신종
# 터 자매 결연 가구 위문 품 터 공감 영등포 구청 희망 온돌 대구시 대구 방문자 샘 교회 명 코로나 수성구 교회 발 층 집단 감염 샘 경북
#  파티마 신축년 수혜자 의무 원장 원목 신부 강복 환자 중심 김선미 대구 파티마 병원 수립 운영 효율 관리 모델링 코로나 신년인사 직무 관련
# 가입자 지역 가입자 납부 예외 기간 서울 수도권 울산 인천 상승 폭 대구 세종 부산 전세 가격 확 진자 부산 검사 소 해운대구 영도구 코호트
#  수도권 코로나 상인동 업주 성영 네이버 카페 청와대 코로나바이러스 대구 실재 체육 시설 단계 서울 협회장 헬스클럽 관장 서울 남부 지법 인
#  역점 곳 재 확산 마곡점 곳 수익금 드 유니폼 삼성 오승환 적십자 대구 온라인 적십자사 삼성 라이온즈 봉사활동 겨울 이불 점 소상 공인 상
# 적십자사 삼성 라이온즈 봉사활동 겨울 이불 점 소상 공인 상공 선수 대구 지사 코로나 온비드 경매 김상수 유니폼 경매 전달 선수 지역 입찰
#  교회 확 진자 수성구 진단 검사 방문자 샘 조사 경산 신매역 경북 대구 감염 교회 날 철도 분리 도시 긴급 관리 재난 인근 교인 외출 경위
# 금지 청와대 서울 헬스클럽 여의도 수도권 피트니스 경영 협회 유튜브 대구 번 인스타 청원 연말 시 관계자 국회의사당 미국 경제학자 부양책 더
# 러스 조혜련 비수 주 접촉 누리꾼 시일 신도 비대 감염증 정규 예배 대구 헬스장 양치 승 인스타그램 구달 경찰서 달서구 바디 스페이스 경제
# ...

# %%
s=['대한민국','한국']
ko=[i for i in ko if i not in s]

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\yumei\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
ko.concordance('참석자')
# Out:
# Displaying 25 of 238 matches:
#  국립 환경과학 코로나 계절 관리제 과학 평균 김영우 남미 금지 령 참석자 코로나 사람 자막 뉴스 이은경 편집 영상편집 이은경 김형근 취재 기
# 관 순국선열 호국 영령 최소 코로나바이러스 서울 고등 검찰청 현충탑 참석자 감염증 코로나바이러스 감염증 국립현충원 서울 현충원 차장 검사 서울
# 변곡점 순국선열 코로나 의회 임일혁 새해 맞이 안보 단체 단체 의원 참석자 호국 영령 국회의원 임종 주년 공식 행사 최 우선 참석자 신축년 소
# 단체 의원 참석자 호국 영령 국회의원 임종 주년 공식 행사 최 우선 참석자 신축년 소병훈 주년 공식 일정 광주시 시장 참배 손씨 대구 장애인
# 코로나 맥스 워너브러더스 블록버스터 솔젠트 간담 회 유재형 오프라인 참석자 동반성 참석 자수 미래에셋 대우 코로나 설명 회 관사 코스닥 주주
#  학교 학부모 컨 학부모 온라인 교원 노조 대유행 지역 의회 코로나 참석자 산티아고 프랑스 연말 시 남미 코로나 금지 령 김형근 유럽 검찰청
#  기후 위기 시민 의회 코로나 시민 영국 민주 주 감염병 비상 결의 참석자 손제 민 과학 널 아테네 발전소 강은미 정의당 탄소세 웨스트 일병
#  사면 론 위원회 도부 가능성 당사자 공감 최고 위원회 지층 민주당 참석자 사망자 코호트 확 진자 방호복 코로나 요양보호사 효 플러스 요양 병
# 수 확 진자 하동 상주 진주 창원 명 명 경남 김해시 창원시 진주시 참석자 명 개 개 허가 김해시 효율 경제 부서 외국인 여성 가족 유치 자치
# 망 차 대구시 이전 공청회 고속도로 경북 당원 충정 입장 문 민주당 참석자 지층 이낙연 선고 일 간담 회 위원회 국민 통합 권리 당원 당사자
# 확 진자 주 수도권 집단 감염 세 손영래 방역 조치 인 코로나 중구 참석자 인 자가 격리 황운하 지역구 횟집 명 전시 중앙 재난 안전 대책 본
# ...

# %%
re_one=[i for i in re if len(i)==1]
print(re_one)
# Out:
# ['액', '끝', '연', '확', '확', '소', '임', '소', '업', '무', '령', '시', '명', '북', '여', '주', '론', '스', '건', '건', '위', '건', '앞', '임', '선', '세', '층', '층', '장', '최', '복', '완', '방', '확', '방', '콥', '강', '환', '호', '해', '트', '카', '세', '진', '소', '곳', '선', '소', '로', '소', '인', '제', '확', '중', '회', '부', '승', '빅', '핀', '시', '자', '칙', '콜', '세', '펍', '발', '론', '시', '론', '워', '별', '국', '애', '스', '삼', '좌', '도', '물', '차', '트', '카', '세', '주', '식', '포', '산', '득', '디', '문', '득', '률', '치', '노', '노', '세', '시', '방', '임', '도', '확', '세', '률', '더', '항', '룸', '포', '인', '명', '임', '세', '염', '책', '주', '세', '부', '시', '행', '김', '환', '인', '률', '율', '군', '학', '관', '김', '행', '관', '직', '관', '임', '사', '광', '일', '포', '션', '샘', '샘', '리', '해', '호', '호', '국', '주', '확', '세', '주', '재', '명', '명', '명', '시', '차', '트', '카', '주', '처', '재', '발', '발', '일', '정', '제', '상', '자', '카', '트', '트', '처', '부', '부', '임', '단', '위', '위', '비', '선', '임', '량', '해', '위', '영', '북', '비', '개', '류', '료', '인', '확', '씨', '날', '확', '시', '칙', '소', '부', '회', '최', '회', '롱
# ...

# %%
re=okt.nouns(text) # text는 글 내용 
ko = nltk.Text(re)
ko.dispersion_plot(['자유'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [93], in <cell line: 1>()
# ----> 1 re=okt.nouns(re) # text는 글 내용
#       2 ko = nltk.Text(re)
#       3 ko.dispersion_plot(['자유'])
#
# File ~\.conda\envs\han\lib\site-packages\konlpy\tag\_okt.py:83, in Okt.nouns(self, phrase)
#      80 def nouns(self, phrase):
#      81     """Noun extractor."""
# ---> 83     tagged = self.pos(phrase)
#      84     return [s for s, t in tagged if t == 'Noun']
#
# File ~\.conda\envs\han\lib\site-packages\konlpy\tag\_okt.py:69, in Okt.pos(self, phrase, norm, stem, join)
#      58 def pos(self, phrase, norm=False, stem=False, join=False):
#      59     """POS tagger.
#      60     In contrast to other classes in this subpackage,
#      61     this POS tagger doesn't have a `flatten` option,
#    (...)
#      67     :param join: If True, returns joined sets of morph and tag.
# ...
