# %% [markdown]
# ## 학습목표
#  1. concat 함수를 활용하여 dataframe 병합시키기

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %% [markdown]
# #### concat 함수 사용하여 dataframe 병합하기
#  - pandas.concat 함수
#  - 축을 따라 dataframe을 병합 가능
#    - 기본 axis = 0 -> 행단위 병합

# %% [markdown]
# * column명이 같은 경우

# %%
df1 = pd.DataFrame({'key1' : np.arange(10), 'value1' : np.random.randn(10)})

# %%
df1
# Out:
#    key1    value1
# 0     0 -0.401116
# 1     1  0.164799
# 2     2 -2.192404
# 3     3  1.708124
# 4     4 -0.869708
# 5     5  0.622816
# 6     6 -0.161632
# 7     7  1.220574
# 8     8  0.738460
# 9     9 -0.927439

# %%
pd.concat([df1,df2],ignore_index=True)   #두파일을 하나로 만들기
# Out:
#     key1    value1
# 0      0 -0.401116
# 1      1  0.164799
# 2      2 -2.192404
# 3      3  1.708124
# 4      4 -0.869708
# 5      5  0.622816
# 6      6 -0.161632
# 7      7  1.220574
# 8      8  0.738460
# 9      9 -0.927439
# 10     0  0.467826
# 11     1  1.231876
# 12     2 -0.042990
# 13     3  1.274432
# 14     4  1.029399
# 15     5  0.182656
# 16     6  0.689465
# 17     7  1.068336
# 18     8  0.334512
# 19     9 -0.118495

# %%
df3
# Out:
#    key1    value1  key1    value1
# 0     0 -0.401116     0  0.467826
# 1     1  0.164799     1  1.231876
# 2     2 -2.192404     2 -0.042990
# 3     3  1.708124     3  1.274432
# 4     4 -0.869708     4  1.029399
# 5     5  0.622816     5  0.182656
# 6     6 -0.161632     6  0.689465
# 7     7  1.220574     7  1.068336
# 8     8  0.738460     8  0.334512
# 9     9 -0.927439     9 -0.118495

# %%
df1
# Out:
#    key1    value1
# 0     0 -0.401116
# 1     1  0.164799
# 2     2 -2.192404
# 3     3  1.708124
# 4     4 -0.869708
# 5     5  0.622816
# 6     6 -0.161632
# 7     7  1.220574
# 8     8  0.738460
# 9     9 -0.927439

# %%
pd.concat([df1,df3])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 pd.concat([df1,df3])
#
# File ~\.conda\envs\han\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\reshape\concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\reshape\concat.py:591, in _Concatenator.get_result(self)
#     589         obj_labels = obj.axes[1 - ax]
#     590         if not new_labels.equals(obj_labels):
# --> 591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
#     595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\indexes\base.py:3721, in Index.get_indexer(self, target, method, limit, tolerance)
#    3718 self._check_indexing_method(method, limit, tolerance)
#    3720 if not self._index_as_unique:
# -> 3721     raise InvalidIndexError(self._requires_unique_msg)
#    3723 if len(target) == 0:
#    3724     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
name=df1.columns

# %%
df1_columns=range(len(df3.columns))

# %%
df3_columns=range(len(df3.columns))

# %%
pd.concat([df1,df3])
# Out:
# ---------------------------------------------------------------------------
# InvalidIndexError                         Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 pd.concat([df1,df3])
#
# File ~\.conda\envs\han\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\reshape\concat.py:360, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     156 """
#     157 Concatenate pandas objects along a particular axis with optional set logic
#     158 along the other axes.
#    (...)
#     345 ValueError: Indexes have overlapping values: ['a']
#     346 """
#     347 op = _Concatenator(
#     348     objs,
#     349     axis=axis,
#    (...)
#     357     sort=sort,
#     358 )
# --> 360 return op.get_result()
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\reshape\concat.py:591, in _Concatenator.get_result(self)
#     589         obj_labels = obj.axes[1 - ax]
#     590         if not new_labels.equals(obj_labels):
# --> 591             indexers[ax] = obj_labels.get_indexer(new_labels)
#     593     mgrs_indexers.append((obj._mgr, indexers))
#     595 new_data = concatenate_managers(
#     596     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     597 )
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\indexes\base.py:3721, in Index.get_indexer(self, target, method, limit, tolerance)
#    3718 self._check_indexing_method(method, limit, tolerance)
#    3720 if not self._index_as_unique:
# -> 3721     raise InvalidIndexError(self._requires_unique_msg)
#    3723 if len(target) == 0:
#    3724     return np.array([], dtype=np.intp)
#
# InvalidIndexError: Reindexing only valid with uniquely valued Index objects

# %%
df3
# Out:
#    key1    value1  key1    value1
# 0     0 -0.401116     0  0.467826
# 1     1  0.164799     1  1.231876
# 2     2 -2.192404     2 -0.042990
# 3     3  1.708124     3  1.274432
# 4     4 -0.869708     4  1.029399
# 5     5  0.622816     5  0.182656
# 6     6 -0.161632     6  0.689465
# 7     7  1.220574     7  1.068336
# 8     8  0.738460     8  0.334512
# 9     9 -0.927439     9 -0.118495

# %%
df2 = pd.DataFrame({'key1' : np.arange(10), 'value1' : np.random.randn(10)})

# %%
df3=pd.concat([df1,df2],axis=1)      #옆으로 붙이기

# %%
df2
# Out:
#    key1    value1
# 0     0  0.467826
# 1     1  1.231876
# 2     2 -0.042990
# 3     3  1.274432
# 4     4  1.029399
# 5     5  0.182656
# 6     6  0.689465
# 7     7  1.068336
# 8     8  0.334512
# 9     9 -0.118495

# %%
pd.concat([df1, df2], ignore_index=True)
# Out:
#     key1    value1
# 0      0  0.428339
# 1      1 -0.630724
# 2      2 -0.354830
# 3      3 -3.319573
# 4      4  0.707479
# 5      5  0.384259
# 6      6 -0.307633
# 7      7 -1.140410
# 8      8 -0.456283
# 9      9 -0.634657
# 10     0 -1.082401
# 11     1  0.410309
# 12     2 -0.697485
# 13     3  1.015928
# 14     4  0.376382
# 15     5  0.868095
# 16     6 -0.018602
# 17     7 -2.161771
# 18     8  0.498214
# 19     9 -0.329963

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    key1    value1  key1    value1
# 0     0  0.428339     0 -1.082401
# 1     1 -0.630724     1  0.410309
# 2     2 -0.354830     2 -0.697485
# 3     3 -3.319573     3  1.015928
# 4     4  0.707479     4  0.376382
# 5     5  0.384259     5  0.868095
# 6     6 -0.307633     6 -0.018602
# 7     7 -1.140410     7 -2.161771
# 8     8 -0.456283     8  0.498214
# 9     9 -0.634657     9 -0.329963

# %% [markdown]
# * column 명이 다른 경우

# %%
df3 = pd.DataFrame({'key2' : np.arange(10), 'value2' : np.random.randn(10)})

# %%
pd.concat([df1, df3])
# Out:
#    key1    value1  key2    value2
# 0   0.0  0.428339   NaN       NaN
# 1   1.0 -0.630724   NaN       NaN
# 2   2.0 -0.354830   NaN       NaN
# 3   3.0 -3.319573   NaN       NaN
# 4   4.0  0.707479   NaN       NaN
# 5   5.0  0.384259   NaN       NaN
# 6   6.0 -0.307633   NaN       NaN
# 7   7.0 -1.140410   NaN       NaN
# 8   8.0 -0.456283   NaN       NaN
# 9   9.0 -0.634657   NaN       NaN
# 0   NaN       NaN   0.0 -0.362260
# 1   NaN       NaN   1.0 -0.326481
# 2   NaN       NaN   2.0 -1.554181
# 3   NaN       NaN   3.0  1.204519
# 4   NaN       NaN   4.0  0.715339
# 5   NaN       NaN   5.0 -0.096684
# 6   NaN       NaN   6.0  0.310233
# 7   NaN       NaN   7.0  0.100812
# 8   NaN       NaN   8.0  1.249370
# 9   NaN       NaN   9.0  0.288051

# %%
pd.concat([df1, df3], axis=1)
# Out:
#    key1    value1  key2    value2
# 0     0  0.428339     0 -0.362260
# 1     1 -0.630724     1 -0.326481
# 2     2 -0.354830     2 -1.554181
# 3     3 -3.319573     3  1.204519
# 4     4  0.707479     4  0.715339
# 5     5  0.384259     5 -0.096684
# 6     6 -0.307633     6  0.310233
# 7     7 -1.140410     7  0.100812
# 8     8 -0.456283     8  1.249370
# 9     9 -0.634657     9  0.288051
