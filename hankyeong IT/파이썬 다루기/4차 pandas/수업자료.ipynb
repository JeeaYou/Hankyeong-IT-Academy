# %%
import pandas as pd

# %%
df=pd.read_csv('./data/cctv_in_seoul.csv')
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1=df.copy()

# %%
df1['기관명']
# Out:
# 0      강남구
# 1      강동구
# 2      강북구
# 3      강서구
# 4      관악구
# 5      광진구
# 6      구로구
# 7      금천구
# 8      노원구
# 9      도봉구
# 10    동대문구
# 11     동작구
# 12     마포구
# 13    서대문구
# 14     서초구
# 15     성동구
# 16     성북구
# 17     송파구
# 18     양천구
# 19    영등포구
# 20     용산구
# 21     은평구
# 22     종로구
# 23      중구
# 24     중랑구
# Name: 기관명, dtype: object

# %%
df1[['기관명','소계']]
# Out:
#      기관명    소계
# 0    강남구  3238
# 1    강동구  1010
# 2    강북구   831
# 3    강서구   911
# 4    관악구  2109
# 5    광진구   878
# 6    구로구  1884
# 7    금천구  1348
# 8    노원구  1566
# 9    도봉구   825
# 10  동대문구  1870
# 11   동작구  1302
# 12   마포구   980
# 13  서대문구  1254
# 14   서초구  2297
# 15   성동구  1327
# 16   성북구  1651
# 17   송파구  1081
# 18   양천구  2482
# 19  영등포구  1277
# 20   용산구  2096
# 21   은평구  2108
# 22   종로구  1619
# 23    중구  1023
# 24   중랑구   916

# %%
df[df['소계']>=1884.00000]
# Out:
#     기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0   강남구  3238       1292    430    584    932
# 4   관악구  2109        846    260    390    613
# 6   구로구  1884       1142    173    246    323
# 14  서초구  2297       1406    157    336    398
# 18  양천구  2482       1843    142     30    467
# 20  용산구  2096       1368    218    112    398
# 21  은평구  2108       1138    224    278    468

# %%
df1['비고']='연습'

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  비고
# 0  강남구  3238       1292    430    584    932  연습
# 1  강동구  1010        379     99    155    377  연습
# 2  강북구   831        369    120    138    204  연습
# 3  강서구   911        388    258    184     81  연습
# 4  관악구  2109        846    260    390    613  연습

# %%
df1.iloc[:,:-1]
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379     99    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573     78     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009     78    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348
# 24   중랑구   916        509    121    177    109

# %%
df1.loc[1,'2014년']
# Out:
# 99

# %%
df.iloc[1:3,-3:-1]
# Out:
#    2014년  2015년
# 1     99    155
# 2    120    138

# %%
df1.loc[[1,2],['2014년','2015년']]
# Out:
#    2014년  2015년
# 1     99    155
# 2    120    138

# %%
df1['2014년'][1]=100
# Out:
# C:\Users\yumei\AppData\Local\Temp\ipykernel_7804\3151249026.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['2014년'][1]=100

# %%
df1=df.copy()

# %%
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  3238       1292    430    584    932
# 1    강동구  1010        379    100    155    377
# 2    강북구   831        369    120    138    204
# 3    강서구   911        388    258    184     81
# 4    관악구  2109        846    260    390    613
# 5    광진구   878        573      0     53    174
# 6    구로구  1884       1142    173    246    323
# 7    금천구  1348        674     51    269    354
# 8    노원구  1566        542     57    451    516
# 9    도봉구   825        238    159     42    386
# 10  동대문구  1870       1070     23    198    579
# 11   동작구  1302        544    341    103    314
# 12   마포구   980        314    118    169    379
# 13  서대문구  1254        844     50     68    292
# 14   서초구  2297       1406    157    336    398
# 15   성동구  1327        730     91    241    265
# 16   성북구  1651       1009      0    360    204
# 17   송파구  1081        529     21     68    463
# 18   양천구  2482       1843    142     30    467
# 19  영등포구  1277        495    214    195    373
# 20   용산구  2096       1368    218    112    398
# 21   은평구  2108       1138    224    278    468
# 22   종로구  1619        464    314    211    630
# 23    중구  1023        413    190     72    348
# 24   중랑구   916        509    121    177    109

# %%
df1['기관명'].str[:2]
# Out:
# 0     강남
# 1     강동
# 2     강북
# 3     강서
# 4     관악
# 5     광진
# 6     구로
# 7     금천
# 8     노원
# 9     도봉
# 10    동대
# 11    동작
# 12    마포
# 13    서대
# 14    서초
# 15    성동
# 16    성북
# 17    송파
# 18    양천
# 19    영등
# 20    용산
# 21    은평
# 22    종로
# 23    중구
# 24    중랑
# Name: 기관명, dtype: object

# %%
res = []
for i in df1['증감']:
    if i >= 0:
        res.append('증가')
    else:
        res.append('감소')
df1['증감_for'] = res
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년   증감 증감_for
# 0    강남구  3238       1292    430    584    932  348     증가
# 1    강동구  1010        379    100    155    377  222     증가
# 2    강북구   831        369    120    138    204   66     증가
# 3    강서구   911        388    258    184     81 -103     감소
# 4    관악구  2109        846    260    390    613  223     증가
# 5    광진구   878        573      0     53    174  121     증가
# 6    구로구  1884       1142    173    246    323   77     증가
# 7    금천구  1348        674     51    269    354   85     증가
# 8    노원구  1566        542     57    451    516   65     증가
# 9    도봉구   825        238    159     42    386  344     증가
# 10  동대문구  1870       1070     23    198    579  381     증가
# 11   동작구  1302        544    341    103    314  211     증가
# 12   마포구   980        314    118    169    379  210     증가
# 13  서대문구  1254        844     50     68    292  224     증가
# 14   서초구  2297       1406    157    336    398   62     증가
# 15   성동구  1327        730     91    241    265   24     증가
# 16   성북구  1651       1009      0    360    204 -156     감소
# 17   송파구  1081        529     21     68    463  395     증가
# 18   양천구  2482       1843    142     30    467  437     증가
# 19  영등포구  1277        495    214    195    373  178     증가
# 20   용산구  2096       1368    218    112    398  286     증가
# 21   은평구  2108       1138    224    278    468  190     증가
# 22   종로구  1619        464    314    211    630  419     증가
# 23    중구  1023        413    190     72    348  276     증가
# 24   중랑구   916        509    121    177    109  -68     감소

# %%
df1=df1.set_index('기관명')

# %%
df1['증감_리스트내포']=['증가' if i >= 0 else '감소' for i in df1['2016년증감']]
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 df1['증감_리스트내포']=['증가' if i >= 0 else '감소' for i in df1['2016년증감']]
#       2 df1.head()
#
# NameError: name 'df1' is not defined

# %%
df1['증감']=df1['2016년']-df1['2015년']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df1['증감']=df1['2016년']-df1['2015년']
#
# NameError: name 'df1' is not defined

# %%
import matplotlib.pyplot as plt

# %%
df1['소계'].plot()
# Out:
# <AxesSubplot:xlabel='기관명'>

# %%
df1
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감
# 기관명
# 강남구   3238       1292    430    584    932  348
# 강동구   1010        379    100    155    377  222
# 강북구    831        369    120    138    204   66
# 강서구    911        388    258    184     81 -103
# 관악구   2109        846    260    390    613  223
# 광진구    878        573      0     53    174  121
# 구로구   1884       1142    173    246    323   77
# 금천구   1348        674     51    269    354   85
# 노원구   1566        542     57    451    516   65
# 도봉구    825        238    159     42    386  344
# 동대문구  1870       1070     23    198    579  381
# 동작구   1302        544    341    103    314  211
# 마포구    980        314    118    169    379  210
# 서대문구  1254        844     50     68    292  224
# 서초구   2297       1406    157    336    398   62
# 성동구   1327        730     91    241    265   24
# 성북구   1651       1009      0    360    204 -156
# 송파구   1081        529     21     68    463  395
# 양천구   2482       1843    142     30    467  437
# 영등포구  1277        495    214    195    373  178
# 용산구   2096       1368    218    112    398  286
# 은평구   2108       1138    224    278    468  190
# 종로구   1619        464    314    211    630  419
# 중구    1023        413    190     72    348  276
# 중랑구    916        509    121    177    109  -68

# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
plt.figure(figsize=(15,6))
plt.plot(df1['소계'])
plt.xticks9rotation='90'
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 plt.figure(figsize=(15,6))
# ----> 2 plt.plot(df1['소계'])
#       3 plt.xticks9rotation='90'
#       4 plt.show
#
# NameError: name 'df1' is not defined

# %%
df1['소계'].plot(kind='barh',figsize=(10,5))

# %%
df1['소계'].plot(kind='box')
plt.show()

# %%
plt.boxplot(df1['소계'])
plt.show()

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년   증감 증감_for
# 0  강남구  3238       1292    430    584    932  348     증가
# 1  강동구  1010        379    100    155    377  222     증가
# 2  강북구   831        369    120    138    204   66     증가
# 3  강서구   911        388    258    184     81 -103     감소
# 4  관악구  2109        846    260    390    613  223     증가

# %%
del df1 ['증감_for']

# %%
df1.set_index('기관명')
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년   증감
# 기관명
# 강남구   3238       1292    430    584    932  348
# 강동구   1010        379    100    155    377  222
# 강북구    831        369    120    138    204   66
# 강서구    911        388    258    184     81 -103
# 관악구   2109        846    260    390    613  223
# 광진구    878        573      0     53    174  121
# 구로구   1884       1142    173    246    323   77
# 금천구   1348        674     51    269    354   85
# 노원구   1566        542     57    451    516   65
# 도봉구    825        238    159     42    386  344
# 동대문구  1870       1070     23    198    579  381
# 동작구   1302        544    341    103    314  211
# 마포구    980        314    118    169    379  210
# 서대문구  1254        844     50     68    292  224
# 서초구   2297       1406    157    336    398   62
# 성동구   1327        730     91    241    265   24
# 성북구   1651       1009      0    360    204 -156
# 송파구   1081        529     21     68    463  395
# 양천구   2482       1843    142     30    467  437
# 영등포구  1277        495    214    195    373  178
# 용산구   2096       1368    218    112    398  286
# 은평구   2108       1138    224    278    468  190
# 종로구   1619        464    314    211    630  419
# 중구    1023        413    190     72    348  276
# 중랑구    916        509    121    177    109  -68

# %%
df1.iloc[:,1:-2].sum(axis=1).sum()
# Out:
# 65964

# %%
df1.iloc[:,1:-2].values.sum()
# Out:
# 65964

# %%
df1[['증감','구문']].value_counts().unstack(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 df1[['증감','구문']].value_counts().unstack(0)
#
# NameError: name 'df1' is not defined
