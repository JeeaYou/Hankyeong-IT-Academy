# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"
else:
    font_family = "AppleGothic"
    
sns.set(font=font_family, rc={"axes.unicode_minus" : False })

# %%
df=pd.read_csv('./data/cctv_in_seoul.csv')
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
df1=df.copy()

# %%
df1['2016증감']=df1['2016년']-df1['2015년']

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감
# 0  강남구  3238       1292    430    584    932     348
# 1  강동구  1010        379     99    155    377     222
# 2  강북구   831        369    120    138    204      66
# 3  강서구   911        388    258    184     81    -103
# 4  관악구  2109        846    260    390    613     223

# %%
df1['증감']=['증가'if i>=0 else '감소' for i in df1['2016증감']]
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감
# 0  강남구  3238       1292    430    584    932     348  증가
# 1  강동구  1010        379     99    155    377     222  증가
# 2  강북구   831        369    120    138    204      66  증가
# 3  강서구   911        388    258    184     81    -103  감소
# 4  관악구  2109        846    260    390    613     223  증가

# %%
df1.describe()
# Out:
#                 소계    2013년도 이전       2014년       2015년       2016년     2016증감
# count    25.000000    25.000000   25.000000   25.000000   25.000000   25.00000
# mean   1515.320000   764.760000  159.480000  205.200000  385.880000  180.68000
# std     616.774656   415.510257  104.132976  137.877059  182.479981  162.65447
# min     825.000000   238.000000   21.000000   30.000000   81.000000 -156.00000
# 25%    1010.000000   464.000000   78.000000  103.000000  292.000000   66.00000
# 50%    1327.000000   573.000000  142.000000  184.000000  377.000000  210.00000
# 75%    1884.000000  1070.000000  218.000000  269.000000  467.000000  286.00000
# max    3238.000000  1843.000000  430.000000  584.000000  932.000000  437.00000

# %%
df1['2016년'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
res=[]
for i in df1['2016증감']:
    if i >= 500:
        res.append('상')
    elif 300<=i<500:
        res.append('중')
    else :
        res.append('하')
df1['구문_for']=res
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문_for
# 0    강남구  3238       1292    430    584    932     348  증가      중
# 1    강동구  1010        379     99    155    377     222  증가      하
# 2    강북구   831        369    120    138    204      66  증가      하
# 3    강서구   911        388    258    184     81    -103  감소      하
# 4    관악구  2109        846    260    390    613     223  증가      하
# 5    광진구   878        573     78     53    174     121  증가      하
# 6    구로구  1884       1142    173    246    323      77  증가      하
# 7    금천구  1348        674     51    269    354      85  증가      하
# 8    노원구  1566        542     57    451    516      65  증가      하
# 9    도봉구   825        238    159     42    386     344  증가      중
# 10  동대문구  1870       1070     23    198    579     381  증가      중
# 11   동작구  1302        544    341    103    314     211  증가      하
# 12   마포구   980        314    118    169    379     210  증가      하
# 13  서대문구  1254        844     50     68    292     224  증가      하
# 14   서초구  2297       1406    157    336    398      62  증가      하
# 15   성동구  1327        730     91    241    265      24  증가      하
# 16   성북구  1651       1009     78    360    204    -156  감소      하
# 17   송파구  1081        529     21     68    463     395  증가      중
# 18   양천구  2482       1843    142     30    467     437  증가      중
# 19  영등포구  1277        495    214    195    373     178  증가      하
# 20   용산구  2096       1368    218    112    398     286  증가      하
# 21   은평구  2108       1138    224    278    468     190  증가      하
# 22   종로구  1619        464    314    211    630     419  증가      중
# 23    중구  1023        413    190     72    348     276  증가      하
# 24   중랑구   916        509    121    177    109     -68  감소      하

# %%
res=[]
for i in df1['2016년']:
    if i>=500:
        res.append('상')
    elif i>=300:
        res.append('중')
    else:
        res.append('하')
df1['구문']=res
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문
# 0    강남구  3238       1292    430    584    932     348  증가  상
# 1    강동구  1010        379     99    155    377     222  증가  중
# 2    강북구   831        369    120    138    204      66  증가  하
# 3    강서구   911        388    258    184     81    -103  감소  하
# 4    관악구  2109        846    260    390    613     223  증가  상
# 5    광진구   878        573     78     53    174     121  증가  하
# 6    구로구  1884       1142    173    246    323      77  증가  중
# 7    금천구  1348        674     51    269    354      85  증가  중
# 8    노원구  1566        542     57    451    516      65  증가  상
# 9    도봉구   825        238    159     42    386     344  증가  중
# 10  동대문구  1870       1070     23    198    579     381  증가  상
# 11   동작구  1302        544    341    103    314     211  증가  중
# 12   마포구   980        314    118    169    379     210  증가  중
# 13  서대문구  1254        844     50     68    292     224  증가  하
# 14   서초구  2297       1406    157    336    398      62  증가  중
# 15   성동구  1327        730     91    241    265      24  증가  하
# 16   성북구  1651       1009     78    360    204    -156  감소  하
# 17   송파구  1081        529     21     68    463     395  증가  중
# 18   양천구  2482       1843    142     30    467     437  증가  중
# 19  영등포구  1277        495    214    195    373     178  증가  중
# 20   용산구  2096       1368    218    112    398     286  증가  중
# 21   은평구  2108       1138    224    278    468     190  증가  중
# 22   종로구  1619        464    314    211    630     419  증가  상
# 23    중구  1023        413    190     72    348     276  증가  중
# 24   중랑구   916        509    121    177    109     -68  감소  하

# %%
res = ['상' if i>=500 else '중' if i>=300 else '하' for i in df1['2016년']]

# %%
del df1['구문_for']

# %%
df1.head()
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문  비율(%)
# 기관명
# 강남구  3238       1292    430    584    932     348  증가  상   8.55
# 강동구  1010        379     99    155    377     222  증가  중   2.67
# 강북구   831        369    120    138    204      66  증가  하   2.19
# 강서구   911        388    258    184     81    -103  감소  하   2.40
# 관악구  2109        846    260    390    613     223  증가  상   5.57

# %%
df1['구문'].value_counts()
# Out:
# 중    13
# 하     7
# 상     5
# Name: 구문, dtype: int64

# %%
df1['증감'].value_counts()
# Out:
# 증가    22
# 감소     3
# Name: 증감, dtype: int64

# %%
df1[['증감','구문']].value_counts().
# Out:
# 증감  구문
# 증가  중     13
#     상      5
#     하      4
# 감소  하      3
# dtype: int64

# %%
df1[['증감','구문']].value_counts().unstack(1).T
# Out:
# 증감   감소    증가
# 구문
# 상   NaN   5.0
# 중   NaN  13.0
# 하   3.0   4.0

# %%
df1.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문
# 0  강남구  3238       1292    430    584    932     348  증가  상
# 1  강동구  1010        379     99    155    377     222  증가  중
# 2  강북구   831        369    120    138    204      66  증가  하
# 3  강서구   911        388    258    184     81    -103  감소  하
# 4  관악구  2109        846    260    390    613     223  증가  상

# %%
df1['비율(%)'] = df1['소계']/df1['소계'].sum()*100
df1
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문     비율(%)
# 0    강남구  3238       1292    430    584    932     348  증가  상  8.547370
# 1    강동구  1010        379     99    155    377     222  증가  중  2.666104
# 2    강북구   831        369    120    138    204      66  증가  하  2.193596
# 3    강서구   911        388    258    184     81    -103  감소  하  2.404773
# 4    관악구  2109        846    260    390    613     223  증가  상  5.567141
# 5    광진구   878        573     78     53    174     121  증가  하  2.317662
# 6    구로구  1884       1142    173    246    323      77  증가  중  4.973207
# 7    금천구  1348        674     51    269    354      85  증가  중  3.558324
# 8    노원구  1566        542     57    451    516      65  증가  상  4.133780
# 9    도봉구   825        238    159     42    386     344  증가  중  2.177758
# 10  동대문구  1870       1070     23    198    579     381  증가  상  4.936251
# 11   동작구  1302        544    341    103    314     211  증가  중  3.436898
# 12   마포구   980        314    118    169    379     210  증가  중  2.586912
# 13  서대문구  1254        844     50     68    292     224  증가  하  3.310192
# 14   서초구  2297       1406    157    336    398      62  증가  중  6.063406
# 15   성동구  1327        730     91    241    265      24  증가  하  3.502890
# 16   성북구  1651       1009     78    360    204    -156  감소  하  4.358155
# 17   송파구  1081        529     21     68    463     395  증가  중  2.853523
# 18   양천구  2482       1843    142     30    467     437  증가  중  6.551751
# 19  영등포구  1277        495    214    195    373     178  증가  중  3.370905
# 20   용산구  2096       1368    218    112    398     286  증가  중  5.532825
# 21   은평구  2108       1138    224    278    468     190  증가  중  5.564501
# 22   종로구  1619        464    314    211    630     419  증가  상  4.273685
# 23    중구  1023        413    190     72    348     276  증가  중  2.700420
# 24   중랑구   916        509    121    177    109     -68  감소  하  2.417971

# %%
df1['비율(%)'] = round(df1['소계']/df1['소계'].sum()*100,2)

# %%
df1['소계'].plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='소계'>

# %%
df1=df1.set_index('기관명')

# %%
df1.sort_values('소계',ascending=False ).head(4)['소계'].plot(kind='pie',autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='소계'>

# %%
sum(df1['2016년'])
# Out:
# 9647

# %%
df1['2016년'].sum()
# Out:
# 9647

# %%
df1['증감'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df1[df1['증감']=='감소'].index
# Out:
# Index(['강서구', '성북구', '중랑구'], dtype='object', name='기관명')

# %%
df1['구문'].unique()
# Out:
# array(['상', '중', '하'], dtype=object)

# %%
df1['구문'].value_counts().index
# Out:
# Index(['중', '하', '상'], dtype='object')

# %%
df1['2016년비율']=round(df1['2016년']/df1.iloc[:,2:6].sum(axis=1)*100,0)
df1
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문  비율(%)  2016년비율
# 기관명
# 강남구   3238       1292    430    584    932     348  증가  상   8.55     41.0
# 강동구   1010        379     99    155    377     222  증가  중   2.67     44.0
# 강북구    831        369    120    138    204      66  증가  하   2.19     39.0
# 강서구    911        388    258    184     81    -103  감소  하   2.40     19.0
# 관악구   2109        846    260    390    613     223  증가  상   5.57     41.0
# 광진구    878        573     78     53    174     121  증가  하   2.32     41.0
# 구로구   1884       1142    173    246    323      77  증가  중   4.97     39.0
# 금천구   1348        674     51    269    354      85  증가  중   3.56     47.0
# 노원구   1566        542     57    451    516      65  증가  상   4.13     47.0
# 도봉구    825        238    159     42    386     344  증가  중   2.18     41.0
# 동대문구  1870       1070     23    198    579     381  증가  상   4.94     49.0
# 동작구   1302        544    341    103    314     211  증가  중   3.44     32.0
# 마포구    980        314    118    169    379     210  증가  중   2.59     43.0
# 서대문구  1254        844     50     68    292     224  증가  하   3.31     46.0
# 서초구   2297       1406    157    336    398      62  증가  중   6.06     42.0
# 성동구   1327        730     91    241    265      24  증가  하   3.50     43.0
# 성북구   1651       1009     78    360    204    -156  감소  하   4.36     42.0
# 송파구   1081        529     21     68    463     395  증가  중   2.85     49.0
# 양천구   2482       1843    142     30    467     437  증가  중   6.55     43.0
# 영등포구  1277        495    214    195    373     178  증가  중   3.37     39.0
# 용산구   2096       1368    218    112    398     286  증가  중   5.53     39.0
# 은평구   2108       1138    224    278    468     190  증가  중   5.56     40.0
# 종로구   1619        464    314    211    630     419  증가  상   4.27     40.0
# 중구    1023        413    190     72    348     276  증가  중   2.70     39.0
# 중랑구    916        509    121    177    109     -68  감소  하   2.42     32.0

# %%
df1
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문  비율(%)
# 기관명
# 강남구   3238       1292    430    584    932     348  증가  상   8.55
# 강동구   1010        379     99    155    377     222  증가  중   2.67
# 강북구    831        369    120    138    204      66  증가  하   2.19
# 강서구    911        388    258    184     81    -103  감소  하   2.40
# 관악구   2109        846    260    390    613     223  증가  상   5.57
# 광진구    878        573     78     53    174     121  증가  하   2.32
# 구로구   1884       1142    173    246    323      77  증가  중   4.97
# 금천구   1348        674     51    269    354      85  증가  중   3.56
# 노원구   1566        542     57    451    516      65  증가  상   4.13
# 도봉구    825        238    159     42    386     344  증가  중   2.18
# 동대문구  1870       1070     23    198    579     381  증가  상   4.94
# 동작구   1302        544    341    103    314     211  증가  중   3.44
# 마포구    980        314    118    169    379     210  증가  중   2.59
# 서대문구  1254        844     50     68    292     224  증가  하   3.31
# 서초구   2297       1406    157    336    398      62  증가  중   6.06
# 성동구   1327        730     91    241    265      24  증가  하   3.50
# 성북구   1651       1009     78    360    204    -156  감소  하   4.36
# 송파구   1081        529     21     68    463     395  증가  중   2.85
# 양천구   2482       1843    142     30    467     437  증가  중   6.55
# 영등포구  1277        495    214    195    373     178  증가  중   3.37
# 용산구   2096       1368    218    112    398     286  증가  중   5.53
# 은평구   2108       1138    224    278    468     190  증가  중   5.56
# 종로구   1619        464    314    211    630     419  증가  상   4.27
# 중구    1023        413    190     72    348     276  증가  중   2.70
# 중랑구    916        509    121    177    109     -68  감소  하   2.42

# %%
df1.iloc[:,1:-4].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df1[df1['2016년']>600]
# Out:
#        소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문  비율(%)  2016년비율
# 기관명
# 강남구  3238       1292    430    584    932     348  증가  상   8.55     41.0
# 관악구  2109        846    260    390    613     223  증가  상   5.57     41.0
# 종로구  1619        464    314    211    630     419  증가  상   4.27     40.0

# %%
top_10=df1['2016년'].quantile(0.1)
df1[df1['2016년']>=top_10]
# Out:
#         소계  2013년도 이전  2014년  2015년  2016년  2016증감  증감 구문  비율(%)  2016년비율
# 기관명
# 강남구   3238       1292    430    584    932     348  증가  상   8.55     41.0
# 강동구   1010        379     99    155    377     222  증가  중   2.67     44.0
# 강북구    831        369    120    138    204      66  증가  하   2.19     39.0
# 관악구   2109        846    260    390    613     223  증가  상   5.57     41.0
# 구로구   1884       1142    173    246    323      77  증가  중   4.97     39.0
# 금천구   1348        674     51    269    354      85  증가  중   3.56     47.0
# 노원구   1566        542     57    451    516      65  증가  상   4.13     47.0
# 도봉구    825        238    159     42    386     344  증가  중   2.18     41.0
# 동대문구  1870       1070     23    198    579     381  증가  상   4.94     49.0
# 동작구   1302        544    341    103    314     211  증가  중   3.44     32.0
# 마포구    980        314    118    169    379     210  증가  중   2.59     43.0
# 서대문구  1254        844     50     68    292     224  증가  하   3.31     46.0
# 서초구   2297       1406    157    336    398      62  증가  중   6.06     42.0
# 성동구   1327        730     91    241    265      24  증가  하   3.50     43.0
# 성북구   1651       1009     78    360    204    -156  감소  하   4.36     42.0
# 송파구   1081        529     21     68    463     395  증가  중   2.85     49.0
# 양천구   2482       1843    142     30    467     437  증가  중   6.55     43.0
# 영등포구  1277        495    214    195    373     178  증가  중   3.37     39.0
# 용산구   2096       1368    218    112    398     286  증가  중   5.53     39.0
# 은평구   2108       1138    224    278    468     190  증가  중   5.56     40.0
# 종로구   1619        464    314    211    630     419  증가  상   4.27     40.0
# 중구    1023        413    190     72    348     276  증가  중   2.70     39.0

# %%
mn,c,mx=df1['2016년'].quantile([0.25,0.5,0.75])
print(mn)
print(c)
print(mx)
# Out:
# 292.0
# 377.0
# 467.0

# %%
df1['2016년'].describe()
# Out:
# count     25.000000
# mean     385.880000
# std      182.479981
# min       81.000000
# 25%      292.000000
# 50%      377.000000
# 75%      467.000000
# max      932.000000
# Name: 2016년, dtype: float64
