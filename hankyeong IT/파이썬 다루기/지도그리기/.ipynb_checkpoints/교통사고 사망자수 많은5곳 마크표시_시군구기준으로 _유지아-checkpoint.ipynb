# %%
import folium
import pandas as pd
import googlemaps

# %%
df=pd.read_csv('./2016년_사망교통사고.csv',encoding='cp949')

# %%
df.head()
# Out:
#     발생년      발생년월일시  발생분  주야 요일  사망자수  사상자수  중상자수  경상자수  부상신고자수  ... 도로형태_대분류  \
# 0  2016  2016122320   35  야간  금     1     1     0     0       0  ...      교차로
# 1  2016  2016122517   48  주간  일     1     1     0     0       0  ...      단일로
# 2  2016  2016122519    5  야간  일     1     1     0     0       0  ...      단일로
# 3  2016  2016122610   40  주간  월     1     1     0     0       0  ...      단일로
# 4  2016  2016122819   40  야간  수     1     1     0     0       0  ...      단일로
#
#     도로형태 당사자종별_1당_대분류 당사자종별_1당 당사자종별_2당_대분류 당사자종별_2당 발생위치X_UTMK 발생위치Y_UTMK  \
# 0   교차로내          승용차       중형          보행자      보행자     981731    1932086
# 1  기타단일로          승용차       중형          보행자      보행자     945989    1942347
# 2  기타단일로          화물차       소형          보행자      보행자     993981    1879534
# 3  기타단일로          승합차       경형          보행자      보행자    1161153    1751026
# 4  기타단일로          승용차       소형          보행자      보행자    1056276    1686645
#
#            경도         위도
# 0  127.293623  37.387686
# 1  126.889123  37.478777
# 2  127.431592  36.915926
# 3  129.282183  35.742393
# 4  128.118016  35.173512
#
# [5 rows x 27 columns]

# %%
df.columns   # '발생지시도', '발생지시군구'
# Out:
# Index(['발생년', '발생년월일시', '발생분', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
#        '부상신고자수', '발생지시도', '발생지시군구', '사고유형_대분류', '사고유형_중분류', '사고유형', '법규위반_대분류',
#        '법규위반', '도로형태_대분류', '도로형태', '당사자종별_1당_대분류', '당사자종별_1당', '당사자종별_2당_대분류',
#        '당사자종별_2당', '발생위치X_UTMK', '발생위치Y_UTMK', '경도', '위도'],
#       dtype='object')

# %%
df['지역']=df['발생지시도']+df['발생지시군구']

# %%
df[['지역','발생지시도', '발생지시군구']]
# Out:
#          지역 발생지시도 발생지시군구
# 0     경기광주시    경기    광주시
# 1     서울금천구    서울    금천구
# 2     충북진천군    충북    진천군
# 3     경북경주시    경북    경주시
# 4     경남진주시    경남    진주시
# ...     ...   ...    ...
# 4114  경기평택시    경기    평택시
# 4115  전남함평군    전남    함평군
# 4116  충북충주시    충북    충주시
# 4117  인천부평구    인천    부평구
# 4118  경북구미시    경북    구미시
#
# [4119 rows x 3 columns]

# %%
df_res=df.groupby('지역').sum()[['사상자수']].sort_values('사상자수',ascending=False).head().reset_index()

# %%
df_res
# Out:
#           지역  사상자수
# 0      충북청주시   118
# 1      경기용인시   111
# 2  경남창원시(통합)   103
# 3      충남천안시    86
# 4      경기평택시    86

# %%
import googlemaps
gmaps_key = "AIzaSyDR5zSAIYE9GW8-sy4rxNCN7x-gQNzhW64" 
gmaps = googlemaps.Client(key=gmaps_key) 
위도=[]
경도=[]
for i in df_res['지역']:
    tmp=gmaps.geocode(i, language='ko') 
    위도.append(tmp[0]['geometry']['location']['lat'])
    경도.append(tmp[0]['geometry']['location']['lng'])
print(위도)
print(경도)
# Out:
# [36.6424341, 37.2410864, 35.4606, 36.815129, 36.9921075]
# [127.4890319, 127.1775537, 128.2132, 127.1138939, 127.1129451]

# %%
import googlemaps
gmaps_key = "AIzaSyDR5zSAIYE9GW8-sy4rxNCN7x-gQNzhW64"        #API key값 넣기
gmaps = googlemaps.Client(key=gmaps_key)      
위도=[]            #위도 리스트 만들기
경도=[]            #경도 리스트 만들기
for i in df_res['지역']:          #for문으로 지역을 돌리기
    tmp=gmaps.geocode(i, language='ko')       #지정장소를 찾아내기
    위도.append(tmp[0]['geometry']['location']['lat'])    #위도 위치를  찾아내기
    경도.append(tmp[0]['geometry']['location']['lng'])    #경도 위치를  찾아내기

df_res['위도']=위도     #위도를 df_res에 담기 
df_res['경도']=경도     #경도를 df_res에 담기 

m = folium.Map(         #folium으로 지도를 설정
  location=[36.3504567,127.3848187],     #중심지역 주소를 지정하기
  zoom_start=7        #중심지역의 크기 조정하기 
)

 
from folium.plugins import MarkerCluster    
marker_cluster = MarkerCluster().add_to(m)      #지도를 마커클러스터에 추가하기 
 
for i in range(len(df_res)):   #for 문으로 자료를 읽기
    folium.Marker(             #지도를 만들기
    location=[df_res.위도[i],df_res.경도[i]],       #경도위도 취치로 지역을 설정하기 
    popup=f'[지역:{df_res.지역[i]},사상자수:{df_res.사상자수[i]}]',     #지역과 사상자수를 팝업에 뜨기 
    icon=folium.Icon(color='red',icon='ok'),      #아이콘의 설정
  ).add_to(marker_cluster)        #지정지도에 추가하기
    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2299c28ca36035e348f0f069e39abe19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2299c28ca36035e348f0f069e39abe19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2299c28ca36035e348f0f069e39abe19 = L.map(
#                 &quot;map_2299c28ca36035e348f0f069e39abe19&quot;,
#                 {
#                     center: [36.3504567, 127.3848187],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb29881c4e2b423f6721657b27020dbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2299c28ca36035e348f0f069e39abe19);
#
#
#             var marker_cluster_5f8d2f2b71dbf5a84a3155337769e570 = L.markerClusterGroup(
#                 {}
#             );
#             map_2299c28ca36035e348f0f069e39abe19.addLayer(marker_cluster_5f8d2f2b71dbf5a84a3155337769e570);
#
#
#             var marker_0d6d6ccee4ab8d108999e519f9736cd8 = L.marker(
#                 [36.6424341, 127.4890319],
#                 {}
#             ).addTo(marker_cluster_5f8d2f2b71dbf5a84a3155337769e570);
#
#
#             var icon_c432c6a279b0dfb2649fe64a4ff3d710 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0d6d6ccee4ab8d108999e519f9736cd8.setIcon(icon_c432c6a279b0dfb2649fe64a4ff3d710);
#
#
#         var popup_7eb8580553056564a5ccf1e305c81480 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_b6abeabd4cebd50b0e343245f5eb9664 = $(`&lt;div id=&quot;html_b6abeabd4cebd50b0e343245f5eb9664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[지역:충북청주시,사상자수:118]&lt;/div&gt;`)[0];
#             popup_7eb8580553056564a5ccf1e305c81480.setContent(html_b6abeabd4cebd50b0e343245f5eb9664);
#
#
#         marker_0d6d6ccee4ab8d108999e519f9736cd8.bindPopup(popup_7eb8580553056564a5ccf1e305c81480)
#         ;
#
#
#
#
#             var marker_95c2ba2394cfd1d34bac862fcab51016 = L.marker(
#                 [37.2410864, 127.1775537],
#                 {}
#             ).addTo(marker_cluster_5f8d2f2b71dbf5a84a3155337769e570);
#
#
#             var icon_ba441cd1dd1a649b74934725010c06a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_95c2ba2394cfd1d34bac862fcab51016.setIcon(icon_ba441cd1dd1a649b74934725010c06a1);
#
#
#         var popup_1c62825cdfa8d889c3effc9eac3e97bf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_9234f5bed5cd1908c29345f2cae67a3d = $(`&lt;div id=&quot;html_9234f5bed5cd1908c29345f2cae67a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[지역:경기용인시,사상자수:111]&lt;/div&gt;`)[0];
#             popup_1c62825cdfa8d889c3effc9eac3e97bf.setContent(html_9234f5bed5cd1908c29345f2cae67a3d);
#
#
#         marker_95c2ba2394cfd1d34bac862fcab51016.bindPopup(popup_1c62825cdfa8d889c3effc9eac3e97bf)
#         ;
#
#
#
#
#             var marker_8cab8a3ab4c0a4b579f9800da7560061 = L.marker(
#                 [35.4606, 128.2132],
#                 {}
#             ).addTo(marker_cluster_5f8d2f2b71dbf5a84a3155337769e570);
#
#
#             var icon_435029903422c2c18007ef682e367cb2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8cab8a3ab4c0a4b579f9800da7560061.setIcon(icon_435029903422c2c18007ef682e367cb2);
#
#
#         var popup_2056f0542baf8bb5eed6b15f2e407889 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e681a82303ff87755fbcad66acd91f9e = $(`&lt;div id=&quot;html_e681a82303ff87755fbcad66acd91f9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[지역:경남창원시(통합),사상자수:103]&lt;/div&gt;`)[0];
#             popup_2056f0542baf8bb5eed6b15f2e407889.setContent(html_e681a82303ff87755fbcad66acd91f9e);
#
#
#         marker_8c
