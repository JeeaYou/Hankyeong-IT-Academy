# %%
import pandas as pd
import numpy as np
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'  #한글 폰트 설정
plt.rcParams['axes.unicode_minus'] =False    #유니코드에서 음수 부호 설정

# %%
##############################
##  데이터셋 임의 제작
################################

dataset=[['사과','치즈','생수','사과','사과'],
               ['생수','호두','치즈','고등어'],
               ['수박','사과','생수'],
               ['생수','호두','치즈','옥수수']]
import numpy as np
np.shape(dataset)
# Out:
# (4,)

# %%
te=TransactionEncoder()
te.fit(dataset)
te.columns_
te.transform(dataset)
te_arry=pd.DataFrame(te.transform(dataset),columns=te.columns_)
te_arry
# Out:
#      고등어     사과    생수     수박    옥수수     치즈     호두
# 0  False   True  True  False  False   True  False
# 1   True  False  True  False  False   True   True
# 2  False   True  True   True  False  False  False
# 3  False  False  True  False   True   True   True

# %%
te=TransactionEncoder()
te_arry=te.fit(dataset).transform(dataset)
print(te_arry)
df=pd.DataFrame(te_arry,columns=te.columns_)
display(df)
# Out:
# [[False  True  True False False  True False]
#  [ True False  True False False  True  True]
#  [False  True  True  True False False False]
#  [False False  True False  True  True  True]]
#      고등어     사과    생수     수박    옥수수     치즈     호두
# 0  False   True  True  False  False   True  False
# 1   True  False  True  False  False   True   True
# 2  False   True  True   True  False  False  False
# 3  False  False  True  False   True   True   True

# %%
#지지도 계산
frequency_itemsts=apriori(df,use_colnames=True)
frequency_itemsts
# Out:
#    support      itemsets
# 0     0.50          (사과)
# 1     1.00          (생수)
# 2     0.75          (치즈)
# 3     0.50          (호두)
# 4     0.50      (사과, 생수)
# 5     0.75      (치즈, 생수)
# 6     0.50      (호두, 생수)
# 7     0.50      (치즈, 호두)
# 8     0.50  (호두, 치즈, 생수)

# %%
#지지도 계산
frequency_itemsts=apriori(df,use_colnames=True,min_support=0.01)
frequency_itemsts
# Out:
#     support           itemsets
# 0      0.25              (고등어)
# 1      0.50               (사과)
# 2      1.00               (생수)
# 3      0.25               (수박)
# 4      0.25              (옥수수)
# 5      0.75               (치즈)
# 6      0.50               (호두)
# 7      0.25          (고등어, 생수)
# 8      0.25          (고등어, 치즈)
# 9      0.25          (고등어, 호두)
# 10     0.50           (사과, 생수)
# 11     0.25           (사과, 수박)
# 12     0.25           (사과, 치즈)
# 13     0.25           (수박, 생수)
# 14     0.25          (옥수수, 생수)
# 15     0.75           (치즈, 생수)
# 16     0.50           (호두, 생수)
# 17     0.25          (치즈, 옥수수)
# 18     0.25          (호두, 옥수수)
# 19     0.50           (치즈, 호두)
# 20     0.25      (고등어, 치즈, 생수)
# 21     0.25      (고등어, 호두, 생수)
# 22     0.25      (고등어, 치즈, 호두)
# 23     0.25       (사과, 수박, 생수)
# 24     0.25       (사과, 치즈, 생수)
# 25     0.25      (옥수수, 치즈, 생수)
# 26     0.25      (호두, 옥수수, 생수)
# 27     0.50       (호두, 치즈, 생수)
# 28     0.25      (호두, 치즈, 옥수수)
# ...

# %%
frequency_itemsts.sort_values('support',ascending=False).head(10)
# Out:
#     support      itemsets
# 2      1.00          (생수)
# 15     0.75      (치즈, 생수)
# 5      0.75          (치즈)
# 16     0.50      (호두, 생수)
# 1      0.50          (사과)
# 6      0.50          (호두)
# 27     0.50  (호두, 치즈, 생수)
# 19     0.50      (치즈, 호두)
# 10     0.50      (사과, 생수)
# 23     0.25  (사과, 수박, 생수)

# %%
len(frequency_itemsts['itemsets'][7])
# Out:
# 2

# %%
# frequency_itemsts['len_itemsets'] = frequency_itemsts['itemsets'].map(len)
# frequency_itemsts

# %%
frequency_itemsts['length']=frequency_itemsts['itemsets'].apply(lambda x:len(x))
frequency_itemsts
# Out:
#     support           itemsets  length
# 0      0.25              (고등어)       1
# 1      0.50               (사과)       1
# 2      1.00               (생수)       1
# 3      0.25               (수박)       1
# 4      0.25              (옥수수)       1
# 5      0.75               (치즈)       1
# 6      0.50               (호두)       1
# 7      0.25          (고등어, 생수)       2
# 8      0.25          (고등어, 치즈)       2
# 9      0.25          (고등어, 호두)       2
# 10     0.50           (사과, 생수)       2
# 11     0.25           (사과, 수박)       2
# 12     0.25           (사과, 치즈)       2
# 13     0.25           (수박, 생수)       2
# 14     0.25          (옥수수, 생수)       2
# 15     0.75           (치즈, 생수)       2
# 16     0.50           (호두, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 18     0.25          (호두, 옥수수)       2
# 19     0.50           (치즈, 호두)       2
# 20     0.25      (고등어, 치즈, 생수)       3
# 21     0.25      (고등어, 호두, 생수)       3
# 22     0.25      (고등어, 치즈, 호두)       3
# ...

# %%
frequency_itemsts['length']=frequency_itemsts['length'].astype(int)
frequency_itemsts1=frequency_itemsts[frequency_itemsts['length']==2].sort_values('support',ascending=False)

# %%
frequency_itemsts['length']==2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: length, dtype: bool

# %%
frequency_itemsts
# Out:
#     support           itemsets  length
# 0      0.25              (고등어)       1
# 1      0.50               (사과)       1
# 2      1.00               (생수)       1
# 3      0.25               (수박)       1
# 4      0.25              (옥수수)       1
# 5      0.75               (치즈)       1
# 6      0.50               (호두)       1
# 7      0.25          (고등어, 생수)       2
# 8      0.25          (고등어, 치즈)       2
# 9      0.25          (고등어, 호두)       2
# 10     0.50           (사과, 생수)       2
# 11     0.25           (사과, 수박)       2
# 12     0.25           (사과, 치즈)       2
# 13     0.25           (수박, 생수)       2
# 14     0.25          (옥수수, 생수)       2
# 15     0.75           (치즈, 생수)       2
# 16     0.50           (호두, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 18     0.25          (호두, 옥수수)       2
# 19     0.50           (치즈, 호두)       2
# 20     0.25      (고등어, 치즈, 생수)       3
# 21     0.25      (고등어, 호두, 생수)       3
# 22     0.25      (고등어, 치즈, 호두)       3
# ...

# %%
frequency_itemsts['length'].dtypes
# Out:
# dtype('int32')

# %%
'사과' in {'사과','치즈','수박'}
# Out:
# True

# %%
frequency_itemsts
# Out:
#     support           itemsets  length
# 0      0.25              (고등어)       1
# 1      0.50               (사과)       1
# 2      1.00               (생수)       1
# 3      0.25               (수박)       1
# 4      0.25              (옥수수)       1
# 5      0.75               (치즈)       1
# 6      0.50               (호두)       1
# 7      0.25          (고등어, 생수)       2
# 8      0.25          (고등어, 치즈)       2
# 9      0.25          (고등어, 호두)       2
# 10     0.50           (사과, 생수)       2
# 11     0.25           (사과, 수박)       2
# 12     0.25           (사과, 치즈)       2
# 13     0.25           (수박, 생수)       2
# 14     0.25          (옥수수, 생수)       2
# 15     0.75           (치즈, 생수)       2
# 16     0.50           (호두, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 18     0.25          (호두, 옥수수)       2
# 19     0.50           (치즈, 호두)       2
# 20     0.25      (고등어, 치즈, 생수)       3
# 21     0.25      (고등어, 호두, 생수)       3
# 22     0.25      (고등어, 치즈, 호두)       3
# ...

# %%
frequency_itemsts[frequency_itemsts['itemsets'].apply(lambda x: '사과'in x)]
# Out:
#     support      itemsets  length
# 1      0.50          (사과)       1
# 10     0.50      (사과, 생수)       2
# 11     0.25      (사과, 수박)       2
# 12     0.25      (사과, 치즈)       2
# 23     0.25  (사과, 수박, 생수)       3
# 24     0.25  (사과, 치즈, 생수)       3

# %%
# '치즈','옥수수'가 포함 된 모둔 항목 추출
item=['치즈','옥수수']
for i in item:
    display(frequency_itemsts[frequency_itemsts['itemsets'].map(lambda x: i in x)])
# Out:
#     support           itemsets  length
# 5      0.75               (치즈)       1
# 8      0.25          (고등어, 치즈)       2
# 12     0.25           (사과, 치즈)       2
# 15     0.75           (치즈, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 19     0.50           (치즈, 호두)       2
# 20     0.25      (고등어, 치즈, 생수)       3
# 22     0.25      (고등어, 치즈, 호두)       3
# 24     0.25       (사과, 치즈, 생수)       3
# 25     0.25      (옥수수, 치즈, 생수)       3
# 27     0.50       (호두, 치즈, 생수)       3
# 28     0.25      (호두, 치즈, 옥수수)       3
# 29     0.25  (고등어, 치즈, 호두, 생수)       4
# 30     0.25  (호두, 옥수수, 치즈, 생수)       4
#     support           itemsets  length
# 4      0.25              (옥수수)       1
# 14     0.25          (옥수수, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 18     0.25          (호두, 옥수수)       2
# 25     0.25      (옥수수, 치즈, 생수)       3
# 26     0.25      (호두, 옥수수, 생수)       3
# 28     0.25      (호두, 치즈, 옥수수)       3
# 30     0.25  (호두, 옥수수, 치즈, 생수)       4

# %%
association_rules(frequency_itemsts,metric='lift', min_threshold=1)
# Out:
#     antecedents    consequents  antecedent support  consequent support  \
# 0         (고등어)           (생수)                0.25                1.00
# 1          (생수)          (고등어)                1.00                0.25
# 2         (고등어)           (치즈)                0.25                0.75
# 3          (치즈)          (고등어)                0.75                0.25
# 4         (고등어)           (호두)                0.25                0.50
# ..          ...            ...                 ...                 ...
# 97     (치즈, 생수)      (옥수수, 호두)                0.75                0.25
# 98         (호두)  (생수, 치즈, 옥수수)                0.50                0.25
# 99        (옥수수)   (생수, 치즈, 호두)                0.25                0.50
# 100        (치즈)  (생수, 옥수수, 호두)                0.75                0.25
# 101        (생수)  (옥수수, 치즈, 호두)                1.00                0.25
#
#      support  confidence      lift  leverage  conviction
# 0       0.25    1.000000  1.000000    0.0000         inf
# ...

# %%
# '치즈','옥수수'가 포함 된 모둔 항목 추출
item=['치즈','옥수수']
for i in item:
    display(frequency_itemsts[frequency_itemsts['itemsets'].map(lambda x: i in x)])
# Out:
#     support           itemsets  length
# 5      0.75               (치즈)       1
# 8      0.25          (고등어, 치즈)       2
# 12     0.25           (사과, 치즈)       2
# 15     0.75           (치즈, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 19     0.50           (치즈, 호두)       2
# 20     0.25      (고등어, 치즈, 생수)       3
# 22     0.25      (고등어, 치즈, 호두)       3
# 24     0.25       (사과, 치즈, 생수)       3
# 25     0.25      (옥수수, 치즈, 생수)       3
# 27     0.50       (호두, 치즈, 생수)       3
# 28     0.25      (호두, 치즈, 옥수수)       3
# 29     0.25  (고등어, 치즈, 호두, 생수)       4
# 30     0.25  (호두, 옥수수, 치즈, 생수)       4
#     support           itemsets  length
# 4      0.25              (옥수수)       1
# 14     0.25          (옥수수, 생수)       2
# 17     0.25          (치즈, 옥수수)       2
# 18     0.25          (호두, 옥수수)       2
# 25     0.25      (옥수수, 치즈, 생수)       3
# 26     0.25      (호두, 옥수수, 생수)       3
# 28     0.25      (호두, 치즈, 옥수수)       3
# 30     0.25  (호두, 옥수수, 치즈, 생수)       4

# %%
rules=association_rules(frequency_itemsts,metric='confidence', min_threshold=0.1)

# %%
con1=rules[rules['antecedents'].apply( lambda x : '사과' in x)]
con2=rules[rules['consequents'].apply( lambda x : '사과' in x)]
rules[con1|con2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\envs\han\lib\site-packages\pandas\core\ops\array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: unsupported operand type(s) for |: 'float' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [174], in <cell line: 3>()
#       1 con1=rules[rules['antecedents'].apply( lambda x : '사과' in x)]
#       2 con2=rules[rules['consequents'].apply( lambda x : '사과' in x)]
# ----> 3 rules[con1|con2]
#
# ...

# %%
for i in te.columns_:
    tmp=rules[rules['antecedents'].apply( lambda x : '사과' in x)].sort_values('lift',ascending=False)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 8         (사과)        (수박)                0.50                0.25     0.25
# 45    (사과, 생수)        (수박)                0.50                0.25     0.25
# 47        (사과)    (수박, 생수)                0.50                0.25     0.25
# 6         (사과)        (생수)                0.50                1.00     0.50
# 44    (사과, 수박)        (생수)                0.25                1.00     0.25
# 50    (사과, 치즈)        (생수)                0.25                1.00     0.25
# 10        (사과)        (치즈)                0.50                0.75     0.25
# 51    (사과, 생수)        (치즈)                0.50                0.75     0.25
# 53        (사과)    (치즈, 생수)                0.50                0.75     0.25
#
#     confidence      lift  leverage  conviction
# 8          0.5  2.000000     0.125         1.5
# 45         0.5  2.000000     0.125         1.5
# 47         0.5  2.000000     0.125         1.5
# ...

# %%
te.columns_
# Out:
# ['고등어', '사과', '생수', '수박', '옥수수', '치즈', '호두']

# %%
rules
# Out:
#     antecedents    consequents  antecedent support  consequent support  \
# 0         (고등어)           (생수)                0.25                1.00
# 1          (생수)          (고등어)                1.00                0.25
# 2         (고등어)           (치즈)                0.25                0.75
# 3          (치즈)          (고등어)                0.75                0.25
# 4         (고등어)           (호두)                0.25                0.50
# ..          ...            ...                 ...                 ...
# 103    (치즈, 생수)      (옥수수, 호두)                0.75                0.25
# 104        (호두)  (생수, 치즈, 옥수수)                0.50                0.25
# 105       (옥수수)   (생수, 치즈, 호두)                0.25                0.50
# 106        (치즈)  (생수, 옥수수, 호두)                0.75                0.25
# 107        (생수)  (옥수수, 치즈, 호두)                1.00                0.25
#
#      support  confidence      lift  leverage  conviction
# 0       0.25    1.000000  1.000000    0.0000         inf
# ...

# %%
from apyori import apriori

dataset=[['사과','치즈','생수'],
               ['생수','호두','치즈','고등어'],
               ['수박','사과','생수'],
               ['생수','호두','치즈','옥수수']]

# %%
# !pip install apyori
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=2ab87791a6812122bb50f8a96ee6f2cf6195287412727c9ee6787956f477f755
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\c4\1a\79\20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
df=pd.DataFrame(list(apriori(dataset,min_support=0.01)))
df
# Out:
#                 items  support  \
# 0               (고등어)     0.25
# 1                (사과)     0.50
# 2                (생수)     1.00
# 3                (수박)     0.25
# 4               (옥수수)     0.25
# 5                (치즈)     0.75
# 6                (호두)     0.50
# 7           (고등어, 생수)     0.25
# 8           (고등어, 치즈)     0.25
# 9           (고등어, 호두)     0.25
# 10           (사과, 생수)     0.50
# 11           (사과, 수박)     0.25
# 12           (사과, 치즈)     0.25
# 13           (수박, 생수)     0.25
# 14          (옥수수, 생수)     0.25
# 15           (치즈, 생수)     0.75
# 16           (호두, 생수)     0.50
# 17          (치즈, 옥수수)     0.25
# 18          (호두, 옥수수)     0.25
# 19           (치즈, 호두)     0.50
# 20      (고등어, 치즈, 생수)     0.25
# 21      (고등어, 호두, 생수)     0.25
# 22      (고등어, 치즈, 호두)     0.25
# 23       (사과, 수박, 생수)     0.25
# 24       (사과, 치즈, 생수)     0.25
# 25      (옥수수, 치즈, 생수)     0.25
# 26      (호두, 옥수수, 생수)     0.25
# 27       (호두, 치즈, 생수)     0.50
# 28      (호두, 치즈, 옥수수)     0.25
# ...

# %%
df['length']=df['items'].apply(lambda x : len(x))
df
# Out:
#                 items  support  \
# 0               (고등어)     0.25
# 1                (사과)     0.50
# 2                (생수)     1.00
# 3                (수박)     0.25
# 4               (옥수수)     0.25
# 5                (치즈)     0.75
# 6                (호두)     0.50
# 7           (고등어, 생수)     0.25
# 8           (고등어, 치즈)     0.25
# 9           (고등어, 호두)     0.25
# 10           (사과, 생수)     0.50
# 11           (사과, 수박)     0.25
# 12           (사과, 치즈)     0.25
# 13           (수박, 생수)     0.25
# 14          (옥수수, 생수)     0.25
# 15           (치즈, 생수)     0.75
# 16           (호두, 생수)     0.50
# 17          (치즈, 옥수수)     0.25
# 18          (호두, 옥수수)     0.25
# 19           (치즈, 호두)     0.50
# 20      (고등어, 치즈, 생수)     0.25
# 21      (고등어, 호두, 생수)     0.25
# 22      (고등어, 치즈, 호두)     0.25
# 23       (사과, 수박, 생수)     0.25
# 24       (사과, 치즈, 생수)     0.25
# 25      (옥수수, 치즈, 생수)     0.25
# 26      (호두, 옥수수, 생수)     0.25
# 27       (호두, 치즈, 생수)     0.50
# 28      (호두, 치즈, 옥수수)     0.25
# ...

# %%
#항목개수가 2개이고,지지도가 0.01이상
con1=df['length']==2
con2=df['support']>=0.01
df[con1&con2].sort_values('support',ascending=False)
# Out:
#         items  support                                 ordered_statistics  \
# 15   (치즈, 생수)     0.75  [((), (치즈, 생수), 0.75, 1.0), ((생수), (치즈), 0.75,...
# 10   (사과, 생수)     0.50  [((), (사과, 생수), 0.5, 1.0), ((사과), (생수), 1.0, 1...
# 16   (호두, 생수)     0.50  [((), (생수, 호두), 0.5, 1.0), ((생수), (호두), 0.5, 1...
# 19   (치즈, 호두)     0.50  [((), (치즈, 호두), 0.5, 1.0), ((치즈), (호두), 0.6666...
# 7   (고등어, 생수)     0.25  [((), (고등어, 생수), 0.25, 1.0), ((고등어), (생수), 1.0...
# 8   (고등어, 치즈)     0.25  [((), (고등어, 치즈), 0.25, 1.0), ((고등어), (치즈), 1.0...
# 9   (고등어, 호두)     0.25  [((), (고등어, 호두), 0.25, 1.0), ((고등어), (호두), 1.0...
# 11   (사과, 수박)     0.25  [((), (사과, 수박), 0.25, 1.0), ((사과), (수박), 0.5, ...
# 12   (사과, 치즈)     0.25  [((), (사과, 치즈), 0.25, 1.0), ((사과), (치즈), 0.5, ...
# 13   (수박, 생수)     0.25  [((), (수박, 생수), 0.25, 1.0), ((생수), (수박), 0.25,...
# 14  (옥수수, 생수)     0.25  [((), (생수, 옥수수), 0.25, 1.0), ((생수), (옥수수), 0.2...
# 17  (치즈, 옥수수)     0.25  [((), (치즈, 옥수수), 0.25, 1.0), ((옥수수), (치즈), 1.0...
# ...

# %%
df['ordered_statistics']
# Out:
# 0                              [((), (고등어), 0.25, 1.0)]
# 1                                [((), (사과), 0.5, 1.0)]
# 2                                [((), (생수), 1.0, 1.0)]
# 3                               [((), (수박), 0.25, 1.0)]
# 4                              [((), (옥수수), 0.25, 1.0)]
# 5                               [((), (치즈), 0.75, 1.0)]
# 6                                [((), (호두), 0.5, 1.0)]
# 7     [((), (고등어, 생수), 0.25, 1.0), ((고등어), (생수), 1.0...
# 8     [((), (고등어, 치즈), 0.25, 1.0), ((고등어), (치즈), 1.0...
# 9     [((), (고등어, 호두), 0.25, 1.0), ((고등어), (호두), 1.0...
# 10    [((), (사과, 생수), 0.5, 1.0), ((사과), (생수), 1.0, 1...
# 11    [((), (사과, 수박), 0.25, 1.0), ((사과), (수박), 0.5, ...
# 12    [((), (사과, 치즈), 0.25, 1.0), ((사과), (치즈), 0.5, ...
# 13    [((), (수박, 생수), 0.25, 1.0), ((생수), (수박), 0.25,...
# 14    [((), (생수, 옥수수), 0.25, 1.0), ((생수), (옥수수), 0.2...
# 15    [((), (치즈, 생수), 0.75, 1.0), ((생수), (치즈), 0.75,...
# 16    [((), (생수, 호두), 0.5, 1.0), ((생수), (호두), 0.5, 1...
# ...

# %%
rules=assocation_rules(df, metric="confidence", min_threshold=0.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [226], in <cell line: 1>()
# ----> 1 rules=assocation_rules(df, metric="confidence", min_threshold=0.1)
#
# TypeError: 'DataFrame' object is not callable

# %%
df.columns=['itemsets', 'support', 'ordered_statistics', 'length']
# Out:
# Index(['items', 'support', 'ordered_statistics', 'length'], dtype='object')

# %%
rules['length']=rules['antecedents'].apply(lambda x: len(x))

# %%
from apyori import apriori
import pandas as pd

dataset=[['사과','치즈','생수'],
               ['생수','호두','치즈','고등어'],
               ['수박','사과','생수'],
               ['생수','호두','치즈','옥수수']]

# %%
result=pd.DataFrame((list(apriori(dataset, min_support=0.01))))
result
# Out:
#                 items  support  \
# 0               (고등어)     0.25
# 1                (사과)     0.50
# 2                (생수)     1.00
# 3                (수박)     0.25
# 4               (옥수수)     0.25
# 5                (치즈)     0.75
# 6                (호두)     0.50
# 7           (고등어, 생수)     0.25
# 8           (고등어, 치즈)     0.25
# 9           (고등어, 호두)     0.25
# 10           (사과, 생수)     0.50
# 11           (사과, 수박)     0.25
# 12           (사과, 치즈)     0.25
# 13           (수박, 생수)     0.25
# 14          (옥수수, 생수)     0.25
# 15           (치즈, 생수)     0.75
# 16           (호두, 생수)     0.50
# 17          (치즈, 옥수수)     0.25
# 18          (호두, 옥수수)     0.25
# 19           (치즈, 호두)     0.50
# 20      (고등어, 치즈, 생수)     0.25
# 21      (고등어, 호두, 생수)     0.25
# 22      (고등어, 치즈, 호두)     0.25
# 23       (사과, 수박, 생수)     0.25
# 24       (사과, 치즈, 생수)     0.25
# 25      (옥수수, 치즈, 생수)     0.25
# 26      (호두, 옥수수, 생수)     0.25
# 27       (호두, 치즈, 생수)     0.50
# 28      (호두, 치즈, 옥수수)     0.25
# ...

# %%
result['length']=result['items'].apply(len)
result
# Out:
#                 items  support  \
# 0               (고등어)     0.25
# 1                (사과)     0.50
# 2                (생수)     1.00
# 3                (수박)     0.25
# 4               (옥수수)     0.25
# 5                (치즈)     0.75
# 6                (호두)     0.50
# 7           (고등어, 생수)     0.25
# 8           (고등어, 치즈)     0.25
# 9           (고등어, 호두)     0.25
# 10           (사과, 생수)     0.50
# 11           (사과, 수박)     0.25
# 12           (사과, 치즈)     0.25
# 13           (수박, 생수)     0.25
# 14          (옥수수, 생수)     0.25
# 15           (치즈, 생수)     0.75
# 16           (호두, 생수)     0.50
# 17          (치즈, 옥수수)     0.25
# 18          (호두, 옥수수)     0.25
# 19           (치즈, 호두)     0.50
# 20      (고등어, 치즈, 생수)     0.25
# 21      (고등어, 호두, 생수)     0.25
# 22      (고등어, 치즈, 호두)     0.25
# 23       (사과, 수박, 생수)     0.25
# 24       (사과, 치즈, 생수)     0.25
# 25      (옥수수, 치즈, 생수)     0.25
# 26      (호두, 옥수수, 생수)     0.25
# 27       (호두, 치즈, 생수)     0.50
# 28      (호두, 치즈, 옥수수)     0.25
# ...

# %%
temp=result[result['length']==2].sort_values('support',ascending=False)

# %%
ar=temp['items']
ar
# Out:
# 15     (치즈, 생수)
# 10     (사과, 생수)
# 16     (호두, 생수)
# 19     (치즈, 호두)
# 7     (고등어, 생수)
# 8     (고등어, 치즈)
# 9     (고등어, 호두)
# 11     (사과, 수박)
# 12     (사과, 치즈)
# 13     (수박, 생수)
# 14    (옥수수, 생수)
# 17    (치즈, 옥수수)
# 18    (호두, 옥수수)
# Name: items, dtype: object

# %%
#########################################################
## Python의 NetworkX는 Link Analysis 알고리즘의 일부로 PageRank 알고리즘을 구현합니다. 
## pagerank는 “(web)Page의 순위(Rank)를 매기는 방법”을 말하며, 
##  page를 노드로 in-link, out-link를 edge로 고려하여 그래프를 만들고
## 그래프에 기반해 node의 순위를 매기는 방식
## 방향성이 있는 네트워크”에서 노드의 영향력을 측정하는 방식
## PageRank 알고리즘: https://wooono.tistory.com/189

## https://networkx.guide/algorithms/link-analysis/pagerank/
## https://frhyme.github.io/python-libs/nx_algo_link_Ana_pagerank/
##########################################################

import networkx as nx

# %%
G=nx.Graph()
G.add_edges_from(ar)
G

# %%
pr=nx.pagerank(G)

# %%
nsize=np.array([i for i in pr.values()])

# %%
nsize=5000*(nsize-min(nsize))/(max(nsize)-min(nsize))   #숫자는 동그라미 크기

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

# %%
nx.draw_networkx(G,font_family='Malgun gothic',node_size=nsize,
                 node_color=list(pr.values()),alpha=0.5,edge_color='0.1',font_size=15)
plt.figure(figsize=(16,12)); plt.axis('off')
# 한글 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)
