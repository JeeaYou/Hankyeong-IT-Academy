# %%
import matplotlib.pyplot as plt
import os
import seaborn as sns
if os.name == 'nt':
    font_family = "Malgun Gothic"

# %%
CCTV_Seoul=pd.read_csv('../data/01. CCTV_in_Seoul.csv')

# %%
CCTV_Seoul
# Out:
#      기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
CCTV_Seoul.columns=['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년']

# %%
CCTV_Seoul
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# 3    강서구   884        388    258    184     81
# 4    관악구  1496        846    260    390    613
# 5    광진구   707        573     78     53    174
# 6    구로구  1561       1142    173    246    323
# 7    금천구  1015        674     51    269    354
# 8    노원구  1265        542     57    451    516
# 9    도봉구   485        238    159     42    386
# 10  동대문구  1294       1070     23    198    579
# 11   동작구  1091        544    341    103    314
# 12   마포구   574        314    118    169    379
# 13  서대문구   962        844     50     68    292
# 14   서초구  1930       1406    157    336    398
# 15   성동구  1062        730     91    241    265
# 16   성북구  1464       1009     78    360    204
# 17   송파구   618        529     21     68    463
# 18   양천구  2034       1843    142     30    467
# ...

# %%
pop_Seoul
# Out:
#      자치구           계        계.1       계.2   65세이상고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul=pd.read_excel('../data/01. population_in_Seoul.xls',header=2, usecols='B,D,G,J,N')  #usecols 불러올 컬럼스를 지정

# %%
pop_Seoul.columns=['구별','인구수','한국인','외국인','고령자']

# %%
CCTV_Seoul.sort_values('소계',ascending=False)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 18   양천구  2034       1843    142     30    467
# 14   서초구  1930       1406    157    336    398
# 21   은평구  1873       1138    224    278    468
# 20   용산구  1624       1368    218    112    398
# 6    구로구  1561       1142    173    246    323
# 4    관악구  1496        846    260    390    613
# 16   성북구  1464       1009     78    360    204
# 10  동대문구  1294       1070     23    198    579
# 8    노원구  1265        542     57    451    516
# 11   동작구  1091        544    341    103    314
# 15   성동구  1062        730     91    241    265
# 7    금천구  1015        674     51    269    354
# 22   종로구  1002        464    314    211    630
# 13  서대문구   962        844     50     68    292
# 19  영등포구   904        495    214    195    373
# 3    강서구   884        388    258    184     81
# 1    강동구   773        379     99    155    377
# 2    강북구   748        369    120    138    204
# ...

# %%
sum=round((CCTV_Seoul.iloc[:,-3:].sum(axis=1))/CCTV_Seoul['2013년도 이전']*100)
CCTV_Seoul['비율']=sum.sort_values(ascending=False)

# %%
pop_Seoul=pop_Seoul[1:]

# %%
pop_Seoul['외국인비율']=pop_Seoul['외국인']/pop_Seoul['인구수']*100

# %%
pop_Seoul['고령자비율']=pop_Seoul['고령자']/pop_Seoul['인구수']*100

# %%
pop_Seoul.reset_index(drop = True,)
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 0    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 1     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 2    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 3    성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689
# 4    광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849
# 5   동대문구  369496.0  354079.0  15417.0  54173.0  4.172440  14.661322
# 6    중랑구  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 7    성북구  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 8    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 9    도봉구  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 10   노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 11   은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 12  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797
# ...

# %%
pop_Seoul=pop_Seoul.sort_values('인구수',ascending=False)

# %%
pop_Seoul
# Out:
#       구별       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 24   송파구  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 16   강서구  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 23   강남구  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 11   노원구  569384.0  565565.0   3819.0  71941.0  0.670725  12.634883
# 21   관악구  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291
# 12   은평구  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 15   양천구  479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 8    성북구  461260.0  449773.0  11487.0  64692.0  2.490353  14.025062
# 25   강동구  453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 22   서초구  450310.0  445994.0   4316.0  51733.0  0.958451  11.488308
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 7    중랑구  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 20   동작구  412520.0  400456.0  12064.0  56013.0  2.924464  13.578251
# ...

# %%
len(pop_Seoul['구별'].unique())
# Out:
# 26

# %%
len(CCTV_Seoul['구별'].unique())
# Out:
# 25

# %%
data_result=pd.merge(CCTV_Seoul,pop_Seoul, on ='구별')

# %%
data_result.columns
# Out:
# Index(['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년', '비율', '인구수', '한국인',
#        '외국인', '고령자', '외국인비율', '고령자비율'],
#       dtype='object')

# %%
data_result=data_result[['구별', '소계','비율', '인구수','한국인','외국인', '고령자', '외국인비율', '고령자비율']]

# %%
data_result=data_result.set_index('구별')
# Out:
#       구별    소계     비율       인구수       한국인      외국인      고령자     외국인비율  \
# 0    강남구  2780  151.0  570500.0  565550.0   4950.0  63167.0  0.867660
# 1    강동구   773  166.0  453233.0  449019.0   4214.0  54622.0  0.929765
# 2    강북구   748  125.0  330192.0  326686.0   3506.0  54813.0  1.061806
# 3    강서구   884  135.0  603772.0  597248.0   6524.0  72548.0  1.080540
# 4    관악구  1496  149.0  525515.0  507203.0  18312.0  68082.0  3.484582
# 5    광진구   707   53.0  372164.0  357211.0  14953.0  42214.0  4.017852
# 6    구로구  1561   65.0  447874.0  416487.0  31387.0  56833.0  7.007998
# 7    금천구  1015  100.0  255082.0  236353.0  18729.0  32970.0  7.342345
# 8    노원구  1265  189.0  569384.0  565565.0   3819.0  71941.0  0.670725
# 9    도봉구   485  247.0  348646.0  346629.0   2017.0  51312.0  0.578524
# 10  동대문구  1294   75.0  369496.0  354079.0  15417.0  54173.0  4.172440
# 11   동작구  1091  139.0  412520.0  400456.0  12064.0  56013.0  2.924464
# ...

# %%
data_result.corr()
# Out:
#              소계        비율       인구수       한국인       외국인       고령자     외국인비율  \
# 소계     1.000000 -0.342443  0.306342  0.304287 -0.023786  0.255196 -0.136074
# 비율    -0.342443  1.000000 -0.093860 -0.083283 -0.150633 -0.071646 -0.043734
# 인구수    0.306342 -0.093860  1.000000  0.998061 -0.153371  0.932667 -0.591939
# 한국인    0.304287 -0.083283  0.998061  1.000000 -0.214576  0.931636 -0.637911
# 외국인   -0.023786 -0.150633 -0.153371 -0.214576  1.000000 -0.155381  0.838904
# 고령자    0.255196 -0.071646  0.932667  0.931636 -0.155381  1.000000 -0.606088
# 외국인비율 -0.136074 -0.043734 -0.591939 -0.637911  0.838904 -0.606088  1.000000
# 고령자비율 -0.280786  0.185904 -0.669462 -0.660812 -0.014055 -0.380468  0.267348
#
#           고령자비율
# 소계    -0.280786
# 비율     0.185904
# 인구수   -0.669462
# 한국인   -0.660812
# 외국인   -0.014055
# 고령자   -0.380468
# 외국인비율  0.267348
# 고령자비율  1.000000

# %%
np.corrcoef(data_result['인구수'],data_result['소계'])
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %%
fp1=np.polyfit(data_result['인구수'],data_result['소계'],1)     #두개숫자의 상간관계 1차 혹은 2차방정식을 찾아준다
fp1
# Out:
# array([1.30916415e-03, 6.45066497e+02])

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'],data_result['소계'],s=50)
plt.plot(fx,f1(fx),':r')

# %%
f1=np.poly1d(fp1)

# %%
a=np.array([1,2,3,4,5])
f1(a)
# Out:
# array([645.06780575, 645.06911491, 645.07042408, 645.07173324,
#        645.07304241])

# %%
fx=np.linspace(0,700000,100)           # 1부터 10까지 균등하게 숫자 5개 만들기

# %%
data_result.head()
# Out:
#        소계     비율       인구수       한국인      외국인      고령자     외국인비율      고령자비율
# 구별
# 강남구  2780  151.0  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 강동구   773  166.0  453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# 강북구   748  125.0  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 강서구   884  135.0  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 관악구  1496  149.0  525515.0  507203.0  18312.0  68082.0  3.484582  12.955291

# %%
data_result['오차']=np.abs(f1(data_result['인구수'])-data_result['소계'])      #오차 수식

# %%
data_sort=data_result.sort_values('오차',ascending=False)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'],data_result['소계'],s=50)
plt.plot(fx,f1(fx),':r')
plt.text(300000,2800,'hello')
for i in range(10):
    plt.text(data_sort['인구수'][i]*1.02,data_sort['소계'][i]*1.02,data_sort.index[i])
plt.show()
# Out:
# C:\Users\yumei\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44053 (\N{HANGUL SYLLABLE GANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yumei\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 45224 (\N{HANGUL SYLLABLE NAM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yumei\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44396 (\N{HANGUL SYLLABLE GU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yumei\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49569 (\N{HANGUL SYLLABLE SONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\yumei\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54028 (\N{HANGUL SYLLABLE PA}) missing from current font.
# ...

# %%
data_sort
# Out:
#         소계     비율       인구수       한국인      외국인      고령자     외국인비율      고령자비율  \
# 구별
# 강남구   2780  151.0  570500.0  565550.0   4950.0  63167.0  0.867660  11.072217
# 송파구    618  104.0  667483.0  660584.0   6899.0  72506.0  1.033584  10.862599
# 양천구   2034   35.0  479978.0  475949.0   4029.0  52975.0  0.839413  11.036964
# 서초구   1930   63.0  450310.0  445994.0   4316.0  51733.0  0.958451  11.488308
# 용산구   1624   53.0  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 도봉구    485  247.0  348646.0  346629.0   2017.0  51312.0  0.578524  14.717507
# 마포구    574  212.0  389649.0  378566.0  11083.0  48765.0  2.844355  12.515110
# 은평구   1873   85.0  494388.0  489943.0   4445.0  72334.0  0.899091  14.631019
# 강서구    884  135.0  603772.0  597248.0   6524.0  72548.0  1.080540  12.015794
# 중랑구    660   80.0  414503.0  409882.0   4621.0  56774.0  1.114829  13.696885
# 강동구    773  166.0  453233.0  449019.0   4214.0  54622.0  0.929765  12.051638
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 os.dir()
#
# AttributeError: module 'os' has no attribute 'dir'
