# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False
import openpyxl
import warnings
warnings.filterwarnings('ignore')
import os

# %%
df=pd.read_csv('./폐업_전국_김혜원_csv').iloc[:,1:]
df
# Out:
#       사업자별 지역별    년도     총계  사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병  \
# 0    간이사업자  강원  2014   9530  4689     8    49    13        1     95      9
# 1    간이사업자  강원  2015   8974  4512    15    32    13        1    103     12
# 2    간이사업자  강원  2016   9833  4705    17    49    16        6    185     10
# 3    간이사업자  강원  2017   9818  4056    29    61    18        0    179     32
# 4    간이사업자  강원  2018   9058  3746    48    51    15        1    202     10
# ..     ...  ..   ...    ...   ...   ...   ...   ...      ...    ...    ...
# 539  일반사업자  충북  2017  13202  5019    39    10   123        3    653      8
# 540  일반사업자  충북  2018  13394  5075    45    14   145        2    785      4
# 541  일반사업자  충북  2019  13869  5402    14    15    89        2    769      2
# 542  일반사업자  충북  2020  12889  5582    24    11    91        4    773      5
# 543  일반사업자  충북  2021  12246  5486    18     7    85        1    891      4
#
#        기타
# 0    4666
# 1    4286
# 2    4845
# 3    5443
# ...

# %%
df.groupby(['지역별','년도']).sum()
# Out:
#              총계   사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병     기타
# 지역별 년도
# 강원  2014  22601  10972    23    66    89        6    363     58  11024
#     2015  21867  10574    51    45    85        5    444     61  10602
#     2016  25626  11514    81    72   121       19    729     72  13018
#     2017  25299  10312    81    85   117        8    768    119  13809
#     2018  25980  10202   196    87   115        7   1006     60  14307
# ...         ...    ...   ...   ...   ...      ...    ...    ...    ...
# 충북  2017  26370  10156    76    39   142        7    920     74  14956
#     2018  25883   9746    85    30   163        6   1065     66  14722
#     2019  26584  10306    45    38   110       13    998     51  15023
#     2020  25489  10895    56    21   116       14   1076     50  13261
#     2021  25382  11433    44    23   105        5   1248     76  12448
#
# [136 rows x 9 columns]

# %%
간이사업자=df[df['사업자별']=='간이사업자'].reset_index(drop=True)
면세사업자=df[df['사업자별']=='면세사업자'].reset_index(drop=True)
법인사업자=df[df['사업자별']=='법인사업자'].reset_index(drop=True)
일반사업자=df[df['사업자별']=='일반사업자'].reset_index(drop=True)

# %%
간이사업자
# Out:
#       사업자별 지역별    년도    총계  사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병  \
# 0    간이사업자  강원  2014  9530  4689     8    49    13        1     95      9
# 1    간이사업자  강원  2015  8974  4512    15    32    13        1    103     12
# 2    간이사업자  강원  2016  9833  4705    17    49    16        6    185     10
# 3    간이사업자  강원  2017  9818  4056    29    61    18        0    179     32
# 4    간이사업자  강원  2018  9058  3746    48    51    15        1    202     10
# ..     ...  ..   ...   ...   ...   ...   ...   ...      ...    ...    ...
# 131  간이사업자  충북  2017  9236  3732    23    19     7        0    197      4
# 132  간이사업자  충북  2018  8277  3361     8    10     9        0    199      0
# 133  간이사업자  충북  2019  8616  3496    22    16    14        3    152      2
# 134  간이사업자  충북  2020  8068  3689    15     6    12        8    190      2
# 135  간이사업자  충북  2021  8728  4392    14    10    16        1    209      5
#
#        기타
# 0    4666
# 1    4286
# 2    4845
# 3    5443
# 4    4985
# ...

# %%
df_all=df.groupby(['년도','사업자별']).sum()
df_all=df_all.reset_index()
df_all
# Out:
#       년도   사업자별      총계    사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병  \
# 0   2014  간이사업자  244474  110159   280   236   171       21   3539    230
# 1   2014  면세사업자   80724   30214   128    67   465       95    939     53
# 2   2014  법인사업자   54296   21233   545    11     0        0    995   1796
# 3   2014  일반사업자  436130  189124  1013   181  4461       67  17928    807
# 4   2015  간이사업자  233772  101358   302   207   236       22   4014    149
# 5   2015  면세사업자   71696   27024   128    63   405      115   1029     42
# 6   2015  법인사업자   50630   20329   943     9     1        0    646   2115
# 7   2015  일반사업자  433952  177355  1481   227  4321      177  20646    371
# 8   2016  간이사업자  252342  104830   679   266   274       56   4360    249
# 9   2016  면세사업자   82325   29382   294    89   480      163   1359     65
# 10  2016  법인사업자   69600   25550  1923    11     1        1    790   2209
# 11  2016  일반사업자  504935  196762  2620   309  4529      420  25248    478
# ...

# %%
df_all['년도'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype=int64)

# %%
import os
from PIL import Image
from IPython.display import Image as Img
from IPython.display import display
def generate_gif(path):
    img_list = os.listdir(path)
    img_list = [path + '/' + x for x in img_list]
    images = [Image.open(x) for x in img_list]
    
    im = images[0]
    im.save(f'{idx}.gif', save_all=True, append_images=images[1:],loop=0xff, duration=1500)
    # loop 반복 횟수
    # duration 프레임 전환 속도 (500 = 0.5초)
    return Img(url='out.gif')

# %%
# 간이사업자 _사유별
ls=[ '총계','사업부진', '행정처분', '계절사업', '법인전환', '면세포기·적용',
       '양도·양수', '해산·합병']

for idx,a in enumerate(ls):
    plt.figure(figsize=(10,8))
    os.makedirs(f'./간이사업자/', exist_ok=True)
    sns.barplot(x='지역별',y=a,hue='년도',data=간이사업자,palette='BuPu')
    plt.title(f'간이사업자 폐업사유: {a}별')
    plt.savefig(f'./간이사업자/{idx+1}.jpg')
    plt.show()

# %%
간이 = generate_gif('간이사업자')
display(간이)
# Out:
# <img src="out.gif"/>

# %%
# 법인사업자 _사유별
for idx,b in enumerate(ls):
    os.makedirs(f'./법인사업자/', exist_ok=True)
    plt.figure(figsize=(10,8))
    sns.barplot(x='지역별',y=b,hue='년도',data=법인사업자,palette='Oranges')
    plt.title(f'법인사업자 폐업사유: {b}별')
    plt.savefig(f'./법인사업자/{idx+1}별.jpg')
    plt.show()

# %%
법인 = generate_gif('./법인사업자/')
display(법인)
# Out:
# <img src="out.gif"/>

# %%
# 면세사업자 _사유별
for idx,c in enumerate(ls):
    os.makedirs(f'./면세사업자/', exist_ok=True)
    plt.figure(figsize=(10,8))
    sns.barplot(x='지역별',y=c,hue='년도',data=면세사업자,palette='Greens')
    plt.title(f'면세사업자 폐업사유: {c}별')
    plt.savefig(f'./면세사업자/{idx+1}별.jpg')
    plt.show()

# %%
면세 = generate_gif('./면세사업자/')
display(면세)
# Out:
# <img src="out.gif"/>

# %%
# 일반사업자 _사유별
for idx,d in enumerate(ls):
    os.makedirs(f'./일반사업자/', exist_ok=True)
    plt.figure(figsize=(10,8))
    sns.barplot(x='지역별',y=d,hue='년도',data=일반사업자,palette='Reds')
    plt.title(f'일반사업자 폐업사유: {d}별')
    plt.savefig(f'./일반사업자/{idx+1}별.jpg')
    plt.show()

# %%
일반 = generate_gif('./일반사업자/')
display(일반)
# Out:
# <img src="out.gif"/>

# %%
df_all['사업자별'].unique()
# Out:
# array(['간이사업자', '면세사업자', '법인사업자', '일반사업자'], dtype=object)

# %%
df_all[df_all['사업자별']=='법인사업자'].groupby('년도').sum().reset_index()
# Out:
#      년도     총계   사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병     기타
# 0  2014  54296  21233   545    11     0        0    995   1796  29716
# 1  2015  50630  20329   943     9     1        0    646   2115  26587
# 2  2016  69600  25550  1923    11     1        1    790   2209  39115
# 3  2017  70362  25496  1642    11     1        0    906   2275  40031
# 4  2018  69667  26431  1029    37     1        0    846   2082  39241
# 5  2019  69587  27898  1198    35     0        1   1035   2205  37215
# 6  2020  67547  29354   749    21     0        0   1028   2172  34223
# 7  2021  65983  28754   632    16     0        0   1171   2682  32728

# %%
for name in df_all['사업자별'].unique():
    plt.figure(figsize=(8,6))
    p=df_all[df_all['사업자별']==name].groupby('년도').sum().reset_index()
    ls1=[ '사업부진', '행정처분', '계절사업', '법인전환', '면세포기·적용',
       '양도·양수', '해산·합병']
    for l in ls1:
        plt.plot(p['년도'],p[l],label=l,linestyle =':',marker='o')
        plt.title(name)
        plt.legend(bbox_to_anchor=(1,1))      
        
    plt.show()

# %%
total=df_all.groupby('년도').sum().reset_index()
del total['총계']
del total['기타']
total
# Out:
#      년도    사업부진  행정처분  계절사업  법인전환  면세포기·적용  양도·양수  해산·합병
# 0  2014  350730  1966   495  5097      183  23401   2886
# 1  2015  326066  2854   506  4963      314  26335   2677
# 2  2016  356524  5516   675  5284      640  31757   3001
# 3  2017  348271  5550   849  5344      430  34394   3080
# 4  2018  360871  3741   933  5551      511  37984   2745
# 5  2019  381334  4027  1102  5236      537  40185   2782
# 6  2020  386219  3313   876  5059      391  43538   2645
# 7  2021  403696  2914   709  4706      268  51200   3063

# %%
total1=total.copy()
total1.iloc[0,1:]
# Out:
# 사업부진       350730
# 행정처분         1966
# 계절사업          495
# 법인전환         5097
# 면세포기·적용       183
# 양도·양수       23401
# 해산·합병        2886
# Name: 0, dtype: int64

# %%
total1.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
import matplotlib.pyplot as plt
import numpy as np
 
cols=[ '사업부진', '행정처분', '계절사업', '법인전환', '면세포기·적용', '양도·양수', '해산·합병']
## 데이터 준비
colors = ['#ff9999', '#ffc000', '#8fd9b6', '#d395d0','red', 'gray', 'purple'] ## 색상
labels = cols ## 라벨
index=total1.index
os.makedirs(f'./년도별_파이차트/', exist_ok=True)

for idx,x in enumerate(index):

    plt.figure(figsize=(10,8))
    wedgeprops = {'width': 0.6, 'linewidth': 1, 'edgecolor': 'black'}  # 파이차트 테두리 설정
    frequency =total1.iloc[x,1:]   # 빈도 / 데이터
    explode = [0.05,0.4,0.4,0.4,0.4,0.4,0.4]   #간격을 설정하기

    fig = plt.figure(figsize=(10,8)) ## 캔버스 생성
    fig.set_facecolor('white') ## 캔버스 배경색을 하얀색으로 설정
    ax = fig.add_subplot() ## 프레임 생성

    pie = ax.pie(frequency, # 파이차트 출력
           startangle=120, # 시작점을 90도(degree)로 지정
           counterclock=False, # 시계방향으로 그려짐
           colors = colors, # 색상 지정
            explode=explode,   # 간격 지정
             wedgeprops = wedgeprops,  # 테두리 지정
           )

    total = np.sum(frequency) # 빈도수 합
    threshold = 5 # 상한선 비율
    sum_pct = 0 # 퍼센티지

    bbox_props = dict(boxstyle='square',fc='w',ec='w',alpha=0) ## annotation 박스 스타일

    # annotation 설정
    config = dict(arrowprops=dict(arrowstyle='-'),bbox=bbox_props,va='center')
    plt.title(f'{x+2014}년') 
    for i,l in enumerate(labels):
        ang1, ang2 = ax.patches[i].theta1, ax.patches[i].theta2 ## 파이의 시작 각도와 끝 각도
        center, r = ax.patches[i].center, ax.patches[i].r ## 원의 중심 좌표와 반지름길이
        

        if i < len(labels) - 1:
            sum_pct += float(f'{frequency[i]/total*100:.2f}')
            text = f'{frequency[i]/total*100:.2f}%'
        else:    # 마지막 파이 조각은 퍼센티지의 합이 100이 되도록 비율을 조절
            text = f'{100-sum_pct:.2f}%'

        ## 비율 상한선보다 작은 것들은 Annotation으로 만든다.
        if frequency[i]/total*100 < threshold:
            ang = (ang1+ang2)/2 ## 중심각
            x = np.cos(np.deg2rad(ang)) ## Annotation의 끝점에 해당하는 x좌표
            y = np.sin(np.deg2rad(ang)) ## Annotation의 끝점에 해당하는 y좌표

            ## x좌표가 양수이면 즉 y축을 중심으로 오른쪽에 있으면 왼쪽 정렬
            ## x좌표가 음수이면 즉 y축을 중심으로 왼쪽에 있으면 오른쪽 정렬
            horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
            connectionstyle = "angle,angleA=0,angleB={}".format(ang) ## 시작점과 끝점 연결 스타일
            config["arrowprops"].update({"connectionstyle": connectionstyle}) ## 
            ax.annotate(text, xy=(x, y), xytext=(2*x, 1.8*y),
                        horizontalalignment=horizontalalignment, **config)
        else:
            x = (r/2)*np.cos(np.pi/180*((ang1+ang2)/2)) + center[0] ## 텍스트 x좌표
            y = (r/2)*np.sin(np.pi/180*((ang1+ang2)/2)) + center[1] ## 텍스트 y좌표
            ax.text(x,y,text,ha='center',va='center',fontsize=12)
       
    plt.legend(pie[0],labels,loc='upper right') ## 범례
    plt.savefig(f'./년도별_파이차트/{idx+1}.jpg')
plt.show()

# %%
년도별 = generate_gif('년도별_파이차트')
display(년도별)
# Out:
# <img src="out.gif"/>
